# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ADSET = 'TSP'

# %% [markdown]
# # Code for video Download from Text file

# %%
with open(f"/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}.txt") as file_in:
    lines = []
    for line in file_in:
      line = line.strip()
      lines.append(line)

lines = [name for name in lines if name.endswith('.mp4')]
lines
# Out:
# ['https://gallery-pm.go-game.io/uploads/2020/10/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/10/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/11/LLC_LightningLinkMultipleIP_V28685_15_English_Portrait&IMG=M4T.mp4',
#  'https://gallery-pm.go-game.io/uploads/2018/11/LLC_UA_V723_15_No%20Language_Square&IMG=K3.mp4',
#  'https://gallery-pm.go-game.io/uploads/2019/08/20190620_LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/04/LLC_BuffaloDeluxe_V20593_15_English_Portrait&IMG=FW1.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/01/LLC_BuffaloDeluxe_V30648_15_English_Square&IMG=NNC.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/02/LLC_LightningLinkMultipleIP_V31163_15_English_Portrait&IMG=O1N.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/11/LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/01/LLC_BuffaloDeluxe_V30647_15_English_Portrait&IMG=NNB.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/07/LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/11/LLC_LightningLinkMultipleIP_V28686_15_English_Square&IMG=M4U.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/07/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/11/LLC_LightningLinkMultipleIP_V28694_15_English_Portrait&IMG=M52.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/09/LLC_BuffaloDeluxe_V25786_15_English_Square&IMG=JWA.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/11/LLC_LightningLinkMultipleIP_V28688_15_English_Portrait&IMG=M4W.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31903_30_English_Portr&IMG=OM7.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31902_30_English_Portr&IMG=OM6.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31887_17_English_Portr&IMG=OLR.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31886_17_English_Squar&IMG=OLQ.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31885_17_English_Lands&IMG=OLP.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31884_17_English_Lands&IMG=OLO.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31882_17_English_Portr&IMG=OLM.mp4']

# %%
len(lines)
# Out:
# 36

# %%
import os
if not os.path.exists(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ADS'):
    os.makedirs(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ADS')

# %%
import requests
import time
from tqdm import tqdm

# %%
def download(url,name):
  r = requests.get(url, allow_redirects=True)
  open(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ADS/{name}.mp4', 'wb').write(r.content)
  print("Download_Complete :",name)

# %%
count=0
for url in tqdm(lines):
    name_start_index = url.index(f"{ADSET}")
    name_end_index = url.index(".mp4") 
    download(url=url,name=url[name_start_index:name_end_index:1])
    count += 1
    time.sleep(2)
# Out:
#   0%|          | 0/36 [00:00<?, ?it/s]
# Download_Complete : LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6
#   3%|▎         | 1/36 [00:05<02:55,  5.01s/it]
# Download_Complete : LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5
#   6%|▌         | 2/36 [00:08<02:30,  4.44s/it]
# Download_Complete : LLC_LightningLinkMultipleIP_V28685_15_English_Portrait&IMG=M4T
#   8%|▊         | 3/36 [00:12<02:22,  4.33s/it]
# Download_Complete : LLC_UA_V723_15_No%20Language_Square&IMG=K3
#  11%|█         | 4/36 [00:16<02:22,  4.44s/it]
# Download_Complete : LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4
#  14%|█▍        | 5/36 [00:20<02:07,  4.10s/it]
# Download_Complete : LLC_BuffaloDeluxe_V20593_15_English_Portrait&IMG=FW1
#  17%|█▋        | 6/36 [00:23<01:55,  3.85s/it]
# Download_Complete : LLC_BuffaloDeluxe_V30648_15_English_Square&IMG=NNC
#  19%|█▉        | 7/36 [00:28<02:02,  4.22s/it]
# Download_Complete : LLC_LightningLinkMultipleIP_V31163_15_English_Portrait&IMG=O1N
#  22%|██▏       | 8/36 [00:32<01:57,  4.19s/it]
# Download_Complete : LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY
#  25%|██▌       | 9/36 [00:39<02:10,  4.85s/it]
# Download_Complete : LLC_WildChuco_V28769_15_English_Square&IMG=M75
#  28%|██▊       | 10/36 [00:43<02:03,  4.74s/it]
# Download_Complete : LLC_BuffaloDeluxe_V30647_15_English_Portrait&IMG=NNB
#  31%|███       | 11/36 [00:47<01:53,  4.54s/it]
# Download_Complete : LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ
#  33%|███▎      | 12/36 [00:52<01:52,  4.67s/it]
# Download_Complete : LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2
#  36%|███▌      | 13/36 [00:58<01:52,  4.91s/it]
# Download_Complete : LLC_LightningLinkMultipleIP_V28686_15_English_Square&IMG=M4U
#  39%|███▉      | 14/36 [01:01<01:39,  4.51s/it]
# Download_Complete : LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV
#  42%|████▏     | 15/36 [01:06<01:38,  4.67s/it]
# Download_Complete : LLC_LightningLinkMultipleIP_V28694_15_English_Portrait&IMG=M52
#  44%|████▍     | 16/36 [01:11<01:31,  4.58s/it]
# Download_Complete : LLC_BuffaloDeluxe_V25786_15_English_Square&IMG=JWA
#  47%|████▋     | 17/36 [01:14<01:23,  4.37s/it]
# Download_Complete : LLC_LightningLinkMultipleIP_V28688_15_English_Portrait&IMG=M4W
#  50%|█████     | 18/36 [01:18<01:14,  4.14s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF
#  53%|█████▎    | 19/36 [01:24<01:18,  4.62s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME
#  56%|█████▌    | 20/36 [01:28<01:12,  4.52s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD
#  58%|█████▊    | 21/36 [01:32<01:04,  4.28s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC
#  61%|██████    | 22/36 [01:36<00:57,  4.11s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB
#  64%|██████▍   | 23/36 [01:39<00:51,  3.94s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9
#  67%|██████▋   | 24/36 [01:44<00:49,  4.15s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31903_30_English_Portr&IMG=OM7
#  69%|██████▉   | 25/36 [01:50<00:53,  4.90s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31902_30_English_Portr&IMG=OM6
#  72%|███████▏  | 26/36 [01:55<00:48,  4.81s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5
#  75%|███████▌  | 27/36 [01:59<00:42,  4.68s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU
#  78%|███████▊  | 28/36 [02:05<00:38,  4.85s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT
#  81%|████████  | 29/36 [02:09<00:32,  4.66s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS
#  83%|████████▎ | 30/36 [02:12<00:25,  4.29s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31887_17_English_Portr&IMG=OLR
#  86%|████████▌ | 31/36 [02:17<00:22,  4.56s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31886_17_English_Squar&IMG=OLQ
#  89%|████████▉ | 32/36 [02:22<00:17,  4.49s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31885_17_English_Lands&IMG=OLP
#  92%|█████████▏| 33/36 [02:26<00:13,  4.34s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31884_17_English_Lands&IMG=OLO
#  94%|█████████▍| 34/36 [02:29<00:08,  4.12s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN
#  97%|█████████▋| 35/36 [02:34<00:04,  4.15s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31882_17_English_Portr&IMG=OLM
# 100%|██████████| 36/36 [02:38<00:00,  4.42s/it]

# %% [markdown]
# ## Video Download from S3 bucket directly

# %%
# !pip3 install boto3

# %%
import boto3, os
from botocore.exceptions import NoCredentialsError
import pandas as pd
import requests, time
import urllib
import requests
import time
from tqdm import tqdm

# %%
ACCESS_ID = 'AKIA526JIYRBRQU7FSKI'
ACCESS_KEY = 'mf5J+4vb2m3c7YTQ8M2T4E4xFyq/P6nut3lCajOB'
bucket = 'blkbox-machinelearning'
acc = 'act_2150947825213215'
url = 'https://blkbox-machinelearning.s3.us-west-1.amazonaws.com/'

# %%
#Connect to s3 Service
client = boto3.client('s3',
         aws_access_key_id=ACCESS_ID,
         aws_secret_access_key= ACCESS_KEY)

# %%
#client.list_objects(Bucket = bucket).get('Contents')

# %%
names = []
if client.list_objects(Bucket = bucket, Prefix='Videos/{a}/'.format(a=acc)).get('Contents'):
            result = client.list_objects(Bucket = bucket, Prefix='Videos/{a}/'.format(a=acc)).get('Contents')
            for obj in result:
                names.append(obj['Key'])

# %%
names = [name for name in names if name.endswith(".mp4")]

# %%
full_paths = []
for name in names:
  path = os.path.join(url, name)
  full_paths.append(path)

# %%
full_paths

# %%
if not os.path.exists(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ADS'):
    os.makedirs(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ADS')

# %%
def download(url,name):
  r = requests.get(url, allow_redirects=True)
  open(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ADS/{name}', 'wb').write(r.content)
  print("Download_Complete :",name)

# %%
count=0
for video_path in full_paths:
    start = video_path.index('act_')
    end = video_path.index('.mp4')
    #print(start)
    #print(end)
    name = video_path[start:end:1].replace('/','-')
    #print(name)
    download(url=video_path,name=name)
    count += 1
  
print(count)

# %% [markdown]
# # Code for Downloaded ADSET VIDEO SPLITTING INTO SCENES USING PYSCENEDETECT

# %%
from tqdm import tqdm
import time
import os
from moviepy.editor import *
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %%
# Name of the directory where we want the splitted scenes to reside
if not os.path.exists(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_F_DATA'):
    os.makedirs(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_F_DATA')

# %%
def list_full_paths(directory):
    return [os.path.join(directory, file) for file in os.listdir(directory)]

videos = list_full_paths(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_ADS')

# %%
data = os.listdir(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_ADS')

# %%
#videos = [video for video in videos if video.endswith('.mp4')]
#data = [name for name in data if name.endswith('.mp4')]
print(len(videos))

print(len(data))
# Out:
# 165
# 165

# %%
print(data)
print()
print(videos)
# Out:
# ['act_472592610491195-03-10-21_TSB21-TeamPower_1920x1080 (1)', 'act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080', 'act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350', 'act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920', 'act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080', 'act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080', 'act_472592610491195-21-03-11-TSB21-SoClose_1080x1080', 'act_472592610491195-21-03-11-TSB21-SoClose_1080x1350', 'act_472592610491195-21-03-11-TSB21-SoClose_1080x1920', 'act_472592610491195-21-03-11-TSB21-SoClose_1920x1080', 'act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1080', 'act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350', 'act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1920', 'act_472592610491195-21-03-12-TSB21-SoClose_TopView_1920x1080', 'act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080', 'act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350', 'act_472592610491195-21-05-17-TSB21_YOU_NOT_MUTED_1920x1080', 'act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350', 'act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350', 'act_472592610491195-21_01_21_TSB21_3HITS_ACUNA_1920x1080_5s', 'act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080', 'act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350', 'act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920', 'act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1080', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1350', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_1', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_2', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_3', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_4', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080', 'act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080', 'act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1350', 'act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920', 'act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1920x1080', 'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V1', 'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V2', 'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V3', 'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V1', 'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V2', 'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V3', 'act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V1', 'act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V2', 'act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V3', 'act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350', 'act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080', 'act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1080_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1350_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1920_08', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1920x1080_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1080_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1350_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1920x1080_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1080_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1350_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1920_04', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1920x1080_01 ...
#
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-03-10-21_TSB21-TeamPower_1920x1080 (1)', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-11-TSB21-SoClose_1080x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-11-TSB21-SoClose_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-11-TSB21-SoClose_1080x1920', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-11-TSB21-SoClose_1920x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1920', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1920x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-05-17-TSB21_YOU_NOT_MUTED_1920x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_01_21_TSB21_3HITS_ACUNA_1920x1080_5s', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_1', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_2', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_3', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3 ...

# %%
# !pip install ffmpeg scenedetect
# Out:
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
# Collecting scenedetect
#   Downloading scenedetect-0.5.5-py2.py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 7.8 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from scenedetect) (4.41.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from scenedetect) (1.19.5)
# Requirement already satisfied: Click in /usr/local/lib/python3.7/dist-packages (from scenedetect) (7.1.2)
# Building wheels for collected packages: ffmpeg
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6084 sha256=b7f67f07d4d159923ec5455984842d3b954004d32e27178f7b4ea52410f9a030
#   Stored in directory: /root/.cache/pip/wheels/64/80/6e/caa3e16deb0267c3cbfd36862058a724144e19fdb9eb03af0f
# Successfully built ffmpeg
# Installing collected packages: scenedetect, ffmpeg
# Successfully installed ffmpeg-1.4 scenedetect-0.5.5

# %%
from scenedetect import VideoManager
from scenedetect.video_splitter import split_video_ffmpeg
from scenedetect import SceneManager

# %%
from scenedetect.detectors import ContentDetector

# %%
def find_scenes(video_path, threshold):
    # Create our video & scene managers, then add the detector.
    video_manager = VideoManager([video_path])
    scene_manager = SceneManager()
    scene_manager.add_detector(
        ContentDetector(threshold=threshold))

    # Improve processing speed by downscaling before processing.
    video_manager.set_downscale_factor()

    # Start the video manager and perform the scene detection.
    video_manager.start()
    scene_manager.detect_scenes(frame_source=video_manager)

    # Each returned scene is a tuple of the (start, end) timecode.
    return scene_manager.get_scene_list()

# %%
def split_scenes(video_path, scene_list, name):
  # print(scene_list)
  # print(os.getcwd())
    os.chdir(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_F_DATA')
  # print(os.getcwd())
    
    if not os.path.exists(name):
        os.makedirs(name)
    print(os.getcwd())
    os.chdir(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_F_DATA/{name}')
    print(os.getcwd())
    split_video_ffmpeg([video_path], scene_list = scene_list, 
      output_file_template = '$VIDEO_NAME - Scene $SCENE_NUMBER.mp4', video_name = name)
    # Each returned scene is a tuple of the (start, end) timecode.
    return True

# %%
def check_video_threshold(video_path):
  # Create an object by passing the location as a string
  video_len = VideoFileClip(video_path)
  
  # getting duration of the video
  video_duration = int(video_len.duration)

  if video_duration <= 15:
    threshold = 45.00
  elif video_duration > 15 & video_duration < 30:
    threshold = 30.00
  return threshold

# %%
check_video_threshold('/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080')
# Out:
# 30.0

# %%
print(videos)
print(data)
# Out:
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-03-10-21_TSB21-TeamPower_1920x1080 (1)', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-11-TSB21-SoClose_1080x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-11-TSB21-SoClose_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-11-TSB21-SoClose_1080x1920', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-11-TSB21-SoClose_1920x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1920', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1920x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-05-17-TSB21_YOU_NOT_MUTED_1920x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_01_21_TSB21_3HITS_ACUNA_1920x1080_5s', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1350', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_1', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_2', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_3', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-21_02_01_TSB21_3 ...
# ['act_472592610491195-03-10-21_TSB21-TeamPower_1920x1080 (1)', 'act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080', 'act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350', 'act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920', 'act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080', 'act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080', 'act_472592610491195-21-03-11-TSB21-SoClose_1080x1080', 'act_472592610491195-21-03-11-TSB21-SoClose_1080x1350', 'act_472592610491195-21-03-11-TSB21-SoClose_1080x1920', 'act_472592610491195-21-03-11-TSB21-SoClose_1920x1080', 'act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1080', 'act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350', 'act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1920', 'act_472592610491195-21-03-12-TSB21-SoClose_TopView_1920x1080', 'act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080', 'act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350', 'act_472592610491195-21-05-17-TSB21_YOU_NOT_MUTED_1920x1080', 'act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350', 'act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350', 'act_472592610491195-21_01_21_TSB21_3HITS_ACUNA_1920x1080_5s', 'act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080', 'act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350', 'act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920', 'act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1080', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1350', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_1', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_2', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_3', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_4', 'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080', 'act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080', 'act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1350', 'act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920', 'act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1920x1080', 'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V1', 'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V2', 'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V3', 'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V1', 'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V2', 'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V3', 'act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V1', 'act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V2', 'act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V3', 'act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350', 'act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080', 'act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1080_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1350_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1920_08', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1920x1080_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1080_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1350_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1920x1080_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1080_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1350_01 (1)', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1920_04', 'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1920x1080_01 ...

# %%
counter = 0
for video in videos:
    video_path = video
    #function to check the length of the videos and assign dynamic threshold
    thres = check_video_threshold(video_path)
    

    #scenes = find_scenes(video_path)
    scenes = find_scenes(video_path, thres)
    split_scenes(video_path, scenes, data[counter])
    counter += 1
    time.sleep(3)
# Out:
# 100%|██████████| 611/611 [00:02<00:00, 298.44frames/s]
#   0%|          | 0/611 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-10-21_TSB21-TeamPower_1920x1080 (1)
# 100%|██████████| 611/611 [00:13<00:00, 41.14frame/s]
#   0%|          | 0/492 [00:00<?, ?frames/s]
#   9%|▊         | 42/492 [00:00<00:01, 417.43frames/s]
#  16%|█▋        | 81/492 [00:00<00:01, 407.00frames/s]
#  25%|██▌       | 123/492 [00:00<00:00, 410.33frames/s]
#  34%|███▎      | 165/492 [00:00<00:00, 411.73frames/s]
#  42%|████▏     | 207/492 [00:00<00:00, 412.36frames/s]
#  51%|█████     | 250/492 [00:00<00:00, 416.38frames/s]
#  61%|██████    | 298/492 [00:00<00:00, 431.57frames/s]
#  69%|██████▉   | 340/492 [00:00<00:00, 426.02frames/s]
#  78%|███████▊  | 384/492 [00:00<00:00, 428.61frames/s]
#  89%|████████▉ | 437/492 [00:01<00:00, 453.47frames/s]
# 100%|██████████| 492/492 [00:01<00:00, 436.55frames/s]
#
#   0%|          | 0/492 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080
#  18%|█▊        | 90/492 [00:00<00:04, 99.10frame/s]
#  28%|██▊       | 138/492 [00:01<00:04, 82.59frame/s]
#  36%|███▋      | 179/492 [00:02<00:04, 73.00frame/s]
#  51%|█████     | 251/492 [00:03<00:03, 70.67frame/s]
#  80%|████████  | 395/492 [00:05<00:01, 74.84frame/s]
#  87%|████████▋ | 429/492 [00:05<00:00, 70.27frame/s]
# 100%|██████████| 492/492 [00:06<00:00, 72.02frame/s]
#   0%|          | 0/492 [00:00<?, ?frames/s]
#
#   2%|▏         | 10/492 [00:00<00:07, 60.37frames/s]
#
#   7%|▋         | 33/492 [00:00<00:05, 77.51frames/s]
#
#  12%|█▏        | 58/492 [00:00<00:04, 97.33frames/s]
#
#  16%|█▋        | 80/492 [00:00<00:03, 116.88frames/s]
#
#  21%|██        | 102/492 [00:00<00:02, 135.88frames/s]
#
#  26%|██▌       | 126/492 [00:00<00:02, 156.12frames/s]
#
#  30%|███       | 149/492 [00:00<00:01, 171.50frames/s]
#
#  35%|███▌      | 174/492 [00:00<00:01, 188.04frames/s]
#
#  40%|████      | 197/492 [00:00<00:01, 197.66frames/s]
#
#  46%|████▌     | 224/492 [00:01<00:01, 213.04frames/s]
#
#  50%|█████     | 248/492 [00:01<00:01, 216.62frames/s]
#
#  55%|█████▌    | 273/492 [00:01<00:00, 225.60frames/s]
#
#  61%|██████    | 299/492 [00:01<00:00, 228.03frames/s]
#
#  66%|██████▌   | 324/492 [00:01<00:00, 233.06frames/s]
#
#  71%|███████   | 348/492 [00:01<00:00, 232.19frames/s]
#
#  76%|███████▌  | 372/492 [00:01<00:00, 233.14frames/s]
#
#  81%|████████  | 398/492 [00:01<00:00, 240.40frames/s]
#
#  86%|████████▌ | 424/492 [00:01<00:00, 243.74frames/s]
#
#  91%|█████████▏| 449/492 [00:02<00:00, 242.27frames/s]
#
# 100%|██████████| 492/492 [00:02<00:00, 225.97frames/s]
#
#
#   0%|          | 0/492 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350
#  18%|█▊        | 90/492 [00:01<00:06, 59.15frame/s]
#
#  28%|██▊       | 138/492 [00:02<00:07, 49.25frame/s]
#
#  36%|███▋      | 179/492 [00:04<00:07, 44.47frame/s]
#
#  51%|█████     | 251/492 [00:05<00:05, 42.69frame/s]
#
#  87%|████████▋ | 429/492 [00:08<00:01, 46.31frame/s]
#
# 100%|██████████| 492/492 [00:10<00:00, 48.42frame/s]
#   0%|          | 0/492 [00:00<?, ?frames/s]
#
#
#   3%|▎         | 13/492 [00:00<00:03, 126.50frames/s]
#
#
#   5%|▌         | 26/492 [00:00<00:03, 127.37frames/s]
#
#
#   9%|▊         | 43/492 [00:00<00:03, 136.72frames/s]
#
#
#  12%|█▏        | 59/492 [00:00<00:03, 141.19frames/s]
#
#
#  15%|█▌        | 76/492 [00:00<00:02, 147.38frames/s]
#
#
#  19%|█▉        | 93/492 [00:00<00:02, 151.51frames/s]
#
#
#  23%|██▎       | 111/492 [00:00<00:02, 157.01frames/s]
#
#
#  26%|██▌       | 129/492 [00:00<00:02, 163.06frames/s]
#
#
#  30%|██▉       | 146/492 [00:00<00:02, 163.77frames/s]
#
#
#  33%|███▎      | 163/492 [00:01<00:02, 162.79frames/s]
#
#
#  37%|███▋      | 180/492 [00:01<00:01, 162.60frames/s]
#
#
#  40%|████      | 197/492 [00:01<00:01, 161.69frames/s]
#
#
#  43%|████▎     | 214/492 [00:01<00:01, 160.80frames/s]
#
#
#  47%|████▋     | 230/492 [00:01<00:01, 159.42frames/s]
#
#
#  50%|█████     | 246/492 [00:01<00:01, 158.71frames/s]
#
#
#  53%|█████▎    | 263/492 [00:01<00:01, 160.71frames/s]
#
#
#  57%|█████▋    | 282/492 [00:01<00:01, 167.31frames/s]
#
#
#  61%|██████    | 299/492 [00:01<00:01, 161.10frames/s]
#
#
#  64%|██████▍   | 316/492 [00:01<00:01, 161.31frames/s]
#
#
#  68%|██████▊   | 333/492 [00:02<00:01, 154.58frames/s]
#
#
#  71%|███████   | 350/492 [00:02<00:00, 157.67frames/s]
#
#
#  74%|███████▍  | 366/492 [00:02<00:00, 157.39frames/s]
#
#
#  78%|███████▊  | 383/492 [00:02<00:00, 160.54frames/s]
#
#
#  82%|████████▏ | 402/492 [00:02<00:00, 167.55frames/s]
#
#
#  85%|████████▌ | 419/492 [00:02<00:00, 166.81frames/s]
#
#
#  89%|████████▊ | 436/492 [00:02<00:00, 166.51frames/s]
#
#
#  92%|█████████▏| 454/492 [00:02<00:00, 169.53frames/s]
#
#
# 100%|██████████| 492/492 [00:03<00:00, 163.15frames/s]
#
#
#
#   0%|          | 0/492 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920
#  18%|█▊        | 90/492 [00:01<00:08, 47.97frame/s]
#
#
#  28%|██▊       | 138/492 [00:03<00:08, 40.03frame/s]
#
#
#  36%|███▋      | 179/492 [00:04<00:08, 35.86frame/s]
#
#
#  43%|████▎     | 213/492 [00:06<00:08, 32.04frame/s]
#
#
#  51%|█████     | 251/492 [00:07<00:08, 29.26frame/s]
#
#
#  87%|████████▋ | 430/492 [00:11<00:01, 32.75frame/s]
#
#
# 100%|██████████| 492/492 [00:13<00:00, 35.34frame/s]
#   0%|          | 0/492 [00:00<?, ?frames/s]
#
#
#
#   5%|▌         | 25/492 [00:00<00:01, 247.87frames/s]
#
#
#
#  12%|█▏        | 57/492 [00:00<00:01, 263.33frames/s]
#
#
#
#  17%|█▋        | 82/492 [00:00<00:01, 257.51frames/s]
#
#
#
#  22%|██▏       | 107/492 [00:00<00:01, 254.01frames/s]
#
#
#
#  26%|██▌       | 127/492 [00:00<00:01, 220.22frames/s]
#
#
#
#  30%|███       | 149/492 [00:00<00:01, 220.14frames/s]
#
#
#
#  36%|███▌      | 175/492 [00:00<00:01, 228.71frames/s]
#
#
#
#  41%|████      | 201/492 [00:00<00:01, 237.04frames/s]
#
#
#
#  46%|████▌     | 225/492 [00:00<00:01, 236.58frames/s]
#
#
#
#  51%|█████     | 249/492 [00:01<00:01, 236.55frames/s]
#
#
#
#  57%|█████▋    | 279/492 [00:01<00:00, 251.44frames/s]
#
#
#
#  62%|██████▏   | 307/492 [00:01<00:00, 258.76frames/s]
#
#
#
#  68%|██████▊   | 333/492 [00:01<00:00, 258.83frames/s]
#
#
#
#  74%|███████▎  | 362/492 [00:01<00:00, 265.73frames/s]
#
#
#
#  80%|███████▉  | 393/492 [00:01<00:00, 277.34frames/s]
#
#
#
#  87%|████████▋ | 429/492 [00:01<00:00, 296.35frames/s]
#
#
#
# 100%|██████████| 492/492 [00:01<00:00, 267.21frames/s]
#
#
#
#
#   0%|          | 0/492 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080
#  18%|█▊        | 90/492 [00:01<00:08, 48.81frame/s]
#
#
#
#  28%|██▊       | 138/492 [00:03<00:08, 40.69frame/s]
#
#
#
#  36%|███▋      | 179/492 [00:04<00:08, 36.40frame/s]
#
#
#
#  43%|████▎     | 213/492 [00:06<00:08, 33.15frame/s]
#
#
#
#  51%|█████     | 251/492 [00:07<00:07, 30.50frame/s]
#
#
#
#  87%|████████▋ | 429/492 [00:11<00:01, 34.45frame/s]
#
#
#
# 100%|██████████| 492/492 [00:12<00:00, 37.24frame/s]
#   0%|          | 0/521 [00:00<?, ?frames/s]
#
#
#
#
#   8%|▊         | 41/521 [00:00<00:01, 408.73frames/s]
#
#
#
#
#  17%|█▋        | 88/521 [00:00<00:01, 423.31frames/s]
#
#
#
#
#  26%|██▌       | 136/521 [00:00<00:00, 437.53frames/s]
#
#
#
#
#  36%|███▌      | 185/521 [00:00<00:00, 450.56frames/s]
#
#
#
#
#  45%|████▍     | 233/521 [00:00<00:00, 458.09frames/s]
#
#
#
#
#  54%|█████▍    | 281/521 [00:00<00:00, 464.00frames/s]
#
#
#
#
#  63%|██████▎   | 326/521 [00:00<00:00, 458.82frames/s]
#
#
#
#
#  72%|███████▏  | 375/521 [00:00<00:00, 466.51frames/s]
#
#
#
#
#  81%|████████  | 421/521 [00:00<00:00, 464.17frames/s]
#
#
#
#
#  90%|█████████ | 471/521 [00:01<00:00, 472.55frames/s]
#
#
#
#
# 100%|██████████| 521/521 [00:01<00:00, 464.35frames/s]
#
#
#
#
#
#   0%|          | 0/521 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080
#  39%|███▉      | 205/521 [00:01<00:02, 151.35frame/s]
#
#
#
#
#  45%|████▌     | 237/521 [00:01<00:02, 112.01frame/s]
#
#
#
#
#  51%|█████     | 266/521 [00:02<00:03, 84.70frame/s]
#
#
#
#
#  55%|█████▍    | 285/521 [00:02<00:03, 72.89frame/s]
#
#
#
#
#  81%|████████▏ | 424/521 [00:04<00:01, 75.56frame/s]
#
#
#
#
#  88%|████████▊ | 458/521 [00:04<00:00, 71.90frame/s]
#
#
#
#
# 100%|██████████| 521/521 [00:05<00:00, 93.22frame/s]
#   0%|          | 0/567 [00:00<?, ?frames/s]
#
#
#
#
#   7%|▋         | 41/567 [00:00<00:01, 408.28frames/s]
#
#
#
#
#  15%|█▌        | 86/567 [00:00<00:01, 419.06frames/s]
#
#
#
#
#  23%|██▎       | 133/567 [00:00<00:01, 432.65frames/s]
#
#
#
#
#  31%|███       | 176/567 [00:00<00:00, 430.34frames/s]
#
#
#
#
#  40%|███▉      | 225/567 [00:00<00:00, 444.62frames/s]
#
#
#
#
#  47%|████▋     | 267/567 [00:00<00:00, 435.92frames/s]
#
#
#
#
#  55%|█████▍    | 311/567 [00:00<00:00, 434.49frames/s]
#
#
#
#
#  62%|██████▏   | 352/567 [00:00<00:00, 423.00frames/s]
#
#
#
#
#  70%|███████   | 399/567 [00:00<00:00, 434.76frames/s]
#
#
#
#
#  78%|███████▊  | 443/567 [00:01<00:00, 435.13frames/s]
#
#
#
#
#  86%|████████▌ | 487/567 [00:01<00:00, 435.74frames/s]
#
#
#
#
# 100%|██████████| 567/567 [00:01<00:00, 439.11frames/s]
#
#
#
#
#
#   0%|          | 0/567 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1080x1080
#  83%|████████▎ | 470/567 [00:02<00:00, 166.14frame/s]
#
#
#
#
#  89%|████████▉ | 504/567 [00:03<00:00, 118.19frame/s]
#
#
#
#
# 100%|██████████| 567/567 [00:04<00:00, 140.96frame/s]
#   0%|          | 0/567 [00:00<?, ?frames/s]
#
#
#
#
#   4%|▍         | 23/567 [00:00<00:02, 227.31frames/s]
#
#
#
#
#   8%|▊         | 48/567 [00:00<00:02, 232.61frames/s]
#
#
#
#
#  13%|█▎        | 74/567 [00:00<00:02, 238.36frames/s]
#
#
#
#
#  18%|█▊        | 103/567 [00:00<00:01, 249.07frames/s]
#
#
#
#
#  23%|██▎       | 129/567 [00:00<00:01, 249.64frames/s]
#
#
#
#
#  27%|██▋       | 153/567 [00:00<00:01, 244.41frames/s]
#
#
#
#
#  32%|███▏      | 180/567 [00:00<00:01, 251.11frames/s]
#
#
#
#
#  36%|███▋      | 206/567 [00:00<00:01, 252.37frames/s]
#
#
#
#
#  41%|████      | 231/567 [00:00<00:01, 251.37frames/s]
#
#
#
#
#  45%|████▌     | 256/567 [00:01<00:01, 246.94frames/s]
#
#
#
#
#  50%|████▉     | 282/567 [00:01<00:01, 250.41frames/s]
#
#
#
#
#  54%|█████▍    | 307/567 [00:01<00:01, 242.19frames/s]
#
#
#
#
#  59%|█████▊    | 333/567 [00:01<00:00, 245.79frames/s]
#
#
#
#
#  63%|██████▎   | 358/567 [00:01<00:00, 244.74frames/s]
#
#
#
#
#  68%|██████▊   | 384/567 [00:01<00:00, 246.29frames/s]
#
#
#
#
#  72%|███████▏  | 410/567 [00:01<00:00, 248.26frames/s]
#
#
#
#
#  77%|███████▋  | 435/567 [00:01<00:00, 246.48frames/s]
#
#
#
#
#  81%|████████  | 460/567 [00:01<00:00, 243.24frames/s]
#
#
#
#
#  86%|████████▌ | 487/567 [00:01<00:00, 249.26frames/s]
#
#
#
#
#  90%|█████████ | 513/567 [00:02<00:00, 250.58frames/s]
#
#
#
#
#  95%|█████████▌| 539/567 [00:02<00:00, 251.50frames/s]
#
#
#
#
# 100%|██████████| 567/567 [00:02<00:00, 248.65frames/s]
#
#
#
#
#
#   0%|          | 0/567 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1080x1350
#  89%|████████▊ | 503/567 [00:04<00:00, 116.85frame/s]
#
#
#
#
# 100%|██████████| 567/567 [00:05<00:00, 94.67frame/s]
#   0%|          | 0/567 [00:00<?, ?frames/s]
#
#
#
#
#
#   3%|▎         | 15/567 [00:00<00:03, 148.28frames/s]
#
#
#
#
#
#   6%|▌         | 34/567 [00:00<00:03, 158.18frames/s]
#
#
#
#
#
#   9%|▉         | 53/567 [00:00<00:03, 164.76frames/s]
#
#
#
#
#
#  13%|█▎        | 72/567 [00:00<00:02, 171.47frames/s]
#
#
#
#
#
#  16%|█▋        | 93/567 [00:00<00:02, 180.75frames/s]
#
#
#
#
#
#  19%|█▉        | 110/567 [00:00<00:02, 174.82frames/s]
#
#
#
#
#
#  23%|██▎       | 130/567 [00:00<00:02, 181.67frames/s]
#
#
#
#
#
#  26%|██▋       | 149/567 [00:00<00:02, 179.96frames/s]
#
#
#
#
#
#  30%|██▉       | 169/567 [00:00<00:02, 184.24frames/s]
#
#
#
#
#
#  33%|███▎      | 189/567 [00:01<00:02, 186.97frames/s]
#
#
#
#
#
#  37%|███▋      | 210/567 [00:01<00:01, 192.48frames/s]
#
#
#
#
#
#  41%|████      | 230/567 [00:01<00:01, 191.32frames/s]
#
#
#
#
#
#  44%|████▍     | 250/567 [00:01<00:01, 183.80frames/s]
#
#
#
#
#
#  48%|████▊     | 270/567 [00:01<00:01, 186.53frames/s]
#
#
#
#
#
#  51%|█████▏    | 291/567 [00:01<00:01, 190.47frames/s]
#
#
#
#
#
#  55%|█████▍    | 311/567 [00:01<00:01, 187.11frames/s]
#
#
#
#
#
#  58%|█████▊    | 331/567 [00:01<00:01, 189.56frames/s]
#
#
#
#
#
#  62%|██████▏   | 351/567 [00:01<00:01, 191.24frames/s]
#
#
#
#
#
#  65%|██████▌   | 371/567 [00:01<00:01, 188.14frames/s]
#
#
#
#
#
#  69%|██████▉   | 390/567 [00:02<00:00, 186.39frames/s]
#
#
#
#
#
#  72%|███████▏  | 409/567 [00:02<00:00, 184.16frames/s]
#
#
#
#
#
#  75%|███████▌  | 428/567 [00:02<00:00, 182.00frames/s]
#
#
#
#
#
#  79%|███████▉  | 447/567 [00:02<00:00, 180.80frames/s]
#
#
#
#
#
#  83%|████████▎ | 468/567 [00:02<00:00, 187.52frames/s]
#
#
#
#
#
#  86%|████████▌ | 487/567 [00:02<00:00, 186.96frames/s]
#
#
#
#
#
#  89%|████████▉ | 507/567 [00:02<00:00, 190.45frames/s]
#
#
#
#
#
#  93%|█████████▎| 527/567 [00:02<00:00, 192.57frames/s]
#
#
#
#
#
#  96%|█████████▋| 547/567 [00:02<00:00, 193.50frames/s]
#
#
#
#
#
# 100%|██████████| 567/567 [00:03<00:00, 187.24frames/s]
#
#
#
#
#
#
#   0%|          | 0/567 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1080x1920
#  89%|████████▉ | 505/567 [00:05<00:00, 88.08frame/s]
#
#
#
#
#
# 100%|██████████| 567/567 [00:06<00:00, 72.67frame/s]
#   0%|          | 0/567 [00:00<?, ?frames/s]
#
#
#
#
#
#
#   5%|▍         | 27/567 [00:00<00:02, 263.33frames/s]
#
#
#
#
#
#
#  10%|█         | 59/567 [00:00<00:01, 278.05frames/s]
#
#
#
#
#
#
#  16%|█▌        | 92/567 [00:00<00:01, 289.76frames/s]
#
#
#
#
#
#
#  22%|██▏       | 125/567 [00:00<00:01, 300.27frames/s]
#
#
#
#
#
#
#  27%|██▋       | 155/567 [00:00<00:01, 300.11frames/s]
#
#
#
#
#
#
#  33%|███▎      | 187/567 [00:00<00:01, 303.26frames/s]
#
#
#
#
#
#
#  39%|███▉      | 221/567 [00:00<00:01, 312.46frames/s]
#
#
#
#
#
#
#  45%|████▍     | 254/567 [00:00<00:00, 315.54frames/s]
#
#
#
#
#
#
#  51%|█████     | 287/567 [00:00<00:00, 318.83frames/s]
#
#
#
#
#
#
#  56%|█████▌    | 318/567 [00:01<00:00, 311.49frames/s]
#
#
#
#
#
#
#  62%|██████▏   | 351/567 [00:01<00:00, 315.23frames/s]
#
#
#
#
#
#
#  68%|██████▊   | 383/567 [00:01<00:00, 298.81frames/s]
#
#
#
#
#
#
#  73%|███████▎  | 414/567 [00:01<00:00, 299.76frames/s]
#
#
#
#
#
#
#  78%|███████▊  | 444/567 [00:01<00:00, 291.57frames/s]
#
#
#
#
#
#
#  84%|████████▎ | 474/567 [00:01<00:00, 289.59frames/s]
#
#
#
#
#
#
#  89%|████████▉ | 506/567 [00:01<00:00, 296.59frames/s]
#
#
#
#
#
#
# 100%|██████████| 567/567 [00:01<00:00, 306.10frames/s]
#
#
#
#
#
#
#
#   0%|          | 0/567 [00:00<?, ?frame/s]
# /content/gdrive/My Drive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/My Drive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1920x1080
#  89%|████████▉ | 504/567 [00:05<00:00, 91.23frame/s]
#
#
#
#
#
#
# 100%|██████████| 567/567 [00:06<00:00, 75.99frame/s]
#   0%|          | 0/400 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#  11%|█         | 44/400 [00:00<00:00, 434.21frames/s]
#
#
#
#
#
#
#
#  24%|██▎       | 94/400 [00:00<00:00, 450.65frames/s]
#
#
#
#
#
#
#
#  36%|███▋      | 145/400 [00:00<00:00, 465.91frames/s]
#
#
#
#
#
#
#
#  48%|████▊     | 193/400 [00:00<00:00, 468.15frames/s]
#
#
#
#
#
#
#
#  62%|██████▏   | 246/400 [00:00<00:00, 484.22frames/s]
#
#
#
#
#
#
#
#  74%|███████▍  | 296/400 [00:00<00:00, 487.39frames/s]
#
#
#
#
#
#
#
#  85%|████████▌ | 340/400 [00:00<00:00, 467.45frames/s]
#
#
#
#
#
#
#
# 100%|██████████| 400/400 [00:00<00:00, 477.07frames/s]
#
#
#
#
#
#
#
#
#   0%|          | 0/400 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1080
# 100%|██████████| 400/400 [00:02<00:00, 188.61frame/s]
#   0%|          | 0/400 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#   4%|▍         | 15/400 [00:00<00:04, 88.64frames/s]
#
#
#
#
#
#
#
#  10%|█         | 41/400 [00:00<00:03, 110.35frames/s]
#
#
#
#
#
#
#
#  18%|█▊        | 70/400 [00:00<00:02, 135.05frames/s]
#
#
#
#
#
#
#
#  24%|██▍       | 98/400 [00:00<00:01, 159.32frames/s]
#
#
#
#
#
#
#
#  31%|███▏      | 125/400 [00:00<00:01, 181.64frames/s]
#
#
#
#
#
#
#
#  38%|███▊      | 151/400 [00:00<00:01, 197.93frames/s]
#
#
#
#
#
#
#
#  45%|████▍     | 179/400 [00:00<00:01, 216.71frames/s]
#
#
#
#
#
#
#
#  52%|█████▏    | 208/400 [00:00<00:00, 233.36frames/s]
#
#
#
#
#
#
#
#  59%|█████▉    | 236/400 [00:00<00:00, 243.96frames/s]
#
#
#
#
#
#
#
#  66%|██████▋   | 265/400 [00:01<00:00, 255.08frames/s]
#
#
#
#
#
#
#
#  73%|███████▎  | 292/400 [00:01<00:00, 257.61frames/s]
#
#
#
#
#
#
#
#  80%|███████▉  | 319/400 [00:01<00:00, 259.29frames/s]
#
#
#
#
#
#
#
#  87%|████████▋ | 347/400 [00:01<00:00, 264.44frames/s]
#
#
#
#
#
#
#
# 100%|██████████| 400/400 [00:01<00:00, 253.45frames/s]
#
#
#
#
#
#
#
#
#   0%|          | 0/400 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350
# 100%|██████████| 400/400 [00:03<00:00, 123.38frame/s]
#   0%|          | 0/400 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#   3%|▎         | 13/400 [00:00<00:03, 128.12frames/s]
#
#
#
#
#
#
#
#
#   8%|▊         | 31/400 [00:00<00:02, 140.01frames/s]
#
#
#
#
#
#
#
#
#  12%|█▎        | 50/400 [00:00<00:02, 151.92frames/s]
#
#
#
#
#
#
#
#
#  18%|█▊        | 70/400 [00:00<00:02, 161.93frames/s]
#
#
#
#
#
#
#
#
#  22%|██▏       | 88/400 [00:00<00:01, 166.05frames/s]
#
#
#
#
#
#
#
#
#  26%|██▋       | 106/400 [00:00<00:01, 169.17frames/s]
#
#
#
#
#
#
#
#
#  31%|███       | 124/400 [00:00<00:01, 170.11frames/s]
#
#
#
#
#
#
#
#
#  36%|███▌      | 143/400 [00:00<00:01, 174.03frames/s]
#
#
#
#
#
#
#
#
#  40%|████      | 160/400 [00:00<00:01, 164.68frames/s]
#
#
#
#
#
#
#
#
#  44%|████▍     | 178/400 [00:01<00:01, 168.18frames/s]
#
#
#
#
#
#
#
#
#  49%|████▉     | 196/400 [00:01<00:01, 169.62frames/s]
#
#
#
#
#
#
#
#
#  54%|█████▍    | 215/400 [00:01<00:01, 174.42frames/s]
#
#
#
#
#
#
#
#
#  58%|█████▊    | 234/400 [00:01<00:00, 178.16frames/s]
#
#
#
#
#
#
#
#
#  63%|██████▎   | 253/400 [00:01<00:00, 179.25frames/s]
#
#
#
#
#
#
#
#
#  68%|██████▊   | 271/400 [00:01<00:00, 177.08frames/s]
#
#
#
#
#
#
#
#
#  72%|███████▏  | 289/400 [00:01<00:00, 172.74frames/s]
#
#
#
#
#
#
#
#
#  77%|███████▋  | 307/400 [00:01<00:00, 169.83frames/s]
#
#
#
#
#
#
#
#
#  81%|████████▏ | 325/400 [00:01<00:00, 172.18frames/s]
#
#
#
#
#
#
#
#
#  86%|████████▌ | 343/400 [00:01<00:00, 172.05frames/s]
#
#
#
#
#
#
#
#
#  90%|█████████ | 361/400 [00:02<00:00, 172.77frames/s]
#
#
#
#
#
#
#
#
#  95%|█████████▌| 380/400 [00:02<00:00, 175.48frames/s]
#
#
#
#
#
#
#
#
# 100%|██████████| 400/400 [00:02<00:00, 172.86frames/s]
#
#
#
#
#
#
#
#
#
#   0%|          | 0/400 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1920
# 100%|██████████| 400/400 [00:05<00:00, 78.02frame/s]
#   0%|          | 0/400 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#   5%|▌         | 20/400 [00:00<00:01, 199.84frames/s]
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 49/400 [00:00<00:01, 219.42frames/s]
#
#
#
#
#
#
#
#
#
#  20%|█▉        | 79/400 [00:00<00:01, 238.47frames/s]
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 109/400 [00:00<00:01, 253.66frames/s]
#
#
#
#
#
#
#
#
#
#  35%|███▍      | 139/400 [00:00<00:00, 265.33frames/s]
#
#
#
#
#
#
#
#
#
#  41%|████      | 163/400 [00:00<00:00, 251.15frames/s]
#
#
#
#
#
#
#
#
#
#  49%|████▉     | 197/400 [00:00<00:00, 270.83frames/s]
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 229/400 [00:00<00:00, 282.34frames/s]
#
#
#
#
#
#
#
#
#
#  65%|██████▌   | 260/400 [00:00<00:00, 288.11frames/s]
#
#
#
#
#
#
#
#
#
#  72%|███████▏  | 289/400 [00:01<00:00, 286.29frames/s]
#
#
#
#
#
#
#
#
#
#  80%|███████▉  | 318/400 [00:01<00:00, 286.89frames/s]
#
#
#
#
#
#
#
#
#
#  87%|████████▋ | 348/400 [00:01<00:00, 290.62frames/s]
#
#
#
#
#
#
#
#
#
# 100%|██████████| 400/400 [00:01<00:00, 286.85frames/s]
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/400 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1920x1080
#  85%|████████▌ | 341/400 [00:03<00:00, 90.16frame/s]
#
#
#
#
#
#
#
#
#
# 100%|██████████| 400/400 [00:04<00:00, 73.17frame/s]
#   0%|          | 0/532 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#   9%|▊         | 46/532 [00:00<00:01, 452.10frames/s]
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 90/532 [00:00<00:00, 448.09frames/s]
#
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 132/532 [00:00<00:00, 436.24frames/s]
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 178/532 [00:00<00:00, 442.35frames/s]
#
#
#
#
#
#
#
#
#
#
#  43%|████▎     | 227/532 [00:00<00:00, 453.36frames/s]
#
#
#
#
#
#
#
#
#
#
#  50%|█████     | 268/532 [00:00<00:00, 437.68frames/s]
#
#
#
#
#
#
#
#
#
#
#  59%|█████▉    | 314/532 [00:00<00:00, 442.49frames/s]
#
#
#
#
#
#
#
#
#
#
#  67%|██████▋   | 357/532 [00:00<00:00, 435.55frames/s]
#
#
#
#
#
#
#
#
#
#
#  75%|███████▌  | 399/532 [00:00<00:00, 429.54frames/s]
#
#
#
#
#
#
#
#
#
#
#  83%|████████▎ | 442/532 [00:01<00:00, 429.03frames/s]
#
#
#
#
#
#
#
#
#
#
#  91%|█████████▏| 486/532 [00:01<00:00, 430.90frames/s]
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 532/532 [00:01<00:00, 435.29frames/s]
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/532 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080
#  10%|▉         | 52/532 [00:00<00:04, 103.26frame/s]
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 138/532 [00:01<00:03, 109.68frame/s]
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 224/532 [00:02<00:02, 104.02frame/s]
#
#
#
#
#
#
#
#
#
#
#  54%|█████▍    | 289/532 [00:03<00:02, 88.46frame/s]
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 362/532 [00:03<00:01, 90.48frame/s]
#
#
#
#
#
#
#
#
#
#
#  82%|████████▏ | 437/532 [00:04<00:01, 85.44frame/s]
#
#
#
#
#
#
#
#
#
#
#  89%|████████▊ | 471/532 [00:05<00:00, 77.08frame/s]
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 532/532 [00:06<00:00, 82.75frame/s]
#   0%|          | 0/357 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 22/357 [00:00<00:01, 213.92frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▎        | 49/357 [00:00<00:01, 226.01frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 77/357 [00:00<00:01, 238.64frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 105/357 [00:00<00:01, 248.17frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 133/357 [00:00<00:00, 255.63frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  44%|████▍     | 157/357 [00:00<00:00, 248.79frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  52%|█████▏    | 184/357 [00:00<00:00, 254.55frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  59%|█████▊    | 209/357 [00:00<00:00, 250.62frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  66%|██████▌   | 235/357 [00:00<00:00, 253.03frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 263/357 [00:01<00:00, 259.18frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  81%|████████  | 289/357 [00:01<00:00, 254.61frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  88%|████████▊ | 315/357 [00:01<00:00, 250.41frames/s]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 357/357 [00:01<00:00, 256.56frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/357 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350
#  40%|████      | 143/357 [00:01<00:02, 82.44frame/s]
#
#
#
#
#
#
#
#
#
#
#
#  51%|█████     | 181/357 [00:02<00:03, 56.40frame/s]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 207/357 [00:03<00:02, 53.84frame/s]
#
#
#
#
#
#
#
#
#
#
#
#  75%|███████▌  | 268/357 [00:04<00:01, 55.22frame/s]
#
#
#
#
#
#
#
#
#
#
#
#  81%|████████  | 288/357 [00:05<00:01, 44.17frame/s]
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 324/357 [00:06<00:00, 41.05frame/s]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 357/357 [00:06<00:00, 43.03frame/s]
#   0%|          | 0/150 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 26/150 [00:00<00:00, 255.29frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#  39%|███▊      | 58/150 [00:00<00:00, 270.18frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#  59%|█████▉    | 89/150 [00:00<00:00, 280.95frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 150/150 [00:00<00:00, 303.93frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/150 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-17-TSB21_YOU_NOT_MUTED_1920x1080
#  71%|███████▏  | 107/150 [00:01<00:00, 62.04frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 150/150 [00:02<00:00, 57.79frame/s]
#   0%|          | 0/357 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▋         | 23/357 [00:00<00:01, 219.65frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 47/357 [00:00<00:01, 224.25frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|██        | 73/357 [00:00<00:01, 232.26frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▊       | 102/357 [00:00<00:01, 246.93frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 129/357 [00:00<00:00, 252.86frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  43%|████▎     | 153/357 [00:00<00:00, 247.46frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  50%|█████     | 179/357 [00:00<00:00, 248.60frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 205/357 [00:00<00:00, 251.77frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  65%|██████▌   | 233/357 [00:00<00:00, 259.04frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  73%|███████▎  | 261/357 [00:01<00:00, 263.51frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  80%|████████  | 287/357 [00:01<00:00, 262.37frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  88%|████████▊ | 313/357 [00:01<00:00, 259.89frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 357/357 [00:01<00:00, 258.49frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/357 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350
#  40%|████      | 143/357 [00:01<00:02, 81.77frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  51%|█████     | 181/357 [00:02<00:03, 56.51frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 207/357 [00:03<00:02, 53.91frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  75%|███████▌  | 268/357 [00:04<00:01, 55.30frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  81%|████████  | 288/357 [00:05<00:01, 44.50frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 324/357 [00:06<00:00, 42.59frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 357/357 [00:06<00:00, 44.39frame/s]
#   0%|          | 0/347 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 25/347 [00:00<00:01, 245.59frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 54/347 [00:00<00:01, 257.40frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 83/347 [00:00<00:00, 264.90frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 111/347 [00:00<00:00, 269.19frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  40%|███▉      | 138/347 [00:00<00:00, 267.35frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  48%|████▊     | 166/347 [00:00<00:00, 270.41frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  56%|█████▌    | 195/347 [00:00<00:00, 275.76frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  65%|██████▍   | 225/347 [00:00<00:00, 280.18frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  73%|███████▎  | 254/347 [00:00<00:00, 280.53frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  81%|████████▏ | 282/347 [00:01<00:00, 274.26frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|████████▉ | 311/347 [00:01<00:00, 275.20frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 347/347 [00:01<00:00, 275.44frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/347 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350
#  39%|███▊      | 134/347 [00:01<00:02, 81.18frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 197/347 [00:02<00:02, 71.23frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▍  | 258/347 [00:03<00:01, 65.87frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  80%|████████  | 278/347 [00:04<00:01, 48.60frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|█████████ | 314/347 [00:05<00:00, 44.61frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 347/347 [00:06<00:00, 44.39frame/s]
#   0%|          | 0/151 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▌        | 23/151 [00:00<00:00, 222.68frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|███       | 46/151 [00:00<00:00, 223.52frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  50%|█████     | 76/151 [00:00<00:00, 241.96frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  69%|██████▉   | 104/151 [00:00<00:00, 250.88frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 151/151 [00:00<00:00, 265.01frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/151 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_21_TSB21_3HITS_ACUNA_1920x1080_5s
#  51%|█████     | 77/151 [00:01<00:01, 49.99frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  83%|████████▎ | 125/151 [00:03<00:00, 42.52frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 151/151 [00:03<00:00, 38.32frame/s]
#   0%|          | 0/437 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|▉         | 43/437 [00:00<00:00, 422.99frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 85/437 [00:00<00:00, 421.18frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 126/437 [00:00<00:00, 416.33frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 166/437 [00:00<00:00, 408.96frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 205/437 [00:00<00:00, 402.99frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 247/437 [00:00<00:00, 406.46frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  66%|██████▌   | 288/437 [00:00<00:00, 407.25frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  75%|███████▍  | 327/437 [00:00<00:00, 400.74frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  85%|████████▍ | 370/437 [00:00<00:00, 406.98frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 437/437 [00:01<00:00, 408.89frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/437 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080
#  13%|█▎        | 55/437 [00:00<00:03, 107.61frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▊        | 81/437 [00:01<00:04, 73.25frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 160/437 [00:02<00:03, 70.84frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  41%|████      | 178/437 [00:02<00:04, 60.52frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 204/437 [00:03<00:04, 54.52frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  52%|█████▏    | 228/437 [00:03<00:04, 51.49frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 437/437 [00:06<00:00, 59.34frame/s]
#   0%|          | 0/437 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 24/437 [00:00<00:01, 236.22frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 51/437 [00:00<00:01, 244.96frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 76/437 [00:00<00:01, 245.25frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 102/437 [00:00<00:01, 247.46frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|██▉       | 129/437 [00:00<00:01, 251.89frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▌      | 154/437 [00:00<00:01, 250.22frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  41%|████      | 179/437 [00:00<00:01, 248.23frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 205/437 [00:00<00:00, 250.00frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 231/437 [00:00<00:00, 251.99frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  59%|█████▊    | 256/437 [00:01<00:00, 247.07frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  65%|██████▍   | 283/437 [00:01<00:00, 252.25frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  70%|███████   | 308/437 [00:01<00:00, 248.73frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  76%|███████▋  | 334/437 [00:01<00:00, 250.01frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  82%|████████▏ | 360/437 [00:01<00:00, 252.27frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 388/437 [00:01<00:00, 258.23frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 437/437 [00:01<00:00, 255.56frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/437 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350
#  13%|█▎        | 55/437 [00:00<00:04, 83.03frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▊        | 81/437 [00:01<00:06, 56.03frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 160/437 [00:03<00:05, 53.84frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  41%|████      | 178/437 [00:03<00:05, 47.78frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 204/437 [00:04<00:05, 42.27frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  52%|█████▏    | 228/437 [00:04<00:04, 43.04frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 437/437 [00:07<00:00, 55.51frame/s]
#   0%|          | 0/437 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 15/437 [00:00<00:02, 146.81frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 33/437 [00:00<00:02, 154.65frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 51/437 [00:00<00:02, 160.17frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 68/437 [00:00<00:02, 162.54frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|█▉        | 87/437 [00:00<00:02, 167.85frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 105/437 [00:00<00:01, 170.80frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 123/437 [00:00<00:01, 172.03frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 142/437 [00:00<00:01, 174.55frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▋      | 159/437 [00:00<00:01, 171.23frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  41%|████      | 177/437 [00:01<00:01, 172.29frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  45%|████▍     | 195/437 [00:01<00:01, 171.67frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  49%|████▉     | 214/437 [00:01<00:01, 175.65frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  54%|█████▎    | 234/437 [00:01<00:01, 181.20frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 253/437 [00:01<00:01, 177.31frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 274/437 [00:01<00:00, 183.95frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  67%|██████▋   | 293/437 [00:01<00:00, 185.34frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  71%|███████▏  | 312/437 [00:01<00:00, 181.99frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  76%|███████▌  | 331/437 [00:01<00:00, 184.23frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  81%|████████  | 352/437 [00:01<00:00, 188.84frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  85%|████████▍ | 371/437 [00:02<00:00, 186.92frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 391/437 [00:02<00:00, 189.95frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▍| 411/437 [00:02<00:00, 192.32frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 437/437 [00:02<00:00, 180.67frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/437 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920
#  13%|█▎        | 55/437 [00:00<00:06, 60.26frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▊        | 81/437 [00:02<00:08, 41.06frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 160/437 [00:04<00:07, 39.28frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  41%|████      | 178/437 [00:04<00:07, 36.12frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 204/437 [00:05<00:07, 32.53frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  52%|█████▏    | 228/437 [00:06<00:06, 33.68frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 437/437 [00:10<00:00, 37.41frame/s]
#   0%|          | 0/437 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 25/437 [00:00<00:01, 243.48frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 53/437 [00:00<00:01, 252.46frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▊        | 81/437 [00:00<00:01, 259.19frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 108/437 [00:00<00:01, 260.24frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 138/437 [00:00<00:01, 269.32frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 161/437 [00:00<00:01, 253.97frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  43%|████▎     | 189/437 [00:00<00:00, 259.63frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  50%|████▉     | 218/437 [00:00<00:00, 267.79frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 247/437 [00:00<00:00, 272.32frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 276/437 [00:01<00:00, 277.04frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  70%|██████▉   | 304/437 [00:01<00:00, 272.44frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  76%|███████▋  | 334/437 [00:01<00:00, 278.97frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▎ | 365/437 [00:01<00:00, 286.67frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 397/437 [00:01<00:00, 293.52frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 437/437 [00:01<00:00, 280.93frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/437 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080
#  13%|█▎        | 55/437 [00:00<00:05, 66.51frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▊        | 81/437 [00:01<00:08, 43.79frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 160/437 [00:04<00:06, 41.22frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  41%|████      | 178/437 [00:04<00:06, 37.87frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 204/437 [00:05<00:07, 32.92frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  52%|█████▏    | 228/437 [00:06<00:06, 31.54frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  86%|████████▋ | 378/437 [00:10<00:01, 33.66frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 437/437 [00:11<00:00, 37.03frame/s]
#   0%|          | 0/453 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 43/453 [00:00<00:00, 422.31frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 85/453 [00:00<00:00, 420.03frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 128/453 [00:00<00:00, 420.84frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 169/453 [00:00<00:00, 416.86frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  46%|████▌     | 208/453 [00:00<00:00, 406.10frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  56%|█████▌    | 252/453 [00:00<00:00, 414.26frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  65%|██████▍   | 294/453 [00:00<00:00, 415.69frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 334/453 [00:00<00:00, 408.62frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  83%|████████▎ | 376/453 [00:00<00:00, 410.27frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 453/453 [00:01<00:00, 414.88frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/453 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1080
#  38%|███▊      | 171/453 [00:01<00:02, 107.13frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 211/453 [00:02<00:02, 82.60frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 257/453 [00:02<00:02, 83.86frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 453/453 [00:04<00:00, 87.09frame/s]
#   0%|          | 0/453 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 12/453 [00:00<00:06, 70.68frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 35/453 [00:00<00:04, 89.05frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 58/453 [00:00<00:03, 108.51frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 82/453 [00:00<00:02, 129.05frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▎       | 107/453 [00:00<00:02, 150.69frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 132/453 [00:00<00:01, 170.56frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 154/453 [00:00<00:01, 181.82frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  39%|███▉      | 177/453 [00:00<00:01, 193.45frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  45%|████▍     | 203/453 [00:00<00:01, 209.30frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  50%|█████     | 228/453 [00:01<00:01, 219.39frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  56%|█████▌    | 254/453 [00:01<00:00, 227.23frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  61%|██████▏   | 278/453 [00:01<00:00, 230.59frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  67%|██████▋   | 303/453 [00:01<00:00, 234.28frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  72%|███████▏  | 327/453 [00:01<00:00, 234.54frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  78%|███████▊  | 352/453 [00:01<00:00, 237.73frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  83%|████████▎ | 377/453 [00:01<00:00, 237.06frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▊ | 401/453 [00:01<00:00, 237.72frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 453/453 [00:02<00:00, 225.56frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/453 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1350
#  38%|███▊      | 171/453 [00:02<00:04, 64.45frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 211/453 [00:03<00:04, 50.47frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 257/453 [00:04<00:03, 52.60frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 453/453 [00:07<00:00, 56.03frame/s]
#   0%|          | 0/453 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 15/453 [00:00<00:03, 144.36frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 35/453 [00:00<00:02, 156.00frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█▏        | 52/453 [00:00<00:02, 159.79frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▍        | 66/453 [00:00<00:02, 151.62frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▊        | 84/453 [00:00<00:02, 157.27frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 103/453 [00:00<00:02, 164.58frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 122/453 [00:00<00:01, 170.71frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 140/453 [00:00<00:01, 171.60frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▍      | 157/453 [00:00<00:01, 167.35frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  39%|███▉      | 176/453 [00:01<00:01, 171.48frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  43%|████▎     | 195/453 [00:01<00:01, 175.86frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 213/453 [00:01<00:01, 175.20frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  51%|█████     | 232/453 [00:01<00:01, 178.13frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  55%|█████▌    | 251/453 [00:01<00:01, 181.25frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  60%|█████▉    | 270/453 [00:01<00:01, 179.37frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  64%|██████▎   | 288/453 [00:01<00:00, 178.05frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 306/453 [00:01<00:00, 174.84frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  72%|███████▏  | 325/453 [00:01<00:00, 176.90frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  76%|███████▌  | 345/453 [00:01<00:00, 182.06frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  80%|████████  | 364/453 [00:02<00:00, 183.75frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  85%|████████▍ | 384/453 [00:02<00:00, 186.74frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 403/453 [00:02<00:00, 184.46frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 422/453 [00:02<00:00, 185.45frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 453/453 [00:02<00:00, 177.82frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/453 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920
#  21%|██        | 96/453 [00:01<00:07, 49.66frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 171/453 [00:03<00:06, 46.56frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 211/453 [00:05<00:06, 39.37frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 257/453 [00:06<00:04, 41.99frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 453/453 [00:10<00:00, 43.99frame/s]
#   0%|          | 0/96 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 15/96 [00:00<00:00, 149.18frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 33/96 [00:00<00:00, 156.98frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 51/96 [00:00<00:00, 162.51frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  72%|███████▏  | 69/96 [00:00<00:00, 166.27frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 96/96 [00:00<00:00, 171.93frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/96 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_1
# 100%|██████████| 96/96 [00:01<00:00, 49.70frame/s]
#   0%|          | 0/115 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 15/115 [00:00<00:00, 149.48frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|███       | 35/115 [00:00<00:00, 161.28frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  46%|████▌     | 53/115 [00:00<00:00, 165.96frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  61%|██████    | 70/115 [00:00<00:00, 164.88frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  75%|███████▍  | 86/115 [00:00<00:00, 161.96frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 115/115 [00:00<00:00, 171.18frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/115 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_2
#  65%|██████▌   | 75/115 [00:01<00:00, 44.65frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 115/115 [00:03<00:00, 36.17frame/s]
#   0%|          | 0/102 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▍        | 15/102 [00:00<00:00, 146.32frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 35/102 [00:00<00:00, 157.93frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  51%|█████     | 52/102 [00:00<00:00, 161.24frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  69%|██████▊   | 70/102 [00:00<00:00, 164.82frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 102/102 [00:00<00:00, 173.78frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/102 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_3
#  45%|████▌     | 46/102 [00:00<00:00, 62.94frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 102/102 [00:02<00:00, 41.47frame/s]
#   0%|          | 0/151 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|▉         | 15/151 [00:00<00:00, 143.33frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 31/151 [00:00<00:00, 146.02frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 49/151 [00:00<00:00, 154.48frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  44%|████▎     | 66/151 [00:00<00:00, 158.73frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  56%|█████▌    | 84/151 [00:00<00:00, 163.90frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  66%|██████▌   | 100/151 [00:00<00:00, 162.58frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  77%|███████▋  | 117/151 [00:00<00:00, 163.75frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 151/151 [00:00<00:00, 166.18frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/151 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_4
# 100%|██████████| 151/151 [00:02<00:00, 51.84frame/s]
#   0%|          | 0/453 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 23/453 [00:00<00:01, 223.55frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|█         | 47/453 [00:00<00:01, 225.94frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▌        | 70/453 [00:00<00:01, 225.06frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██▏       | 97/453 [00:00<00:01, 235.77frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 127/453 [00:00<00:01, 250.68frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 151/453 [00:00<00:01, 245.88frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  39%|███▊      | 175/453 [00:00<00:01, 243.90frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  45%|████▍     | 202/453 [00:00<00:01, 249.80frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  51%|█████     | 229/453 [00:00<00:00, 253.25frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 256/453 [00:01<00:00, 257.28frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  62%|██████▏   | 282/453 [00:01<00:00, 257.55frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 308/453 [00:01<00:00, 258.04frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▍  | 335/453 [00:01<00:00, 260.41frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  81%|████████  | 368/453 [00:01<00:00, 277.18frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  87%|████████▋ | 396/453 [00:01<00:00, 276.10frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 453/453 [00:01<00:00, 263.50frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/453 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080
#  38%|███▊      | 171/453 [00:03<00:05, 49.98frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 211/453 [00:04<00:06, 40.32frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 257/453 [00:05<00:04, 42.73frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  87%|████████▋ | 395/453 [00:09<00:01, 42.08frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 453/453 [00:10<00:00, 43.26frame/s]
#   0%|          | 0/483 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 41/483 [00:00<00:01, 407.39frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 84/483 [00:00<00:00, 412.01frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 130/483 [00:00<00:00, 423.81frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 174/483 [00:00<00:00, 425.57frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  46%|████▌     | 220/483 [00:00<00:00, 434.27frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  56%|█████▌    | 270/483 [00:00<00:00, 450.60frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  65%|██████▌   | 316/483 [00:00<00:00, 450.35frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  75%|███████▍  | 361/483 [00:00<00:00, 449.55frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 407/483 [00:00<00:00, 451.45frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 483/483 [00:01<00:00, 449.98frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/483 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080
#  18%|█▊        | 89/483 [00:00<00:03, 104.66frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  41%|████▏     | 200/483 [00:02<00:02, 100.32frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  49%|████▉     | 237/483 [00:02<00:02, 94.59frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  80%|███████▉  | 386/483 [00:04<00:01, 86.41frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  87%|████████▋ | 420/483 [00:05<00:00, 77.25frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 483/483 [00:05<00:00, 81.39frame/s]
#   0%|          | 0/483 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 11/483 [00:00<00:08, 57.91frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 35/483 [00:00<00:05, 74.73frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 58/483 [00:00<00:04, 93.44frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 81/483 [00:00<00:03, 112.93frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 106/483 [00:00<00:02, 134.98frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 134/483 [00:00<00:02, 159.20frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▎      | 142/421 [00:02<00:04, 61.55frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 162/421 [00:02<00:04, 54.89frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  48%|████▊     | 203/421 [00:03<00:04, 54.01frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  64%|██████▍   | 271/421 [00:04<00:02, 58.14frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 332/421 [00:05<00:01, 60.28frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▎ | 352/421 [00:05<00:01, 54.11frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  92%|█████████▏| 388/421 [00:06<00:00, 54.67frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 421/421 [00:07<00:00, 54.14frame/s]
#   0%|          | 0/363 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 34/363 [00:00<00:00, 336.84frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 76/363 [00:00<00:00, 357.19frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███▏      | 114/363 [00:00<00:00, 362.95frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  41%|████▏     | 150/363 [00:00<00:00, 361.06frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  52%|█████▏    | 190/363 [00:00<00:00, 370.30frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  64%|██████▎   | 231/363 [00:00<00:00, 378.37frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  75%|███████▍  | 272/363 [00:00<00:00, 386.87frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  85%|████████▌ | 309/363 [00:00<00:00, 365.11frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 363/363 [00:00<00:00, 374.88frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/363 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080
#  13%|█▎        | 48/363 [00:00<00:04, 71.75frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 85/363 [00:01<00:03, 72.97frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  40%|████      | 147/363 [00:02<00:03, 71.60frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  59%|█████▊    | 213/363 [00:03<00:02, 70.75frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  75%|███████▌  | 274/363 [00:03<00:01, 72.51frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  81%|████████  | 294/363 [00:04<00:01, 58.47frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 330/363 [00:05<00:00, 55.92frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 363/363 [00:05<00:00, 65.84frame/s]
#   0%|          | 0/363 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 34/363 [00:00<00:00, 337.52frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|██        | 73/363 [00:00<00:00, 351.58frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 113/363 [00:00<00:00, 362.92frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  43%|████▎     | 155/363 [00:00<00:00, 375.62frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 194/363 [00:00<00:00, 377.75frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  65%|██████▌   | 236/363 [00:00<00:00, 387.53frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  76%|███████▋  | 277/363 [00:00<00:00, 393.80frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  87%|████████▋ | 317/363 [00:00<00:00, 394.11frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 363/363 [00:00<00:00, 395.88frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/363 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080
#  13%|█▎        | 48/363 [00:00<00:04, 71.31frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 84/363 [00:01<00:04, 68.48frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  40%|████      | 147/363 [00:02<00:03, 67.91frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  59%|█████▊    | 213/363 [00:03<00:02, 67.39frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  75%|███████▌  | 274/363 [00:04<00:01, 69.20frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  81%|████████  | 294/363 [00:04<00:01, 57.21frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 330/363 [00:05<00:00, 54.50frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 363/363 [00:05<00:00, 63.00frame/s]
#   0%|          | 0/601 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 41/601 [00:00<00:01, 408.97frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 80/601 [00:00<00:01, 402.26frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|█▉        | 119/601 [00:00<00:01, 395.75frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 157/601 [00:00<00:01, 389.32frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 195/601 [00:00<00:01, 386.45frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  40%|███▉      | 238/601 [00:00<00:00, 397.19frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 281/601 [00:00<00:00, 404.86frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  54%|█████▎    | 322/601 [00:00<00:00, 405.34frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  61%|██████    | 366/601 [00:00<00:00, 414.00frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 411/601 [00:01<00:00, 423.39frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  75%|███████▌  | 453/601 [00:01<00:00, 419.71frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  82%|████████▏ | 495/601 [00:01<00:00, 413.71frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 537/601 [00:01<00:00, 413.71frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 601/601 [00:01<00:00, 412.30frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/601 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080
#   6%|▋         | 39/601 [00:00<00:07, 72.77frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|▉         | 60/601 [00:00<00:08, 62.94frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▍        | 88/601 [00:01<00:08, 61.79frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 150/601 [00:02<00:06, 67.36frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 199/601 [00:02<00:06, 66.26frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  44%|████▍     | 266/601 [00:03<00:04, 72.38frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  78%|███████▊  | 466/601 [00:05<00:01, 84.33frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 504/601 [00:05<00:01, 75.72frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  90%|████████▉ | 538/601 [00:06<00:00, 73.35frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 601/601 [00:06<00:00, 86.50frame/s]
#   0%|          | 0/481 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 43/481 [00:00<00:01, 427.66frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▋        | 79/481 [00:00<00:00, 402.78frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 117/481 [00:00<00:00, 395.17frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 159/481 [00:00<00:00, 401.02frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  41%|████      | 196/481 [00:00<00:00, 389.99frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  49%|████▉     | 235/481 [00:00<00:00, 389.08frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 278/481 [00:00<00:00, 398.68frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  66%|██████▋   | 319/481 [00:00<00:00, 400.72frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  75%|███████▍  | 360/481 [00:00<00:00, 402.47frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 403/481 [00:01<00:00, 409.17frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 481/481 [00:01<00:00, 402.23frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/481 [00:00<?, ?frame/s]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080
#  10%|█         | 50/481 [00:00<00:03, 119.87frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 92/481 [00:01<00:04, 90.97frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 119/481 [00:01<00:05, 71.37frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 157/481 [00:02<00:04, 66.16frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  52%|█████▏    | 248/481 [00:03<00:03, 76.50frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  56%|█████▋    | 271/481 [00:03<00:03, 69.03frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  60%|██████    | 291/481 [00:04<00:03, 57.95frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  80%|███████▉  | 384/481 [00:05<00:01, 64.51frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  87%|████████▋ | 418/481 [00:05<00:00, 64.43frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 481/481 [00:06<00:00, 69.50frame/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py in ffmpeg_parse_infos(filename, print_infos, check_duration, fps_source)
#     284             index = -1 if is_GIF else 0
# --> 285             line = [l for l in lines if keyword in l][index]
#     286             match = re.findall("([0-9][0-9]:[0-9][0-9]:[0-9][0-9].[0-9][0-9])", line)[0]
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-30-a33e6e941fc3> in <module>()
#       3     video_path = video
#       4     #function to check the length of the videos and assign dynamic threshold
# ----> 5     thres = check_video_threshold(video_path)
#       6
#       7
#
# <ipython-input-26-ed180ed9aa6e> in check_video_threshold(video_path)
#       1 def check_video_threshold(video_path):
#       2   # Create an object by passing the location as a string
# ----> 3   video_len = VideoFileClip(video_path)
#       4
#       5   # getting duration of the video
#
# /usr/local/lib/python3.7/dist-packages/moviepy/video/io/VideoFileClip.py in __init__(self, filename, has_mask, audio, audio_buffersize, target_resolution, resize_algorithm, audio_fps, audio_nbytes, verbose, fps_source)
#      89                                          target_resolution=target_resolution,
#      90                                          resize_algo=resize_algorithm,
# ---> 91                                          fps_source=fps_source)
#      92
#      93         # Make some of the reader's attributes accessible from the clip
#
# /usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py in __init__(self, filename, print_infos, bufsize, pix_fmt, check_duration, target_resolution, resize_algo, fps_source)
#      31         self.proc = None
#      32         infos = ffmpeg_parse_infos(filename, print_infos, check_duration,
# ---> 33                                    fps_source)
#      34         self.fps = infos['video_fps']
#      35         self.size = infos['video_size']
#
# /usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py in ffmpeg_parse_infos(filename, print_infos, check_duration, fps_source)
#     289             raise IOError(("MoviePy error: failed to read the duration of file %s.\n"
#     290                            "Here are the file infos returned by ffmpeg:\n\n%s")%(
# --> 291                               filename, infos))
#     292
#     293     # get the output line that speaks about video
#
# OSError: MoviePy error: failed to read the duration of file /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-TSB21-53_Drama+NewText_20s_1080x1080.
# Here are the file infos returned by ffmpeg:
#
# ffmpeg version N-86111-ga441aa90e8-static http://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2017 the FFmpeg developers
#   built with gcc 5.4.1 (Debian 5.4.1-8) 20170304
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-debug --disable-ffplay --disable-indev=sndio --disable-outdev=sndio --cc=gcc-5 --enable-fontconfig --enable-frei0r --enable-gnutls --enable-gray --enable-libass --enable-libfreetype --enable-libfribidi --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-librtmp --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libvidstab --enable-libvo-amrwbenc --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libzimg
#   libavutil      55. 63.100 / 55. 63.100
#   libavcodec     57. 96.101 / 57. 96.101
#   libavformat    57. 72.101 / 57. 72.101
#   libavdevice    57.  7.100 / 57.  7.100
#   libavfilter     6. 89.101 /  6. 89.101
#   libswscale      4.  7.101 /  4.  7.101
#   libswresample   2.  8.100 /  2.  8.100
#   libpostproc    54.  6.100 / 54.  6.100
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_ADS/act_472592610491195-TSB21-53_Drama+NewText_20s_1080x1080: Invalid data found when processing input

# %% [markdown]
# # Code to make training Data seperated in START,MID,END folder

# %%
import os
from pathlib import Path
import pandas as pd
import shutil

# %%
image_dir = Path(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_F_DATA')

# %%
total=os.listdir(image_dir)
print(len(total))
total
# Out:
# 110
# ['act_472592610491195-03-10-21_TSB21-TeamPower_1920x1080 (1)',
#  'act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080',
#  'act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350',
#  'act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920',
#  'act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080',
#  'act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080',
#  'act_472592610491195-21-03-11-TSB21-SoClose_1080x1080',
#  'act_472592610491195-21-03-11-TSB21-SoClose_1080x1350',
#  'act_472592610491195-21-03-11-TSB21-SoClose_1080x1920',
#  'act_472592610491195-21-03-11-TSB21-SoClose_1920x1080',
#  'act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1080',
#  'act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350',
#  'act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1920',
#  'act_472592610491195-21-03-12-TSB21-SoClose_TopView_1920x1080',
#  'act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080',
#  'act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350',
#  'act_472592610491195-21-05-17-TSB21_YOU_NOT_MUTED_1920x1080',
#  'act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350',
#  'act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350',
#  'act_472592610491195-21_01_21_TSB21_3HITS_ACUNA_1920x1080_5s',
#  'act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080',
#  'act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350',
#  'act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920',
#  'act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080',
#  'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1080',
#  'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1350',
#  'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920',
#  'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_1',
#  'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_2',
#  'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_3',
#  'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_4',
#  'act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080',
#  'act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080',
#  'act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1350',
#  'act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920',
#  'act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1920x1080',
#  'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V1',
#  'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V2',
#  'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V3',
#  'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V1',
#  'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V2',
#  'act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V3',
#  'act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V1',
#  'act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V2',
#  'act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V3',
#  'act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350',
#  'act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080',
#  'act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920',
#  'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1080_01 (1)',
#  'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1350_01 (1)',
#  'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1920_08',
#  'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1920x1080_01 (1)',
#  'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1080_01 (1)',
#  'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1350_01 (1)',
#  'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03',
#  'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1920x1080_01 (1)',
#  'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1080_01 (1)',
#  'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1350_01 (1)',
#  'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1920_04',
#  'act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1920x1080_01 (1)',
#  'act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_15s',
#  'act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_5s',
#  'act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_15s',
#  'act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_5s',
#  'act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_15s',
#  'act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s (1)',
#  'act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s',
#  'act_472592610491195-Glu_TapBaseball_CinematicOpening_1920x1080_15s',
#  'act_472592610491195-HitSlideCatchWin_1080x1080 (1)',
#  'act_472592610491195-HitSlideCatchWin_1080x1350 (1)',
#  'act_472592610491195-HitSlideCatchWin_1080x1920 (1)',
#  'act_472592610491195-HitSlideCatchWin_1920x1080 (1)',
#  'act_472592610491195-Not A Cat EN_With End Card',
#  'act_472592610491195-Not A Cat SP_V08',
#  'act_472592610491195-Pulsing Text - Story_v01_Full video',
#  'act_472592610491195-Pulsing Text - Story_v01_Scene 1',
#  'act_472592610491195-Pulsing Text - Story_v01_Scene 2',
#  'act_472592610491195-Pulsing Text - Story_v01_Scene 3',
#  'act_472592610491195-Pulsing Text - Story_v01_Scene 4',
#  'act_472592610491195-Pulsing Text - Story_v02_Full video',
#  'act_472592610491195-Pulsing Text - Story_v02_Scene 1',
#  'act_472592610491195-Pulsing Text - Story_v02_Scene 2',
#  'act_472592610491195-Pulsing Text - Story_v02_Scene 3',
#  'act_472592610491195-Pulsing Text - Story_v02_Scene 4',
#  'act_472592610491195-Spring in my step 1080x1080',
#  'act_472592610491195-Spring in my step 1080x1350',
#  'act_472592610491195-Spring in my step 1080x1920',
#  'act_472592610491195-Spring in my step 1920x1080',
#  'act_472592610491195-Story Ad 1080x1080',
#  'act_472592610491195-Story Ad 1080x1350',
#  'act_472592610491195-Story Ad 1080x1920',
#  'act_472592610491195-Story Ad 1920x1080',
#  'act_472592610491195-Story Ad_A (2)',
#  'act_472592610491195-Story Ad_B (1)',
#  'act_472592610491195-Story Ad_C_v02',
#  'act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080',
#  'act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350',
#  'act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920',
#  'act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1920x1080',
#  'act_472592610491195-TSB20_21-02-22-BETTER_THAN_EVER_1920X1080',
#  'act_472592610491195-TSB20_210323v_1080x1080_20s',
#  'act_472592610491195-TSB20_210323v_1080x1350_20s',
#  'act_472592610491195-TSB20_210323v_1080x1920_20s',
#  'act_472592610491195-TSB20_210323v_1920x1080_20s',
#  'act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080',
#  'act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080',
#  'act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080',
#  'act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080',
#  'act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080',
#  'act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080']

# %%
# Name of the directory where we want the splitted scenes to reside
if not os.path.exists(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data'):
    os.makedirs(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data')

# %%
root_path = f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/'
folders = ['START','MID','END','Unseen_Start']
for folder in folders:
    os.mkdir(os.path.join(root_path,folder))

# %%
# Test Paths
total[1]
filepaths = list(pd.Series(list(image_dir.glob(r'{}/*.mp4'.format(total[54]))), name='Filepath').astype(str))
print("All Paths")
print(filepaths)
print("Start Scene")
print(filepaths[0])
print("End Scene")
print(filepaths[-1])
print("Mid Scenes")
print(filepaths[1:-1])
# Out:
# All Paths
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03 - Scene 001.mp4']
# Start Scene
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03 - Scene 001.mp4
# End Scene
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03 - Scene 001.mp4
# Mid Scenes
# []

# %%
#start
counter = 0
for i in total:
    filepaths = list(pd.Series(list(image_dir.glob(r'{}/*.mp4'.format(i))), name='Filepath').astype(str))
    try:
      print(filepaths[0])
      shutil.copy2(filepaths[0],f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/START')
      counter += 1
    except:
      pass
    
print(counter)
# Out:
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-10-21_TSB21-TeamPower_1920x1080 (1)/act_472592610491195-03-10-21_TSB21-TeamPower_1920x1080 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1080x1080/act_472592610491195-21-03-11-TSB21-SoClose_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1080x1350/act_472592610491195-21-03-11-TSB21-SoClose_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1080x1920/act_472592610491195-21-03-11-TSB21-SoClose_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1920x1080/act_472592610491195-21-03-11-TSB21-SoClose_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1080/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1920/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1920x1080/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-17-TSB21_YOU_NOT_MUTED_1920x1080/act_472592610491195-21-05-17-TSB21_YOU_NOT_MUTED_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_21_TSB21_3HITS_ACUNA_1920x1080_5s/act_472592610491195-21_01_21_TSB21_3HITS_ACUNA_1920x1080_5s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1080/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1350/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_1/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_1 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_2/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_2 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_3/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_3 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_4/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_4 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1350/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1920x1080/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V1/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V1 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V2/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V2 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V3/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V3 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V1/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V1 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V2/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V2 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V3/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V3 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V1/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V1 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V2/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V2 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V3/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V3 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1350_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1350_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1920_08/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1920_08 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1920x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1920x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1350_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1350_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1920x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1920x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1350_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1350_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1920_04/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1920_04 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1920x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1920x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_15s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_15s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_5s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_5s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_15s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_15s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_5s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_5s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_15s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_15s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s (1)/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1920x1080_15s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1920x1080_15s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1080 (1)/act_472592610491195-HitSlideCatchWin_1080x1080 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1350 (1)/act_472592610491195-HitSlideCatchWin_1080x1350 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1920 (1)/act_472592610491195-HitSlideCatchWin_1080x1920 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1920x1080 (1)/act_472592610491195-HitSlideCatchWin_1920x1080 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Not A Cat EN_With End Card/act_472592610491195-Not A Cat EN_With End Card - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Not A Cat SP_V08/act_472592610491195-Not A Cat SP_V08 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Full video/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Scene 1/act_472592610491195-Pulsing Text - Story_v01_Scene 1 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Scene 2/act_472592610491195-Pulsing Text - Story_v01_Scene 2 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Scene 3/act_472592610491195-Pulsing Text - Story_v01_Scene 3 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Scene 4/act_472592610491195-Pulsing Text - Story_v01_Scene 4 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Full video/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Scene 1/act_472592610491195-Pulsing Text - Story_v02_Scene 1 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Scene 2/act_472592610491195-Pulsing Text - Story_v02_Scene 2 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Scene 3/act_472592610491195-Pulsing Text - Story_v02_Scene 3 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Scene 4/act_472592610491195-Pulsing Text - Story_v02_Scene 4 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1920/act_472592610491195-Spring in my step 1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1920x1080/act_472592610491195-Story Ad 1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_A (2)/act_472592610491195-Story Ad_A (2) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_B (1)/act_472592610491195-Story Ad_B (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_C_v02/act_472592610491195-Story Ad_C_v02 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1920x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_21-02-22-BETTER_THAN_EVER_1920X1080/act_472592610491195-TSB20_21-02-22-BETTER_THAN_EVER_1920X1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1080_20s/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1350_20s/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080 - Scene 001.mp4
# 110

# %%
#end
counter = 0 
for i in total:
    filepaths = list(pd.Series(list(image_dir.glob(r'{}/*.mp4'.format(i))), name='Filepath').astype(str))
    try:
      print(filepaths[-1])
      shutil.copy2(filepaths[-1],f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/END')
      counter += 1
    except:
      pass
print(counter)
# Out:
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-10-21_TSB21-TeamPower_1920x1080 (1)/act_472592610491195-03-10-21_TSB21-TeamPower_1920x1080 (1) - Scene 004.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080 - Scene 007.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 006.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920 - Scene 007.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080 - Scene 007.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080 - Scene 007.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1080x1080/act_472592610491195-21-03-11-TSB21-SoClose_1080x1080 - Scene 003.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1080x1350/act_472592610491195-21-03-11-TSB21-SoClose_1080x1350 - Scene 002.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1080x1920/act_472592610491195-21-03-11-TSB21-SoClose_1080x1920 - Scene 002.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1920x1080/act_472592610491195-21-03-11-TSB21-SoClose_1920x1080 - Scene 002.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1080/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1920/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1920x1080/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1920x1080 - Scene 002.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080 - Scene 008.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350 - Scene 007.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-17-TSB21_YOU_NOT_MUTED_1920x1080/act_472592610491195-21-05-17-TSB21_YOU_NOT_MUTED_1920x1080 - Scene 002.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350 - Scene 007.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350 - Scene 006.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_21_TSB21_3HITS_ACUNA_1920x1080_5s/act_472592610491195-21_01_21_TSB21_3HITS_ACUNA_1920x1080_5s - Scene 003.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080 - Scene 007.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350 - Scene 007.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920 - Scene 007.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080 - Scene 008.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1080/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1080 - Scene 004.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1350/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1350 - Scene 004.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920 - Scene 005.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_1/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_1 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_2/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_2 - Scene 002.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_3/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_3 - Scene 002.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_4/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_4 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080 - Scene 005.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080 - Scene 006.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1350/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1350 - Scene 005.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920 - Scene 005.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1920x1080/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1920x1080 - Scene 005.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V1/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V1 - Scene 003.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V2/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V2 - Scene 003.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V3/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V3 - Scene 003.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V1/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V1 - Scene 004.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V2/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V2 - Scene 004.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V3/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V3 - Scene 004.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V1/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V1 - Scene 005.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V2/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V2 - Scene 005.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V3/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V3 - Scene 005.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350 - Scene 012.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 013.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920 - Scene 011.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1350_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1350_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1920_08/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1920_08 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1920x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1920x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1350_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1350_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1920x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1920x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1350_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1350_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1920_04/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1920_04 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1920x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1920x1080_01 (1) - Scene 002.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_15s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_15s - Scene 004.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_5s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_5s - Scene 002.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_15s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_15s - Scene 004.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_5s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_5s - Scene 002.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_15s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_15s - Scene 004.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s (1)/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s - Scene 002.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1920x1080_15s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1920x1080_15s - Scene 006.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1080 (1)/act_472592610491195-HitSlideCatchWin_1080x1080 (1) - Scene 011.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1350 (1)/act_472592610491195-HitSlideCatchWin_1080x1350 (1) - Scene 009.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1920 (1)/act_472592610491195-HitSlideCatchWin_1080x1920 (1) - Scene 009.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1920x1080 (1)/act_472592610491195-HitSlideCatchWin_1920x1080 (1) - Scene 009.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Not A Cat EN_With End Card/act_472592610491195-Not A Cat EN_With End Card - Scene 003.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Not A Cat SP_V08/act_472592610491195-Not A Cat SP_V08 - Scene 004.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Full video/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 012.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Scene 1/act_472592610491195-Pulsing Text - Story_v01_Scene 1 - Scene 002.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Scene 2/act_472592610491195-Pulsing Text - Story_v01_Scene 2 - Scene 003.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Scene 3/act_472592610491195-Pulsing Text - Story_v01_Scene 3 - Scene 003.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Scene 4/act_472592610491195-Pulsing Text - Story_v01_Scene 4 - Scene 003.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Full video/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 012.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Scene 1/act_472592610491195-Pulsing Text - Story_v02_Scene 1 - Scene 002.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Scene 2/act_472592610491195-Pulsing Text - Story_v02_Scene 2 - Scene 003.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Scene 3/act_472592610491195-Pulsing Text - Story_v02_Scene 3 - Scene 003.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Scene 4/act_472592610491195-Pulsing Text - Story_v02_Scene 4 - Scene 003.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 016.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 016.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1920/act_472592610491195-Spring in my step 1080x1920 - Scene 014.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 016.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 016.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 016.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 016.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1920x1080/act_472592610491195-Story Ad 1920x1080 - Scene 014.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_A (2)/act_472592610491195-Story Ad_A (2) - Scene 003.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_B (1)/act_472592610491195-Story Ad_B (1) - Scene 008.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_C_v02/act_472592610491195-Story Ad_C_v02 - Scene 006.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 022.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 022.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920 - Scene 022.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1920x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1920x1080 - Scene 021.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_21-02-22-BETTER_THAN_EVER_1920X1080/act_472592610491195-TSB20_21-02-22-BETTER_THAN_EVER_1920X1080 - Scene 013.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1080_20s/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 027.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1350_20s/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 026.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 027.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 027.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 011.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 011.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080 - Scene 008.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080 - Scene 008.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 010.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080 - Scene 010.mp4
# 110

# %%
#mid
counter = 0
for i in total:
    filepaths = list(pd.Series(list(image_dir.glob(r'{}/*.mp4'.format(i))), name='Filepath').astype(str))
    filepaths = filepaths[1:-1]
    print(filepaths[1:-1])
    for c in filepaths:
        shutil.copy2(c,f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/MID')
    counter += 1
print(counter)
# Out:
# []
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080 - Scene 005.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 004.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920 - Scene 005.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080 - Scene 005.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080 - Scene 005.mp4']
# []
# []
# []
# []
# []
# []
# []
# []
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080 - Scene 006.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350 - Scene 005.mp4']
# []
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350 - Scene 005.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350 - Scene 004.mp4']
# []
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080 - Scene 005.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350 - Scene 005.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920 - Scene 005.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080 - Scene 006.mp4']
# []
# []
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920 - Scene 003.mp4']
# []
# []
# []
# []
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080 - Scene 003.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080 - Scene 004.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1350/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1350 - Scene 003.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920 - Scene 003.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1920x1080/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1920x1080 - Scene 003.mp4']
# []
# []
# []
# []
# []
# []
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V1/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V1 - Scene 003.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V2/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V2 - Scene 003.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V3/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V3 - Scene 003.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350 - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350 - Scene 010.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 011.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920 - Scene 009.mp4']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1920x1080_15s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1920x1080_15s - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1920x1080_15s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1920x1080_15s - Scene 004.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1080 (1)/act_472592610491195-HitSlideCatchWin_1080x1080 (1) - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1080 (1)/act_472592610491195-HitSlideCatchWin_1080x1080 (1) - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1080 (1)/act_472592610491195-HitSlideCatchWin_1080x1080 (1) - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1080 (1)/act_472592610491195-HitSlideCatchWin_1080x1080 (1) - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1080 (1)/act_472592610491195-HitSlideCatchWin_1080x1080 (1) - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1080 (1)/act_472592610491195-HitSlideCatchWin_1080x1080 (1) - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1080 (1)/act_472592610491195-HitSlideCatchWin_1080x1080 (1) - Scene 009.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1350 (1)/act_472592610491195-HitSlideCatchWin_1080x1350 (1) - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1350 (1)/act_472592610491195-HitSlideCatchWin_1080x1350 (1) - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1350 (1)/act_472592610491195-HitSlideCatchWin_1080x1350 (1) - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1350 (1)/act_472592610491195-HitSlideCatchWin_1080x1350 (1) - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1350 (1)/act_472592610491195-HitSlideCatchWin_1080x1350 (1) - Scene 007.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1920 (1)/act_472592610491195-HitSlideCatchWin_1080x1920 (1) - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1920 (1)/act_472592610491195-HitSlideCatchWin_1080x1920 (1) - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1920 (1)/act_472592610491195-HitSlideCatchWin_1080x1920 (1) - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1920 (1)/act_472592610491195-HitSlideCatchWin_1080x1920 (1) - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1920 (1)/act_472592610491195-HitSlideCatchWin_1080x1920 (1) - Scene 007.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1920x1080 (1)/act_472592610491195-HitSlideCatchWin_1920x1080 (1) - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1920x1080 (1)/act_472592610491195-HitSlideCatchWin_1920x1080 (1) - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1920x1080 (1)/act_472592610491195-HitSlideCatchWin_1920x1080 (1) - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1920x1080 (1)/act_472592610491195-HitSlideCatchWin_1920x1080 (1) - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1920x1080 (1)/act_472592610491195-HitSlideCatchWin_1920x1080 (1) - Scene 007.mp4']
# []
# []
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Full video/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Full video/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Full video/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Full video/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Full video/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Full video/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Full video/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Full video/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 010.mp4']
# []
# []
# []
# []
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Full video/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Full video/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Full video/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Full video/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Full video/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Full video/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Full video/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Full video/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 010.mp4']
# []
# []
# []
# []
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 011.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 012.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 013.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 014.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 011.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 012.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 013.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 014.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1920/act_472592610491195-Spring in my step 1080x1920 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1920/act_472592610491195-Spring in my step 1080x1920 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1920/act_472592610491195-Spring in my step 1080x1920 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1920/act_472592610491195-Spring in my step 1080x1920 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1920/act_472592610491195-Spring in my step 1080x1920 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1920/act_472592610491195-Spring in my step 1080x1920 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1920/act_472592610491195-Spring in my step 1080x1920 - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1920/act_472592610491195-Spring in my step 1080x1920 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1920/act_472592610491195-Spring in my step 1080x1920 - Scene 011.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1920/act_472592610491195-Spring in my step 1080x1920 - Scene 012.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 011.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 012.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 013.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 014.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 011.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 012.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 013.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 014.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 011.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 012.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 013.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 014.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 011.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 012.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 013.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 014.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1920x1080/act_472592610491195-Story Ad 1920x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1920x1080/act_472592610491195-Story Ad 1920x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1920x1080/act_472592610491195-Story Ad 1920x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1920x1080/act_472592610491195-Story Ad 1920x1080 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1920x1080/act_472592610491195-Story Ad 1920x1080 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1920x1080/act_472592610491195-Story Ad 1920x1080 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1920x1080/act_472592610491195-Story Ad 1920x1080 - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1920x1080/act_472592610491195-Story Ad 1920x1080 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1920x1080/act_472592610491195-Story Ad 1920x1080 - Scene 011.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1920x1080/act_472592610491195-Story Ad 1920x1080 - Scene 012.mp4']
# []
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_B (1)/act_472592610491195-Story Ad_B (1) - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_B (1)/act_472592610491195-Story Ad_B (1) - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_B (1)/act_472592610491195-Story Ad_B (1) - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_B (1)/act_472592610491195-Story Ad_B (1) - Scene 006.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_C_v02/act_472592610491195-Story Ad_C_v02 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_C_v02/act_472592610491195-Story Ad_C_v02 - Scene 004.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 011.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 012.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 013.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 014.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 015.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 016.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 017.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 018.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 019.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 020.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 011.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 012.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 013.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 014.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 015.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 016.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 017.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 018.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 019.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 020.mp4']
# ...
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 011.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 012.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 013.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 014.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 015.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 016.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 017.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 018.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 019.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 020.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 021.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 022.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 023.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 024.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_4725926104911 ...
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 011.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 012.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 013.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 014.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 015.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 016.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 017.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 018.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 019.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 020.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 021.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 022.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 023.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 024.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_4725926104911 ...
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 009.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 009.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080 - Scene 006.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080 - Scene 006.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 008.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080 - Scene 008.mp4']
# 110

# %%
#Unseen_Start
counter = 0
for i in total:
    filepaths = list(pd.Series(list(image_dir.glob(r'{}/*.mp4'.format(i))), name='Filepath').astype(str))
    try:
      print(filepaths[0])
      shutil.copy2(filepaths[0],f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/Unseen_Start')
    except:
      pass
    counter += 1
print(counter)
# Out:
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-10-21_TSB21-TeamPower_1920x1080 (1)/act_472592610491195-03-10-21_TSB21-TeamPower_1920x1080 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1080x1080/act_472592610491195-21-03-11-TSB21-SoClose_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1080x1350/act_472592610491195-21-03-11-TSB21-SoClose_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1080x1920/act_472592610491195-21-03-11-TSB21-SoClose_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-11-TSB21-SoClose_1920x1080/act_472592610491195-21-03-11-TSB21-SoClose_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1080/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1920/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1920x1080/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-17-TSB21_YOU_NOT_MUTED_1920x1080/act_472592610491195-21-05-17-TSB21_YOU_NOT_MUTED_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_21_TSB21_3HITS_ACUNA_1920x1080_5s/act_472592610491195-21_01_21_TSB21_3HITS_ACUNA_1920x1080_5s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1080/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1350/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_1/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_1 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_2/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_2 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_3/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_3 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_4/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_4 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1350/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1920x1080/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V1/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V1 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V2/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V2 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V3/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V3 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V1/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V1 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V2/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V2 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V3/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V3 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V1/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V1 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V2/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V2 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V3/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V3 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1350_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1350_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1920_08/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1920_08 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1920x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1920x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1350_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1350_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1920x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1920x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1350_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1350_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1920_04/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1920_04 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1920x1080_01 (1)/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1920x1080_01 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_15s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_15s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_5s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_5s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_15s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_15s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_5s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_5s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_15s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_15s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s (1)/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Glu_TapBaseball_CinematicOpening_1920x1080_15s/act_472592610491195-Glu_TapBaseball_CinematicOpening_1920x1080_15s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1080 (1)/act_472592610491195-HitSlideCatchWin_1080x1080 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1350 (1)/act_472592610491195-HitSlideCatchWin_1080x1350 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1080x1920 (1)/act_472592610491195-HitSlideCatchWin_1080x1920 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-HitSlideCatchWin_1920x1080 (1)/act_472592610491195-HitSlideCatchWin_1920x1080 (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Not A Cat EN_With End Card/act_472592610491195-Not A Cat EN_With End Card - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Not A Cat SP_V08/act_472592610491195-Not A Cat SP_V08 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Full video/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Scene 1/act_472592610491195-Pulsing Text - Story_v01_Scene 1 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Scene 2/act_472592610491195-Pulsing Text - Story_v01_Scene 2 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Scene 3/act_472592610491195-Pulsing Text - Story_v01_Scene 3 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v01_Scene 4/act_472592610491195-Pulsing Text - Story_v01_Scene 4 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Full video/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Scene 1/act_472592610491195-Pulsing Text - Story_v02_Scene 1 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Scene 2/act_472592610491195-Pulsing Text - Story_v02_Scene 2 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Scene 3/act_472592610491195-Pulsing Text - Story_v02_Scene 3 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Pulsing Text - Story_v02_Scene 4/act_472592610491195-Pulsing Text - Story_v02_Scene 4 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1080/act_472592610491195-Spring in my step 1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1350/act_472592610491195-Spring in my step 1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1080x1920/act_472592610491195-Spring in my step 1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Spring in my step 1920x1080/act_472592610491195-Spring in my step 1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1080/act_472592610491195-Story Ad 1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1350/act_472592610491195-Story Ad 1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1080x1920/act_472592610491195-Story Ad 1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad 1920x1080/act_472592610491195-Story Ad 1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_A (2)/act_472592610491195-Story Ad_A (2) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_B (1)/act_472592610491195-Story Ad_B (1) - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-Story Ad_C_v02/act_472592610491195-Story Ad_C_v02 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1920x1080/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1920x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_21-02-22-BETTER_THAN_EVER_1920X1080/act_472592610491195-TSB20_21-02-22-BETTER_THAN_EVER_1920X1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1080_20s/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1350_20s/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1080x1920_20s/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB20_210323v_1920x1080_20s/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 001.mp4
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_F_DATA/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080 - Scene 001.mp4
# 110

# %%
import numpy as np
import cv2 # extract frames from the videos
from PIL import Image  # to manipulate images
import os
import psycopg2

from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.preprocessing.image import load_img,img_to_array
from tensorflow.keras.models import Model
from tensorflow.keras.applications.imagenet_utils import preprocess_input

from PIL import Image
import os
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
from google.colab.patches import cv2_imshow
import pickle
from tqdm import tqdm
import moviepy.editor
# Import everything needed to edit video clips
from moviepy.editor import VideoFileClip, AudioFileClip, concatenate_videoclips, TextClip, CompositeVideoClip, concatenate_audioclips, AudioClip, CompositeAudioClip

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %%
# load the model
dense_model = DenseNet201(weights='imagenet')

# remove the last layers in order to get features instead of predictions
feat_extractor = Model(inputs=dense_model.input, outputs=dense_model.get_layer("avg_pool").output)

# print the layers of the CNN
feat_extractor.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels.h5
# 82526208/82524592 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 112, 112, 64) 0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 114, 114, 64) 0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 56, 56, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 56, 56, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 56, 56, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 56, 56, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 56, 56, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 56, 56, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 56, 56, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 56, 56, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 56, 56, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 56, 56, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 56, 56, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 56, 56, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 56, 56, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 56, 56, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 56, 56, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 56, 56, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 56, 56, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 56, 56, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 56, 56, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 56, 56, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 56, 56, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 56, 56, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 56, 56, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 56, 56, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 56, 56, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 28, 28, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 28, 28, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 28, 28, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 28, 28, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 28, 28, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 28, 28, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 28, 28, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 28, 28, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 28, 28, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 28, 28, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 28, 28, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 28, 28, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 28, 28, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 28, 28, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 28, 28, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 28, 28, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 28, 28, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 28, 28, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 28, 28, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 28, 28, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 28, 28, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 28, 28, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 28, 28, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 28, 28, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 28, 28, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 28, 28, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 28, 28, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 28, 28, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 28, 28, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 28, 28, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 28, 28, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 28, 28, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 28, 28, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 28, 28, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 28, 28, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 28, 28, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 28, 28, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 28, 28, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 28, 28, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 28, 28, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 28, 28, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 28, 28, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 28, 28, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 28, 28, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 28, 28, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 28, 28, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 28, 28, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 28, 28, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 28, 28, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 28, 28, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 28, 28, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 28, 28, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 14, 14, 256)  0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 256)  1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 14, 14, 256)  0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 128)  32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 128)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 14, 14, 288)  0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 14, 14, 288)  1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 14, 14, 288)  0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 128)  36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 128)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 14, 14, 320)  0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 14, 14, 320)  1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 14, 14, 320)  0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 128)  40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 128)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 14, 14, 352)  0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 14, 14, 352)  1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 14, 14, 352)  0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 128)  45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 128)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 14, 14, 384)  0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 14, 14, 384)  1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 14, 14, 384)  0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 128)  49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 128)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 14, 14, 416)  0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 14, 14, 416)  1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 14, 14, 416)  0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 128)  53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 128)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 14, 14, 448)  0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 14, 14, 448)  1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 14, 14, 448)  0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 14, 14, 128)  57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 14, 14, 128)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 14, 14, 480)  0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 14, 14, 480)  1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 14, 14, 480)  0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 14, 14, 128)  61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 14, 14, 128)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 14, 14, 512)  0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 14, 14, 512)  2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 14, 14, 512)  0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 14, 14, 128)  65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 14, 14, 128)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 14, 14, 544)  0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 14, 14, 544)  2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 14, 14, 544)  0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 14, 14, 128)  69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 14, 14, 576)  0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 14, 14, 576)  2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 14, 14, 576)  0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 14, 14, 128)  73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 14, 14, 608)  0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 14, 14, 608)  2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 14, 14, 608)  0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 14, 14, 128)  77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 14, 14, 640)  0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# ...
# conv5_block22_concat (Concatena (None, 7, 7, 1600)   0           conv5_block21_concat[0][0]
#                                                                  conv5_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_bn (BatchNormal (None, 7, 7, 1600)   6400        conv5_block22_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_relu (Activatio (None, 7, 7, 1600)   0           conv5_block23_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_conv (Conv2D)   (None, 7, 7, 128)    204800      conv5_block23_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_concat (Concatena (None, 7, 7, 1632)   0           conv5_block22_concat[0][0]
#                                                                  conv5_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_bn (BatchNormal (None, 7, 7, 1632)   6528        conv5_block23_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_relu (Activatio (None, 7, 7, 1632)   0           conv5_block24_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_conv (Conv2D)   (None, 7, 7, 128)    208896      conv5_block24_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block24_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block24_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block24_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_concat (Concatena (None, 7, 7, 1664)   0           conv5_block23_concat[0][0]
#                                                                  conv5_block24_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_bn (BatchNormal (None, 7, 7, 1664)   6656        conv5_block24_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_relu (Activatio (None, 7, 7, 1664)   0           conv5_block25_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_conv (Conv2D)   (None, 7, 7, 128)    212992      conv5_block25_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block25_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block25_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block25_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_concat (Concatena (None, 7, 7, 1696)   0           conv5_block24_concat[0][0]
#                                                                  conv5_block25_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_bn (BatchNormal (None, 7, 7, 1696)   6784        conv5_block25_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_relu (Activatio (None, 7, 7, 1696)   0           conv5_block26_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_conv (Conv2D)   (None, 7, 7, 128)    217088      conv5_block26_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block26_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block26_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block26_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_concat (Concatena (None, 7, 7, 1728)   0           conv5_block25_concat[0][0]
#                                                                  conv5_block26_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_bn (BatchNormal (None, 7, 7, 1728)   6912        conv5_block26_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_relu (Activatio (None, 7, 7, 1728)   0           conv5_block27_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_conv (Conv2D)   (None, 7, 7, 128)    221184      conv5_block27_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block27_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block27_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block27_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_concat (Concatena (None, 7, 7, 1760)   0           conv5_block26_concat[0][0]
#                                                                  conv5_block27_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_bn (BatchNormal (None, 7, 7, 1760)   7040        conv5_block27_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_relu (Activatio (None, 7, 7, 1760)   0           conv5_block28_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_conv (Conv2D)   (None, 7, 7, 128)    225280      conv5_block28_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block28_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block28_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block28_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_concat (Concatena (None, 7, 7, 1792)   0           conv5_block27_concat[0][0]
#                                                                  conv5_block28_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_bn (BatchNormal (None, 7, 7, 1792)   7168        conv5_block28_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_relu (Activatio (None, 7, 7, 1792)   0           conv5_block29_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_conv (Conv2D)   (None, 7, 7, 128)    229376      conv5_block29_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block29_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block29_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block29_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_concat (Concatena (None, 7, 7, 1824)   0           conv5_block28_concat[0][0]
#                                                                  conv5_block29_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_bn (BatchNormal (None, 7, 7, 1824)   7296        conv5_block29_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_relu (Activatio (None, 7, 7, 1824)   0           conv5_block30_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_conv (Conv2D)   (None, 7, 7, 128)    233472      conv5_block30_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block30_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block30_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block30_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_concat (Concatena (None, 7, 7, 1856)   0           conv5_block29_concat[0][0]
#                                                                  conv5_block30_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_bn (BatchNormal (None, 7, 7, 1856)   7424        conv5_block30_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_relu (Activatio (None, 7, 7, 1856)   0           conv5_block31_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_conv (Conv2D)   (None, 7, 7, 128)    237568      conv5_block31_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block31_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block31_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block31_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_concat (Concatena (None, 7, 7, 1888)   0           conv5_block30_concat[0][0]
#                                                                  conv5_block31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_bn (BatchNormal (None, 7, 7, 1888)   7552        conv5_block31_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_relu (Activatio (None, 7, 7, 1888)   0           conv5_block32_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_conv (Conv2D)   (None, 7, 7, 128)    241664      conv5_block32_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_concat (Concatena (None, 7, 7, 1920)   0           conv5_block31_concat[0][0]
#                                                                  conv5_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 7, 7, 1920)   7680        conv5_block32_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 7, 7, 1920)   0           bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1920)         0           relu[0][0]
# ==================================================================================================
# Total params: 18,321,984
# Trainable params: 18,092,928
# Non-trainable params: 229,056
# __________________________________________________________________________________________________

# %%
# parameters setup

video_path_mid = f"/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/MID/"
video_path_end = f"/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/END/"
target_path = f"/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/Unseen_Start/"
video_model_width, video_model_height = 224, 224
No_of_frames = 10
No_of_mid_scenes = 2
No_of_end_scenes = 1

nb_closest_videos = 1

# %%
files_mid = [video_path_mid + x for x in os.listdir(video_path_mid) if ".mp4" in x]
#files_mid = np.random.choice(files_mid, 20)
files_mid = list(set(files_mid))
print("number of videos in Mid :",len(files_mid))

files_end = [video_path_end + x for x in os.listdir(video_path_end) if ".mp4" in x]
#files_end = np.random.choice(files_end, 5)
files_end = list(set(files_end))
print("number of videos in end:",len(files_end))
# Out:
# number of videos in Mid : 563
# number of videos in end: 109

# %%
# Fetching Data directly from Database
def global_performance(clip_name):
  conn = psycopg2.connect(user = "ds_readonly", password = "blkbox2020!",host = "db.blkbox.ai",port = "5432",database = "blkbox")
  sql = ("select sum(distinct(global_performance)) as global_performance "   
        "from fb_app_assets "
        "where asset_name like '%{a}%' and asset_type = 'VIDEO' "
        "order by global_performance desc; ".format(a=clip_name))
  data = pd.read_sql_query(sql, conn)
  conn = None
  return max(data.global_performance,default=0)

def all_video_ar(video):
  # loading video dsa gfg intro video 
  clip = VideoFileClip(video) 
  # getting only first 5 seconds
  clip = clip.subclip(0, 5) 
  # getting clip size
  value = clip.size
  return value

def performance_df(files,section):
  counter = 0
  performance = []
  dimension = []
  video_name_list = []
  for video in files:
    s1 = video
    s2 = "{a}/".format(a=section)
    s3 = " - Scene"

    name = s1[s1.index(s2) + len(s2):s1.index(s3)]
    video_name_list.append(name)
    performance.append(global_performance(name))
    dimension.append(all_video_ar(video))
  print(len(video_name_list))
  print(len(performance))
  print(len(files))
  print(len(dimension))
  df = pd.DataFrame(list(zip(video_name_list, files, performance, dimension)),columns =['video_name','files_path','performance','dimension'])
  return df

# %%
df_mid_performance = performance_df(files_mid,'MID')
df_end_performance = performance_df(files_end,'END')
#df_Unseen_performance = performance_df(target,'Unseen_Start')
df_mid_performance['performance'] = df_mid_performance['performance'].fillna(0)
df_end_performance['performance'] = df_end_performance['performance'].fillna(0)
print(df_mid_performance.head(30))
print(df_end_performance.head(30))
# Out:
# 563
# 563
# 563
# 563
# 109
# 109
# 109
# 109
#                                            video_name  ... aspect_ratio
# 0   act_472592610491195-TSB20_20210319_Step It Up_...  ...  (720, 1280)
# 1              act_472592610491195-Story Ad 1080x1080  ...   (640, 640)
# 2   act_472592610491195-21_02_01_TSB21_3HITS_SOTO_...  ...  (720, 1280)
# 3              act_472592610491195-Story Ad 1080x1920  ...  (720, 1280)
# 4     act_472592610491195-TSB20_210323v_1080x1920_20s  ...  (720, 1280)
# 5     act_472592610491195-TSB20_210323v_1080x1080_20s  ...   (640, 640)
# 6     act_472592610491195-TSB20_210323v_1920x1080_20s  ...  (1280, 720)
# 7   act_472592610491195-TSB20_20210319_Step It Up_...  ...   (720, 900)
# 8   act_472592610491195-Glu_TapBaseball_CinematicO...  ...   (640, 640)
# 9   act_472592610491195-TSB20_21-02-22-BETTER_THAN...  ...  (1280, 720)
# 10  act_472592610491195-TSB21-159_TikTok-Jump-Into...  ...   (640, 640)
# 11  act_472592610491195-HitSlideCatchWin_1080x1920...  ...  (720, 1280)
# 12             act_472592610491195-Story Ad 1080x1080  ...   (640, 640)
# 13             act_472592610491195-Story Ad 1080x1920  ...  (720, 1280)
# 14  act_472592610491195-HitSlideCatchWin_1920x1080...  ...  (1280, 720)
# 15  act_472592610491195-21-05-19-TSB21_SERIOUS_SP_...  ...   (720, 900)
# 16  act_472592610491195-21_02_16_TSB21_3HITS_SOTO_...  ...   (720, 900)
# 17    act_472592610491195-Spring in my step 1080x1350  ...   (720, 900)
# 18  act_472592610491195-21-05-17-TSB21_SERIOUS_PiP...  ...   (720, 900)
# 19    act_472592610491195-TSB20_210323v_1080x1920_20s  ...  (720, 1280)
# 20             act_472592610491195-Story Ad 1080x1920  ...  (720, 1280)
# 21  act_472592610491195-HitSlideCatchWin_1080x1350...  ...   (720, 900)
# 22             act_472592610491195-Story Ad 1920x1080  ...  (1280, 720)
# 23    act_472592610491195-Spring in my step 1080x1080  ...   (640, 640)
# 24  act_472592610491195-TSB20_20210319_Step It Up_...  ...  (720, 1280)
# 25    act_472592610491195-Spring in my step 1080x1920  ...  (720, 1280)
# 26  act_472592610491195-TSB20_21-02-22-BETTER_THAN...  ...  (1280, 720)
# 27  act_472592610491195-03-15-21_TSB21_Target_Bash...  ...  (1280, 720)
# 28  act_472592610491195-03-10-21_TSB21-TeamPower_1...  ...  (1280, 720)
# 29             act_472592610491195-Story Ad 1080x1350  ...   (720, 900)
#
# [30 rows x 4 columns]
#                                            video_name  ... aspect_ratio
# 0   act_472592610491195-21_02_16_TSB21_3HITS_SOTO_...  ...   (720, 900)
# 1   act_472592610491195-21_02_16__TSB21_3HITS_SOTO...  ...  (720, 1280)
# 2   act_472592610491195-Pulsing Text - Story_v01_S...  ...  (720, 1280)
# 3   act_472592610491195-Pulsing Text - Story_v02_S...  ...  (720, 1280)
# 4   act_472592610491195-TSB20_20210319_Step It Up_...  ...  (720, 1280)
# 5   act_472592610491195-21_01_26_TSB21_3HITS_SCREE...  ...   (720, 900)
# 6              act_472592610491195-Story Ad 1080x1920  ...  (720, 1280)
# 7                  act_472592610491195-Story Ad_A (2)  ...  (720, 1280)
# 8                  act_472592610491195-Story Ad_C_v02  ...  (720, 1280)
# 9   act_472592610491195-GM_210205v_TSBSoyLaBestia-...  ...  (1280, 720)
# 10  act_472592610491195-Pulsing Text - Story_v01_S...  ...  (720, 1280)
# 11  act_472592610491195-03-15-21_TSB21_Target_Bash...  ...   (720, 900)
# 12  act_472592610491195-03_07_21_TSB21_It_Keeper_T...  ...   (640, 640)
# 13     act_472592610491195-Not A Cat EN_With End Card  ...  (1280, 720)
# 14  act_472592610491195-21-03-12-TSB21-SoClose_Top...  ...  (720, 1280)
# 15  act_472592610491195-Glu_TapBaseball_CinematicO...  ...  (720, 1280)
# 16  act_472592610491195-HitSlideCatchWin_1080x1350...  ...   (720, 900)
# 17  act_472592610491195-Pulsing Text - Story_v01_S...  ...  (720, 1280)
# 18  act_472592610491195-TSB20_20210319_Step It Up_...  ...   (720, 900)
# 19    act_472592610491195-Spring in my step 1920x1080  ...  (1280, 720)
# 20  act_472592610491195-TSB20_20210319_Step It Up_...  ...  (1280, 720)
# 21  act_472592610491195-21-03-12-TSB21-SoClose_Top...  ...   (640, 640)
# 22  act_472592610491195-21_02_01_TSB21_3HITS_ACUNA...  ...   (640, 640)
# 23    act_472592610491195-Spring in my step 1080x1920  ...  (720, 1280)
# 24  act_472592610491195-21-03-12-TSB21-SoClose_Top...  ...  (1280, 720)
# 25  act_472592610491195-TSB21-40_Gameplay-Build-Yo...  ...   (640, 640)
# 26  act_472592610491195-TSB21-37_Jaws_Soto_20sec_1...  ...   (640, 640)
# 27  act_472592610491195-21_02_16_TSB21_3HITS_SOTO_...  ...   (720, 900)
# 28  act_472592610491195-21-03-11-TSB21-SoClose_108...  ...   (720, 900)
# 29  act_472592610491195-Glu_TapBaseball_CinematicO...  ...  (720, 1280)
#
# [30 rows x 4 columns]

# %%
 df_mid_performance.head()
# Out:
#                                           video_name  ... aspect_ratio
# 0  act_472592610491195-TSB20_20210319_Step It Up_...  ...  (720, 1280)
# 1             act_472592610491195-Story Ad 1080x1080  ...   (640, 640)
# 2  act_472592610491195-21_02_01_TSB21_3HITS_SOTO_...  ...  (720, 1280)
# 3             act_472592610491195-Story Ad 1080x1920  ...  (720, 1280)
# 4    act_472592610491195-TSB20_210323v_1080x1920_20s  ...  (720, 1280)
#
# [5 rows x 4 columns]

# %%
target = [target_path + x for x in os.listdir(target_path) if ".mp4" in x]
#files1 = np.random.choice(files1, 3)
print("number of Videos:",len(target))

target = list(target)
print(len(target))
a = []
for vid in target:
      video = moviepy.editor.VideoFileClip(vid)
      video_duration = int(video.duration)
    #  print(video_duration)
      if video_duration > 0:
        a.append(vid)
        
target = a
print(len(target))

df_target_performance = performance_df(target,'Unseen_Start')
df_Unseen_performance = performance_df(target,'Unseen_Start')
df_target_performance['performance'] = df_mid_performance['performance'].fillna(0)
print(df_target_performance.head(10))
# Out:
# number of Videos: 110
# 110
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
#                                           video_name  ... aspect_ratio
# 0  act_472592610491195-03-10-21_TSB21-TeamPower_1...  ...  (1280, 720)
# 1  act_472592610491195-03-15-21_TSB21_Target_Bash...  ...   (640, 640)
# 2  act_472592610491195-03-15-21_TSB21_Target_Bash...  ...   (720, 900)
# 3  act_472592610491195-03-15-21_TSB21_Target_Bash...  ...  (720, 1280)
# 4  act_472592610491195-03-15-21_TSB21_Target_Bash...  ...  (1280, 720)
# 5  act_472592610491195-03_07_21_TSB21_It_Keeper_T...  ...   (640, 640)
# 6  act_472592610491195-21-03-11-TSB21-SoClose_108...  ...   (640, 640)
# 7  act_472592610491195-21-03-11-TSB21-SoClose_108...  ...   (720, 900)
# 8  act_472592610491195-21-03-11-TSB21-SoClose_108...  ...  (720, 1280)
# 9  act_472592610491195-21-03-11-TSB21-SoClose_192...  ...  (1280, 720)
#
# [10 rows x 4 columns]

# %%
target = list(df_target_performance.files_path.head())

t = target[2]
target = []
target.append(t)
target
# Out:
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/Unseen_Start/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 001.mp4']

# %%
target_clip = VideoFileClip(target[0])      
# getting only first 5 seconds
target_clip = target_clip.subclip(0, 5) 
# getting clip size
height, width = target_clip.size
target_size = target_clip.size
print("Height is :",height,"Width is :",width)
print("The target size is :",target_size)
# Out:
# Height is : 720 Width is : 900
# The target size is : (720, 900)

# %% [markdown]
# ### Filtering files_mid & files_end according to the target scene aspect ratio

# %% [markdown]
# #### Function to extract features from videos

# %%
def feature_extractor(files):  
  importedvideos = []
  # load all the images and prepare them for feeding into the CNN
  counter = 0

  for video in tqdm(files):  
        frames = []
        count = 1

        path = video
        cap = cv2.VideoCapture(path)

        length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        print("The name of the video is :",video)
        print("The total frames in the video is :",length)
        temp = length / No_of_frames
   #    print(temp)

        ret = True
        while ret:
          ret, img = cap.read() # read one frame from the 'capture' object; img is (H, W, C)
          if ret:
              img = cv2.resize(img, (224, 224))
              frames.append(img)
      #       cv2_imshow(img)
      #       print("****************************")
      #       print("****************************")
              count += temp
              cap.set(1,count)
          else:
            cap.release()
            break
        video_frames = np.stack(frames, axis=0)  
        # extract the images features

        imgs_features = feat_extractor.predict(video_frames)

        print("features successfully extracted!")
        print(imgs_features.shape)

        flatten_img_features = imgs_features.flatten()
        flatten_img_features = np.expand_dims(flatten_img_features,axis = 0)
        print(flatten_img_features.shape)
    #   if flatten_img_features.shape[1] == 19200:
        importedvideos.append(flatten_img_features)
  videos_array = np.vstack(importedvideos)
  return videos_array

# %%
# Name of the directory where we want the splitted scenes to reside
if not os.path.exists(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_ARRAY_STORAGE'):
    os.makedirs(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_ARRAY_STORAGE')

# %%
videos_mid_train = feature_extractor(files_mid)
np.save(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_ARRAY_STORAGE/videos_mid_train', videos_mid_train)
file_name = f"/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_ARRAY_STORAGE/{ADSET}_files_mid"
open_file = open(file_name, "wb")
pickle.dump(files_mid, open_file)
open_file.close()

open_file = open(file_name, "rb")
files_mid = pickle.load(open_file)
open_file.close()
print(files_mid)
print(len(files_mid))

print()
# Out:
#   0%|          | 0/563 [00:00<?, ?it/s]
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920 - Scene 004.mp4
# The total frames in the video is : 33
#   0%|          | 1/563 [00:00<08:28,  1.11it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1080 - Scene 006.mp4
# The total frames in the video is : 24
#   0%|          | 2/563 [00:01<07:00,  1.33it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920 - Scene 003.mp4
# The total frames in the video is : 37
#   1%|          | 3/563 [00:02<07:18,  1.28it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1920 - Scene 012.mp4
# The total frames in the video is : 31
#   1%|          | 4/563 [00:02<07:23,  1.26it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 004.mp4
# The total frames in the video is : 19
#   1%|          | 5/563 [00:03<06:57,  1.34it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 005.mp4
# The total frames in the video is : 15
#   1%|          | 6/563 [00:03<05:47,  1.60it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 019.mp4
# The total frames in the video is : 16
#   1%|          | 7/563 [00:04<05:40,  1.63it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 011.mp4
# The total frames in the video is : 18
#   1%|▏         | 8/563 [00:04<05:09,  1.79it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_15s - Scene 002.mp4
# The total frames in the video is : 33
#   2%|▏         | 9/563 [00:05<04:54,  1.88it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_21-02-22-BETTER_THAN_EVER_1920X1080 - Scene 007.mp4
# The total frames in the video is : 28
#   2%|▏         | 10/563 [00:06<05:24,  1.71it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080 - Scene 005.mp4
# The total frames in the video is : 61
#   2%|▏         | 11/563 [00:06<05:27,  1.69it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-HitSlideCatchWin_1080x1920 (1) - Scene 008.mp4
# The total frames in the video is : 188
#   2%|▏         | 12/563 [00:10<12:58,  1.41s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1080 - Scene 010.mp4
# The total frames in the video is : 16
#   2%|▏         | 13/563 [00:10<10:07,  1.10s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1920 - Scene 010.mp4
# The total frames in the video is : 16
#   2%|▏         | 14/563 [00:11<08:48,  1.04it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-HitSlideCatchWin_1920x1080 (1) - Scene 005.mp4
# The total frames in the video is : 18
#   3%|▎         | 15/563 [00:11<07:30,  1.22it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350 - Scene 004.mp4
# The total frames in the video is : 20
#   3%|▎         | 16/563 [00:12<06:26,  1.42it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V1 - Scene 002.mp4
# The total frames in the video is : 148
#   3%|▎         | 17/563 [00:13<08:27,  1.08it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1350 - Scene 005.mp4
# The total frames in the video is : 55
#   3%|▎         | 18/563 [00:14<07:31,  1.21it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350 - Scene 003.mp4
# The total frames in the video is : 26
#   3%|▎         | 19/563 [00:14<06:58,  1.30it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 012.mp4
# The total frames in the video is : 19
#   4%|▎         | 20/563 [00:15<06:29,  1.39it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1920 - Scene 014.mp4
# The total frames in the video is : 21
#   4%|▎         | 21/563 [00:15<06:07,  1.47it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-HitSlideCatchWin_1080x1350 (1) - Scene 006.mp4
# The total frames in the video is : 86
#   4%|▍         | 22/563 [00:17<07:43,  1.17it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1920x1080 - Scene 002.mp4
# The total frames in the video is : 54
#   4%|▍         | 23/563 [00:18<08:39,  1.04it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1080 - Scene 006.mp4
# The total frames in the video is : 24
#   4%|▍         | 24/563 [00:18<07:04,  1.27it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920 - Scene 014.mp4
# The total frames in the video is : 33
#   4%|▍         | 25/563 [00:19<07:16,  1.23it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1920 - Scene 006.mp4
# The total frames in the video is : 24
#   5%|▍         | 26/563 [00:20<06:54,  1.30it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_21-02-22-BETTER_THAN_EVER_1920X1080 - Scene 008.mp4
# The total frames in the video is : 19
#   5%|▍         | 27/563 [00:20<06:32,  1.37it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080 - Scene 002.mp4
# The total frames in the video is : 48
#   5%|▍         | 28/563 [00:22<07:30,  1.19it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-10-21_TSB21-TeamPower_1920x1080 (1) - Scene 003.mp4
# The total frames in the video is : 188
#   5%|▌         | 29/563 [00:25<14:29,  1.63s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1350 - Scene 008.mp4
# The total frames in the video is : 15
#   5%|▌         | 30/563 [00:25<11:15,  1.27s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 006.mp4
# The total frames in the video is : 41
#   6%|▌         | 31/563 [00:26<08:59,  1.01s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920 - Scene 007.mp4
# The total frames in the video is : 19
#   6%|▌         | 32/563 [00:26<07:47,  1.14it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 005.mp4
# The total frames in the video is : 36
#   6%|▌         | 33/563 [00:27<07:55,  1.11it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 012.mp4
# The total frames in the video is : 18
#   6%|▌         | 34/563 [00:28<06:22,  1.38it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1350 - Scene 010.mp4
# The total frames in the video is : 17
#   6%|▌         | 35/563 [00:28<05:47,  1.52it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 008.mp4
# The total frames in the video is : 61
#   6%|▋         | 36/563 [00:29<05:25,  1.62it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1350 - Scene 004.mp4
# The total frames in the video is : 16
#   7%|▋         | 37/563 [00:29<04:40,  1.88it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 003.mp4
# The total frames in the video is : 52
#   7%|▋         | 38/563 [00:30<04:33,  1.92it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 025.mp4
# The total frames in the video is : 56
#   7%|▋         | 39/563 [00:30<04:47,  1.82it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 025.mp4
# The total frames in the video is : 90
#   7%|▋         | 40/563 [00:31<06:09,  1.42it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350 - Scene 004.mp4
# The total frames in the video is : 61
#   7%|▋         | 41/563 [00:32<06:26,  1.35it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080 - Scene 003.mp4
# The total frames in the video is : 41
#   7%|▋         | 42/563 [00:33<07:06,  1.22it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080 - Scene 002.mp4
# The total frames in the video is : 86
#   8%|▊         | 43/563 [00:34<06:14,  1.39it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350 - Scene 006.mp4
# The total frames in the video is : 47
#   8%|▊         | 44/563 [00:34<06:09,  1.40it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1920x1080 - Scene 010.mp4
# The total frames in the video is : 31
#   8%|▊         | 45/563 [00:35<06:42,  1.29it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 007.mp4
# The total frames in the video is : 68
#   8%|▊         | 46/563 [00:36<06:17,  1.37it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 004.mp4
# The total frames in the video is : 42
#   8%|▊         | 47/563 [00:37<06:40,  1.29it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1920x1080 - Scene 004.mp4
# The total frames in the video is : 32
#   9%|▊         | 48/563 [00:37<06:16,  1.37it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 015.mp4
# The total frames in the video is : 23
#   9%|▊         | 49/563 [00:38<05:34,  1.54it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920 - Scene 010.mp4
# The total frames in the video is : 29
#   9%|▉         | 50/563 [00:38<05:26,  1.57it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350 - Scene 004.mp4
# The total frames in the video is : 61
#   9%|▉         | 51/563 [00:39<05:54,  1.44it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 013.mp4
# The total frames in the video is : 22
#   9%|▉         | 52/563 [00:40<05:43,  1.49it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080 - Scene 004.mp4
# The total frames in the video is : 66
#   9%|▉         | 53/563 [00:40<05:43,  1.48it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1350 - Scene 015.mp4
# The total frames in the video is : 28
#  10%|▉         | 54/563 [00:41<05:16,  1.61it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1350 - Scene 002.mp4
# The total frames in the video is : 54
#  10%|▉         | 55/563 [00:42<06:02,  1.40it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-HitSlideCatchWin_1080x1080 (1) - Scene 002.mp4
# The total frames in the video is : 72
#  10%|▉         | 56/563 [00:43<05:44,  1.47it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V3 - Scene 002.mp4
# The total frames in the video is : 117
#  10%|█         | 57/563 [00:44<06:34,  1.28it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1920x1080 - Scene 004.mp4
# The total frames in the video is : 17
#  10%|█         | 58/563 [00:44<06:29,  1.30it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920 - Scene 005.mp4
# The total frames in the video is : 26
#  10%|█         | 59/563 [00:45<06:40,  1.26it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 025.mp4
# The total frames in the video is : 15
#  11%|█         | 60/563 [00:46<06:04,  1.38it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1350 - Scene 002.mp4
# The total frames in the video is : 40
#  11%|█         | 61/563 [00:46<06:11,  1.35it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-HitSlideCatchWin_1920x1080 (1) - Scene 008.mp4
# The total frames in the video is : 187
#  11%|█         | 62/563 [00:50<13:01,  1.56s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350 - Scene 004.mp4
# The total frames in the video is : 18
#  11%|█         | 63/563 [00:50<10:26,  1.25s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 014.mp4
# The total frames in the video is : 23
#  11%|█▏        | 64/563 [00:51<08:27,  1.02s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920 - Scene 002.mp4
# The total frames in the video is : 20
#  12%|█▏        | 65/563 [00:52<07:20,  1.13it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080 - Scene 007.mp4
# The total frames in the video is : 36
#  12%|█▏        | 66/563 [00:52<06:21,  1.30it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1920x1080 - Scene 002.mp4
# The total frames in the video is : 15
#  12%|█▏        | 67/563 [00:53<06:08,  1.35it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1080 - Scene 005.mp4
# The total frames in the video is : 16
#  12%|█▏        | 68/563 [00:53<04:56,  1.67it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 008.mp4
# The total frames in the video is : 50
#  12%|█▏        | 69/563 [00:53<04:32,  1.81it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad_C_v02 - Scene 003.mp4
# The total frames in the video is : 23
#  12%|█▏        | 70/563 [00:54<04:50,  1.70it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080 - Scene 005.mp4
# The total frames in the video is : 144
#  13%|█▎        | 71/563 [00:55<06:00,  1.37it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_15s - Scene 002.mp4
# The total frames in the video is : 33
#  13%|█▎        | 72/563 [00:56<06:15,  1.31it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 021.mp4
# The total frames in the video is : 97
#  13%|█▎        | 73/563 [00:57<07:06,  1.15it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 009.mp4
# The total frames in the video is : 15
#  13%|█▎        | 74/563 [00:58<06:04,  1.34it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1350 - Scene 002.mp4
# The total frames in the video is : 111
#  13%|█▎        | 75/563 [00:59<07:33,  1.07it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 003.mp4
# The total frames in the video is : 61
#  13%|█▎        | 76/563 [01:00<07:24,  1.09it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 009.mp4
# The total frames in the video is : 138
#  14%|█▎        | 77/563 [01:00<06:37,  1.22it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1920x1080 - Scene 006.mp4
# The total frames in the video is : 15
#  14%|█▍        | 78/563 [01:01<05:42,  1.42it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920 - Scene 002.mp4
# The total frames in the video is : 75
#  14%|█▍        | 79/563 [01:02<06:56,  1.16it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920 - Scene 009.mp4
# The total frames in the video is : 26
#  14%|█▍        | 80/563 [01:03<06:38,  1.21it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 019.mp4
# The total frames in the video is : 19
#  14%|█▍        | 81/563 [01:03<05:33,  1.45it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_21-02-22-BETTER_THAN_EVER_1920X1080 - Scene 010.mp4
# The total frames in the video is : 26
#  15%|█▍        | 82/563 [01:04<05:50,  1.37it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 004.mp4
# The total frames in the video is : 19
#  15%|█▍        | 83/563 [01:04<05:19,  1.50it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080 - Scene 004.mp4
# The total frames in the video is : 34
#  15%|█▍        | 84/563 [01:05<05:46,  1.38it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 007.mp4
# The total frames in the video is : 17
#  15%|█▌        | 85/563 [01:06<04:40,  1.71it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 002.mp4
# The total frames in the video is : 35
#  15%|█▌        | 86/563 [01:07<05:29,  1.45it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 024.mp4
# The total frames in the video is : 16
#  15%|█▌        | 87/563 [01:07<04:49,  1.64it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 007.mp4
# The total frames in the video is : 68
#  16%|█▌        | 88/563 [01:08<04:51,  1.63it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 004.mp4
# The total frames in the video is : 62
#  16%|█▌        | 89/563 [01:08<04:35,  1.72it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Pulsing Text - Story_v01_Scene 3 - Scene 002.mp4
# The total frames in the video is : 46
#  16%|█▌        | 90/563 [01:09<05:58,  1.32it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 020.mp4
# The total frames in the video is : 19
#  16%|█▌        | 91/563 [01:10<05:36,  1.40it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350 - Scene 006.mp4
# The total frames in the video is : 36
#  16%|█▋        | 92/563 [01:11<05:38,  1.39it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_01_21_TSB21_3HITS_ACUNA_1920x1080_5s - Scene 002.mp4
# The total frames in the video is : 48
#  17%|█▋        | 93/563 [01:12<06:40,  1.17it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 010.mp4
# The total frames in the video is : 36
#  17%|█▋        | 94/563 [01:12<05:39,  1.38it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920 - Scene 003.mp4
# The total frames in the video is : 52
#  17%|█▋        | 95/563 [01:13<06:20,  1.23it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920 - Scene 004.mp4
# The total frames in the video is : 18
#  17%|█▋        | 96/563 [01:14<05:40,  1.37it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 005.mp4
# The total frames in the video is : 30
#  17%|█▋        | 97/563 [01:14<05:28,  1.42it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1350 - Scene 008.mp4
# The total frames in the video is : 15
#  17%|█▋        | 98/563 [01:15<04:41,  1.65it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350 - Scene 003.mp4
# The total frames in the video is : 79
#  18%|█▊        | 99/563 [01:16<04:59,  1.55it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 017.mp4
# The total frames in the video is : 34
#  18%|█▊        | 100/563 [01:16<04:32,  1.70it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 005.mp4
# The total frames in the video is : 15
#  18%|█▊        | 101/563 [01:16<04:12,  1.83it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 021.mp4
# The total frames in the video is : 22
#  18%|█▊        | 102/563 [01:17<04:08,  1.85it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 005.mp4
# The total frames in the video is : 20
#  18%|█▊        | 103/563 [01:17<03:33,  2.15it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920 - Scene 002.mp4
# The total frames in the video is : 111
#  18%|█▊        | 104/563 [01:19<05:48,  1.32it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1080 - Scene 010.mp4
# The total frames in the video is : 17
#  19%|█▊        | 105/563 [01:19<04:56,  1.54it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 006.mp4
# The total frames in the video is : 15
#  19%|█▉        | 106/563 [01:20<04:32,  1.68it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 002.mp4
# The total frames in the video is : 21
#  19%|█▉        | 107/563 [01:20<03:57,  1.92it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080 - Scene 003.mp4
# The total frames in the video is : 79
#  19%|█▉        | 108/563 [01:20<03:50,  1.97it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Pulsing Text - Story_v02_Scene 3 - Scene 002.mp4
# The total frames in the video is : 46
#  19%|█▉        | 109/563 [01:22<05:21,  1.41it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920 - Scene 004.mp4
# The total frames in the video is : 46
#  20%|█▉        | 110/563 [01:23<05:56,  1.27it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 002.mp4
# The total frames in the video is : 48
#  20%|█▉        | 111/563 [01:23<05:53,  1.28it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 007.mp4
# The total frames in the video is : 43
#  20%|█▉        | 112/563 [01:24<06:10,  1.22it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1080 - Scene 015.mp4
# The total frames in the video is : 23
#  20%|██        | 113/563 [01:25<05:05,  1.47it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080 - Scene 004.mp4
# The total frames in the video is : 72
#  20%|██        | 114/563 [01:25<05:09,  1.45it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 010.mp4
# The total frames in the video is : 36
#  20%|██        | 115/563 [01:26<04:40,  1.60it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 013.mp4
# The total frames in the video is : 25
#  21%|██        | 116/563 [01:26<03:59,  1.87it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1920x1080 - Scene 003.mp4
# The total frames in the video is : 52
#  21%|██        | 117/563 [01:27<04:49,  1.54it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 012.mp4
# The total frames in the video is : 25
#  21%|██        | 118/563 [01:27<04:20,  1.71it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 007.mp4
# The total frames in the video is : 20
#  21%|██        | 119/563 [01:28<03:54,  1.90it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080 - Scene 005.mp4
# The total frames in the video is : 38
#  21%|██▏       | 120/563 [01:29<04:59,  1.48it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 003.mp4
# The total frames in the video is : 28
#  21%|██▏       | 121/563 [01:29<04:10,  1.77it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 004.mp4
# The total frames in the video is : 42
#  22%|██▏       | 122/563 [01:30<04:55,  1.49it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920 - Scene 019.mp4
# The total frames in the video is : 38
#  22%|██▏       | 123/563 [01:31<05:12,  1.41it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 011.mp4
# The total frames in the video is : 19
#  22%|██▏       | 124/563 [01:31<04:26,  1.65it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 006.mp4
# The total frames in the video is : 60
#  22%|██▏       | 125/563 [01:32<04:56,  1.48it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 021.mp4
# The total frames in the video is : 97
#  22%|██▏       | 126/563 [01:33<05:12,  1.40it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080 - Scene 002.mp4
# The total frames in the video is : 42
#  23%|██▎       | 127/563 [01:33<04:50,  1.50it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 009.mp4
# The total frames in the video is : 34
#  23%|██▎       | 128/563 [01:34<04:07,  1.76it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1920x1080 - Scene 004.mp4
# The total frames in the video is : 33
#  23%|██▎       | 129/563 [01:35<04:45,  1.52it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1350 - Scene 014.mp4
# The total frames in the video is : 22
#  23%|██▎       | 130/563 [01:35<04:19,  1.67it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 008.mp4
# The total frames in the video is : 15
#  23%|██▎       | 131/563 [01:35<03:45,  1.92it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 016.mp4
# The total frames in the video is : 41
#  23%|██▎       | 132/563 [01:36<04:29,  1.60it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 006.mp4
# The total frames in the video is : 41
#  24%|██▎       | 133/563 [01:37<04:01,  1.78it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080 - Scene 004.mp4
# The total frames in the video is : 18
#  24%|██▍       | 134/563 [01:37<04:16,  1.67it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 023.mp4
# The total frames in the video is : 15
#  24%|██▍       | 135/563 [01:38<03:47,  1.88it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1350 - Scene 003.mp4
# The total frames in the video is : 37
#  24%|██▍       | 136/563 [01:38<04:04,  1.75it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-HitSlideCatchWin_1080x1920 (1) - Scene 002.mp4
# The total frames in the video is : 72
#  24%|██▍       | 137/563 [01:40<05:52,  1.21it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1920 - Scene 004.mp4
# The total frames in the video is : 16
#  25%|██▍       | 138/563 [01:40<04:57,  1.43it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 019.mp4
# The total frames in the video is : 20
#  25%|██▍       | 139/563 [01:41<04:53,  1.45it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1920x1080 - Scene 009.mp4
# The total frames in the video is : 15
#  25%|██▍       | 140/563 [01:41<04:28,  1.58it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080 - Scene 004.mp4
# The total frames in the video is : 65
#  25%|██▌       | 141/563 [01:42<04:32,  1.55it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 011.mp4
# The total frames in the video is : 19
#  25%|██▌       | 142/563 [01:43<04:24,  1.59it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 017.mp4
# The total frames in the video is : 20
#  25%|██▌       | 143/563 [01:43<04:15,  1.65it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1920x1080 - Scene 011.mp4
# The total frames in the video is : 17
#  26%|██▌       | 144/563 [01:44<04:30,  1.55it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 018.mp4
# The total frames in the video is : 49
#  26%|██▌       | 145/563 [01:44<04:10,  1.67it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1080 - Scene 011.mp4
# The total frames in the video is : 33
#  26%|██▌       | 146/563 [01:45<04:06,  1.70it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080 - Scene 005.mp4
# The total frames in the video is : 26
#  26%|██▌       | 147/563 [01:46<03:50,  1.80it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-HitSlideCatchWin_1080x1080 (1) - Scene 009.mp4
# The total frames in the video is : 148
#  26%|██▋       | 148/563 [01:47<05:21,  1.29it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1920x1080 - Scene 003.mp4
# The total frames in the video is : 18
#  26%|██▋       | 149/563 [01:47<05:10,  1.33it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350 - Scene 006.mp4
# The total frames in the video is : 36
#  27%|██▋       | 150/563 [01:48<04:51,  1.42it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1920x1080 - Scene 018.mp4
# The total frames in the video is : 39
#  27%|██▋       | 151/563 [01:49<05:24,  1.27it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1080 - Scene 013.mp4
# The total frames in the video is : 23
#  27%|██▋       | 152/563 [01:50<04:40,  1.46it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1080 - Scene 009.mp4
# The total frames in the video is : 20
#  27%|██▋       | 153/563 [01:50<04:06,  1.66it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 005.mp4
# ...
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 010.mp4
# The total frames in the video is : 18
#  93%|█████████▎| 526/563 [06:29<00:31,  1.18it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920 - Scene 006.mp4
# The total frames in the video is : 179
#  94%|█████████▎| 527/563 [06:32<00:52,  1.45s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080 - Scene 003.mp4
# The total frames in the video is : 63
#  94%|█████████▍| 528/563 [06:33<00:42,  1.21s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080 - Scene 003.mp4
# The total frames in the video is : 29
#  94%|█████████▍| 529/563 [06:33<00:33,  1.02it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350 - Scene 005.mp4
# The total frames in the video is : 36
#  94%|█████████▍| 530/563 [06:34<00:28,  1.16it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 018.mp4
# The total frames in the video is : 49
#  94%|█████████▍| 531/563 [06:35<00:25,  1.24it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920 - Scene 018.mp4
# The total frames in the video is : 49
#  94%|█████████▍| 532/563 [06:35<00:26,  1.19it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1920 - Scene 008.mp4
# The total frames in the video is : 15
#  95%|█████████▍| 533/563 [06:36<00:22,  1.35it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 010.mp4
# The total frames in the video is : 28
#  95%|█████████▍| 534/563 [06:37<00:20,  1.41it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 017.mp4
# The total frames in the video is : 36
#  95%|█████████▌| 535/563 [06:37<00:19,  1.43it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-HitSlideCatchWin_1920x1080 (1) - Scene 007.mp4
# The total frames in the video is : 23
#  95%|█████████▌| 536/563 [06:38<00:18,  1.48it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080 - Scene 006.mp4
# The total frames in the video is : 34
#  95%|█████████▌| 537/563 [06:38<00:14,  1.74it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1350 - Scene 012.mp4
# The total frames in the video is : 17
#  96%|█████████▌| 538/563 [06:39<00:13,  1.89it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 017.mp4
# The total frames in the video is : 20
#  96%|█████████▌| 539/563 [06:39<00:12,  1.95it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_21-02-22-BETTER_THAN_EVER_1920X1080 - Scene 006.mp4
# The total frames in the video is : 46
#  96%|█████████▌| 540/563 [06:40<00:12,  1.82it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-HitSlideCatchWin_1080x1080 (1) - Scene 005.mp4
# The total frames in the video is : 18
#  96%|█████████▌| 541/563 [06:40<00:10,  2.10it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 018.mp4
# The total frames in the video is : 20
#  96%|█████████▋| 542/563 [06:41<00:10,  2.02it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 003.mp4
# The total frames in the video is : 28
#  96%|█████████▋| 543/563 [06:42<00:12,  1.65it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1920 - Scene 005.mp4
# The total frames in the video is : 55
#  97%|█████████▋| 544/563 [06:42<00:12,  1.53it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 021.mp4
# The total frames in the video is : 22
#  97%|█████████▋| 545/563 [06:43<00:10,  1.74it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080 - Scene 003.mp4
# The total frames in the video is : 62
#  97%|█████████▋| 546/563 [06:43<00:09,  1.76it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 025.mp4
# The total frames in the video is : 15
#  97%|█████████▋| 547/563 [06:44<00:08,  1.80it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080 - Scene 005.mp4
# The total frames in the video is : 73
#  97%|█████████▋| 548/563 [06:44<00:08,  1.76it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 005.mp4
# The total frames in the video is : 49
#  98%|█████████▊| 549/563 [06:45<00:07,  1.77it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 016.mp4
# The total frames in the video is : 20
#  98%|█████████▊| 550/563 [06:45<00:06,  2.00it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1350 - Scene 009.mp4
# The total frames in the video is : 47
#  98%|█████████▊| 551/563 [06:46<00:06,  1.81it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080 - Scene 003.mp4
# The total frames in the video is : 86
#  98%|█████████▊| 552/563 [06:47<00:06,  1.76it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 003.mp4
# The total frames in the video is : 28
#  98%|█████████▊| 553/563 [06:47<00:05,  1.84it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1920 - Scene 008.mp4
# The total frames in the video is : 16
#  98%|█████████▊| 554/563 [06:48<00:04,  1.86it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080 - Scene 002.mp4
# The total frames in the video is : 36
#  99%|█████████▊| 555/563 [06:48<00:04,  1.95it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 006.mp4
# The total frames in the video is : 16
#  99%|█████████▉| 556/563 [06:49<00:03,  1.86it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1920 - Scene 009.mp4
# The total frames in the video is : 47
#  99%|█████████▉| 557/563 [06:49<00:03,  1.57it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 011.mp4
# The total frames in the video is : 20
#  99%|█████████▉| 558/563 [06:50<00:02,  1.69it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 014.mp4
# The total frames in the video is : 19
#  99%|█████████▉| 559/563 [06:51<00:02,  1.65it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Glu_TapBaseball_CinematicOpening_1920x1080_15s - Scene 003.mp4
# The total frames in the video is : 35
#  99%|█████████▉| 560/563 [06:51<00:02,  1.48it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350 - Scene 009.mp4
# The total frames in the video is : 26
# 100%|█████████▉| 561/563 [06:52<00:01,  1.54it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-HitSlideCatchWin_1080x1350 (1) - Scene 005.mp4
# The total frames in the video is : 18
# 100%|█████████▉| 562/563 [06:52<00:00,  1.72it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V2 - Scene 002.mp4
# The total frames in the video is : 111
# 100%|██████████| 563/563 [06:54<00:00,  1.36it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1080 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1920 - Scene 012.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 019.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 011.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_15s - Scene 002.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_21-02-22-BETTER_THAN_EVER_1920X1080 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-HitSlideCatchWin_1080x1920 (1) - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1080 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1920 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-HitSlideCatchWin_1920x1080 (1) - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V1 - Scene 002.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1350 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 012.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1080x1920 - Scene 014.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-HitSlideCatchWin_1080x1350 (1) - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Story Ad 1920x1080 - Scene 002.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1080 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920 - Scene 014.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-Spring in my step 1080x1920 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-TSB20_21-02-22-BETTER_THAN_EVER_1920X1080 - Scene 008.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080 - Scene 002 ...
# 563

# %%
videos_end_train = feature_extractor(files_end)
np.save(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_ARRAY_STORAGE/videos_end_train', videos_end_train)
file_name = f"/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_ARRAY_STORAGE/{ADSET}_files_end"
open_file = open(file_name, "wb")
pickle.dump(files_end, open_file)
open_file.close()

open_file = open(file_name, "rb")
files_end = pickle.load(open_file)
open_file.close()
print(files_end)
print(len(files_end))
# Out:
#   0%|          | 0/109 [00:00<?, ?it/s]
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V2 - Scene 004.mp4
# The total frames in the video is : 130
#   1%|          | 1/109 [00:00<01:43,  1.04it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V2 - Scene 005.mp4
# The total frames in the video is : 131
#   2%|▏         | 2/109 [00:02<01:52,  1.06s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Pulsing Text - Story_v01_Scene 2 - Scene 003.mp4
# The total frames in the video is : 48
#   3%|▎         | 3/109 [00:03<01:51,  1.05s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Pulsing Text - Story_v02_Scene 1 - Scene 002.mp4
# The total frames in the video is : 48
#   4%|▎         | 4/109 [00:04<01:40,  1.05it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920 - Scene 022.mp4
# The total frames in the video is : 60
#   5%|▍         | 5/109 [00:04<01:37,  1.07it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350 - Scene 007.mp4
# The total frames in the video is : 209
#   6%|▌         | 6/109 [00:07<02:17,  1.34s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Story Ad 1080x1920 - Scene 016.mp4
# The total frames in the video is : 34
#   6%|▋         | 7/109 [00:07<01:57,  1.16s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Story Ad_A (2) - Scene 003.mp4
# The total frames in the video is : 26
#   7%|▋         | 8/109 [00:08<01:39,  1.02it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Story Ad_C_v02 - Scene 006.mp4
# The total frames in the video is : 34
#   8%|▊         | 9/109 [00:09<01:31,  1.09it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 013.mp4
# The total frames in the video is : 50
#   9%|▉         | 10/109 [00:10<01:28,  1.12it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Pulsing Text - Story_v01_Scene 4 - Scene 003.mp4
# The total frames in the video is : 82
#  10%|█         | 11/109 [00:11<01:39,  1.01s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 006.mp4
# The total frames in the video is : 63
#  11%|█         | 12/109 [00:12<01:31,  1.06it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080 - Scene 007.mp4
# The total frames in the video is : 63
#  12%|█▏        | 13/109 [00:12<01:18,  1.22it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Not A Cat EN_With End Card - Scene 003.mp4
# The total frames in the video is : 64
#  13%|█▎        | 14/109 [00:13<01:23,  1.13it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1920 - Scene 001.mp4
# The total frames in the video is : 400
#  14%|█▍        | 15/109 [00:16<02:02,  1.30s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s (1) - Scene 001.mp4
# The total frames in the video is : 151
#  15%|█▍        | 16/109 [00:18<02:27,  1.59s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-HitSlideCatchWin_1080x1350 (1) - Scene 009.mp4
# The total frames in the video is : 63
#  16%|█▌        | 17/109 [00:18<02:01,  1.32s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Pulsing Text - Story_v01_Scene 3 - Scene 003.mp4
# The total frames in the video is : 49
#  17%|█▋        | 18/109 [00:20<01:53,  1.25s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 022.mp4
# The total frames in the video is : 60
#  17%|█▋        | 19/109 [00:20<01:37,  1.09s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Spring in my step 1920x1080 - Scene 016.mp4
# The total frames in the video is : 48
#  18%|█▊        | 20/109 [00:21<01:27,  1.01it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1920x1080 - Scene 021.mp4
# The total frames in the video is : 61
#  19%|█▉        | 21/109 [00:22<01:24,  1.04it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1080 - Scene 001.mp4
# The total frames in the video is : 400
#  20%|██        | 22/109 [00:23<01:26,  1.00it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1080 - Scene 004.mp4
# The total frames in the video is : 196
#  21%|██        | 23/109 [00:24<01:35,  1.11s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Spring in my step 1080x1920 - Scene 014.mp4
# The total frames in the video is : 48
#  22%|██▏       | 24/109 [00:25<01:27,  1.03s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1920x1080 - Scene 002.mp4
# The total frames in the video is : 59
#  23%|██▎       | 25/109 [00:26<01:21,  1.04it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080 - Scene 010.mp4
# The total frames in the video is : 63
#  24%|██▍       | 26/109 [00:27<01:09,  1.20it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 010.mp4
# The total frames in the video is : 63
#  25%|██▍       | 27/109 [00:27<00:59,  1.37it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V1 - Scene 004.mp4
# The total frames in the video is : 130
#  26%|██▌       | 28/109 [00:28<01:04,  1.26it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-11-TSB21-SoClose_1080x1350 - Scene 002.mp4
# The total frames in the video is : 64
#  27%|██▋       | 29/109 [00:29<01:01,  1.30it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_15s - Scene 004.mp4
# The total frames in the video is : 239
#  28%|██▊       | 30/109 [00:32<02:05,  1.59s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_3 - Scene 002.mp4
# The total frames in the video is : 56
#  28%|██▊       | 31/109 [00:34<01:59,  1.53s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_4 - Scene 001.mp4
# The total frames in the video is : 151
#  29%|██▉       | 32/109 [00:35<02:04,  1.62s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1920x1080 - Scene 005.mp4
# The total frames in the video is : 58
#  30%|███       | 33/109 [00:36<01:45,  1.38s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1080 - Scene 022.mp4
# The total frames in the video is : 60
#  31%|███       | 34/109 [00:37<01:23,  1.11s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB20_21-02-22-BETTER_THAN_EVER_1920X1080 - Scene 013.mp4
# The total frames in the video is : 127
#  32%|███▏      | 35/109 [00:38<01:23,  1.12s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_15s - Scene 004.mp4
# The total frames in the video is : 239
#  33%|███▎      | 36/109 [00:41<01:55,  1.59s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_1 - Scene 001.mp4
# The total frames in the video is : 96
#  34%|███▍      | 37/109 [00:42<01:45,  1.47s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1080 - Scene 007.mp4
# The total frames in the video is : 209
#  35%|███▍      | 38/109 [00:43<01:45,  1.49s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1920_08 - Scene 001.mp4
# The total frames in the video is : 151
#  36%|███▌      | 39/109 [00:45<01:41,  1.45s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V2 - Scene 003.mp4
# The total frames in the video is : 129
#  37%|███▋      | 40/109 [00:45<01:22,  1.20s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V1 - Scene 005.mp4
# The total frames in the video is : 131
#  38%|███▊      | 41/109 [00:47<01:22,  1.21s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920_SNAP_CHAT_2 - Scene 002.mp4
# The total frames in the video is : 40
#  39%|███▊      | 42/109 [00:47<01:16,  1.14s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1920x1080_01 (1) - Scene 002.mp4
# The total frames in the video is : 59
#  39%|███▉      | 43/109 [00:48<01:08,  1.04s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1920 - Scene 007.mp4
# The total frames in the video is : 209
#  40%|████      | 44/109 [00:51<01:46,  1.64s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-HitSlideCatchWin_1080x1920 (1) - Scene 009.mp4
# The total frames in the video is : 62
#  41%|████▏     | 45/109 [00:52<01:31,  1.42s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Story Ad 1080x1350 - Scene 016.mp4
# The total frames in the video is : 34
#  42%|████▏     | 46/109 [00:53<01:13,  1.16s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_5s - Scene 002.mp4
# The total frames in the video is : 29
#  43%|████▎     | 47/109 [00:53<00:57,  1.08it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1080_01 (1) - Scene 001.mp4
# The total frames in the video is : 151
#  44%|████▍     | 48/109 [00:54<00:54,  1.12it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_01_21_TSB21_3HITS_ACUNA_1920x1080_5s - Scene 003.mp4
# The total frames in the video is : 26
#  45%|████▍     | 49/109 [00:55<00:48,  1.24it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-11-TSB21-SoClose_1920x1080 - Scene 002.mp4
# The total frames in the video is : 63
#  46%|████▌     | 50/109 [00:55<00:49,  1.20it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1080_01 (1) - Scene 001.mp4
# The total frames in the video is : 242
#  47%|████▋     | 51/109 [00:57<01:05,  1.13s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1350_01 (1) - Scene 001.mp4
# The total frames in the video is : 151
#  48%|████▊     | 52/109 [00:58<01:01,  1.08s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1080 - Scene 007.mp4
# The total frames in the video is : 63
#  49%|████▊     | 53/109 [00:59<00:51,  1.09it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1080x1350 - Scene 012.mp4
# The total frames in the video is : 50
#  50%|████▉     | 54/109 [00:59<00:45,  1.20it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1920_03 - Scene 001.mp4
# The total frames in the video is : 151
#  50%|█████     | 55/109 [01:01<01:02,  1.17s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Spring in my step 1080x1080 - Scene 016.mp4
# The total frames in the video is : 48
#  51%|█████▏    | 56/109 [01:02<00:50,  1.04it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1350_01 (1) - Scene 001.mp4
# The total frames in the video is : 242
#  52%|█████▏    | 57/109 [01:05<01:17,  1.50s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-05-19-TSB21_SERIOUS_PiP_SP_1080x1350 - Scene 007.mp4
# The total frames in the video is : 33
#  53%|█████▎    | 58/109 [01:05<01:00,  1.19s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Pulsing Text - Story_v02_Scene 2 - Scene 003.mp4
# The total frames in the video is : 48
#  54%|█████▍    | 59/109 [01:06<00:52,  1.06s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1920x1080_01 (1) - Scene 001.mp4
# The total frames in the video is : 151
#  55%|█████▌    | 60/109 [01:07<00:53,  1.09s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Pulsing Text - Story_v02_Scene 4 - Scene 003.mp4
# The total frames in the video is : 82
#  56%|█████▌    | 61/109 [01:08<00:55,  1.16s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Story Ad 1080x1080 - Scene 016.mp4
# The total frames in the video is : 34
#  57%|█████▋    | 62/109 [01:09<00:44,  1.07it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1920 - Scene 005.mp4
# The total frames in the video is : 62
#  58%|█████▊    | 63/109 [01:10<00:43,  1.06it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-26-TSB21-MegaLevelUp_1080x1080 - Scene 008.mp4
# The total frames in the video is : 61
#  59%|█████▊    | 64/109 [01:10<00:36,  1.23it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB21-159_TikTok-Jump-Out-Of-Uniform_002_1080x1080 - Scene 008.mp4
# The total frames in the video is : 33
#  60%|█████▉    | 65/109 [01:11<00:29,  1.48it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-HitSlideCatchWin_1080x1080 (1) - Scene 011.mp4
# The total frames in the video is : 62
#  61%|██████    | 66/109 [01:11<00:26,  1.60it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V3 - Scene 003.mp4
# The total frames in the video is : 129
#  61%|██████▏   | 67/109 [01:12<00:26,  1.60it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1080_15s - Scene 004.mp4
# The total frames in the video is : 239
#  62%|██████▏   | 68/109 [01:14<00:41,  1.01s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-11-TSB21-SoClose_1080x1080 - Scene 003.mp4
# The total frames in the video is : 63
#  63%|██████▎   | 69/109 [01:14<00:34,  1.16it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-05-17-TSB21_YOU_NOT_MUTED_1920x1080 - Scene 002.mp4
# The total frames in the video is : 43
#  64%|██████▍   | 70/109 [01:15<00:31,  1.24it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1080_V1 - Scene 003.mp4
# The total frames in the video is : 130
#  65%|██████▌   | 71/109 [01:15<00:28,  1.32it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Pulsing Text - Story_v02_Full video - Scene 012.mp4
# The total frames in the video is : 81
#  66%|██████▌   | 72/109 [01:17<00:33,  1.09it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V3 - Scene 005.mp4
# The total frames in the video is : 131
#  67%|██████▋   | 73/109 [01:18<00:36,  1.02s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1920x1080 - Scene 005.mp4
# The total frames in the video is : 63
#  68%|██████▊   | 74/109 [01:19<00:34,  1.00it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350 - Scene 001.mp4
# The total frames in the video is : 400
#  69%|██████▉   | 75/109 [01:21<00:40,  1.19s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1920 - Scene 007.mp4
# The total frames in the video is : 62
#  70%|██████▉   | 76/109 [01:22<00:37,  1.13s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB20_210323v_1920x1080_20s - Scene 027.mp4
# The total frames in the video is : 52
#  71%|███████   | 77/109 [01:22<00:33,  1.04s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB21-144_Lets-Relax(EN)_20s_1080x1080 - Scene 011.mp4
# The total frames in the video is : 33
#  72%|███████▏  | 78/109 [01:23<00:25,  1.20it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB21-159_TikTok-Jump-Into-Uniform_1080x1080 - Scene 008.mp4
# The total frames in the video is : 33
#  72%|███████▏  | 79/109 [01:23<00:20,  1.45it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-05-19-TSB21_SERIOUS_SP_1080x1350 - Scene 006.mp4
# The total frames in the video is : 33
#  73%|███████▎  | 80/109 [01:24<00:18,  1.56it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GM_210209v_TSBSoyLaBestia-R07_18s_1080x1920 - Scene 011.mp4
# The total frames in the video is : 50
#  74%|███████▍  | 81/109 [01:24<00:19,  1.44it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Glu_TapBaseball_CinematicOpening_1920x1080_15s - Scene 006.mp4
# The total frames in the video is : 57
#  75%|███████▌  | 82/109 [01:25<00:19,  1.38it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Not A Cat SP_V08 - Scene 004.mp4
# The total frames in the video is : 64
#  76%|███████▌  | 83/109 [01:26<00:19,  1.34it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1350 - Scene 005.mp4
# The total frames in the video is : 63
#  77%|███████▋  | 84/109 [01:27<00:18,  1.35it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1920x1080_01 (1) - Scene 001.mp4
# The total frames in the video is : 151
#  78%|███████▊  | 85/109 [01:28<00:22,  1.09it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Pulsing Text - Story_v02_Scene 3 - Scene 003.mp4
# The total frames in the video is : 49
#  79%|███████▉  | 86/109 [01:29<00:19,  1.17it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1350_5s - Scene 002.mp4
# The total frames in the video is : 29
#  80%|███████▉  | 87/109 [01:29<00:16,  1.33it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video1_1080x1080_01 (1) - Scene 001.mp4
# The total frames in the video is : 151
#  81%|████████  | 88/109 [01:30<00:15,  1.39it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1920x1080 - Scene 007.mp4
# The total frames in the video is : 63
#  82%|████████▏ | 89/109 [01:31<00:15,  1.29it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Story Ad 1920x1080 - Scene 014.mp4
# The total frames in the video is : 34
#  83%|████████▎ | 90/109 [01:32<00:14,  1.33it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s - Scene 002.mp4
# The total frames in the video is : 29
#  83%|████████▎ | 91/109 [01:32<00:12,  1.41it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1920 - Scene 005.mp4
# The total frames in the video is : 196
#  84%|████████▍ | 92/109 [01:35<00:23,  1.36s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-11-TSB21-SoClose_1080x1920 - Scene 002.mp4
# The total frames in the video is : 62
#  85%|████████▌ | 93/109 [01:36<00:20,  1.25s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Spring in my step 1080x1350 - Scene 016.mp4
# The total frames in the video is : 48
#  86%|████████▌ | 94/109 [01:37<00:15,  1.05s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB21-144_Lets-Relax(SP)_20s_1080x1080 - Scene 011.mp4
# The total frames in the video is : 33
#  87%|████████▋ | 95/109 [01:37<00:11,  1.19it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video3_1080x1920_04 - Scene 001.mp4
# The total frames in the video is : 242
#  88%|████████▊ | 96/109 [01:40<00:20,  1.61s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Pulsing Text - Story_v01_Scene 1 - Scene 002.mp4
# The total frames in the video is : 49
#  89%|████████▉ | 97/109 [01:41<00:17,  1.46s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB20_210323v_1080x1350_20s - Scene 026.mp4
# The total frames in the video is : 52
#  90%|████████▉ | 98/109 [01:42<00:13,  1.23s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-03-10-21_TSB21-TeamPower_1920x1080 (1) - Scene 004.mp4
# The total frames in the video is : 63
#  91%|█████████ | 99/109 [01:43<00:11,  1.14s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-05-17-TSB21_SERIOUS_PiP_1080x1350 - Scene 007.mp4
# The total frames in the video is : 33
#  92%|█████████▏| 100/109 [01:44<00:08,  1.06it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB20_210323v_1080x1920_20s - Scene 027.mp4
# The total frames in the video is : 52
#  93%|█████████▎| 101/109 [01:44<00:07,  1.08it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1920x1080 - Scene 008.mp4
# The total frames in the video is : 59
#  94%|█████████▎| 102/109 [01:45<00:06,  1.11it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Pulsing Text - Story_v01_Full video - Scene 012.mp4
# The total frames in the video is : 76
#  94%|█████████▍| 103/109 [01:47<00:05,  1.01it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1350 - Scene 004.mp4
# The total frames in the video is : 196
#  95%|█████████▌| 104/109 [01:49<00:06,  1.36s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB20_210323v_1080x1080_20s - Scene 027.mp4
# The total frames in the video is : 52
#  96%|█████████▋| 105/109 [01:49<00:04,  1.09s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GluMobile_TSB20_WhichPlayerAreYou_video2_1080x1350_01 (1) - Scene 001.mp4
# The total frames in the video is : 151
#  97%|█████████▋| 106/109 [01:51<00:03,  1.17s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V3 - Scene 004.mp4
# The total frames in the video is : 130
#  98%|█████████▊| 107/109 [01:51<00:02,  1.09s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-HitSlideCatchWin_1920x1080 (1) - Scene 009.mp4
# The total frames in the video is : 63
#  99%|█████████▉| 108/109 [01:52<00:01,  1.03s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_01_TSB21_3HITS_SOTO_1080x1080 - Scene 006.mp4
# The total frames in the video is : 63
# 100%|██████████| 109/109 [01:53<00:00,  1.04s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_16_TSB21_3HITS_SOTO_1080x1350_V2 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_16__TSB21_3HITS_SOTO_1080x1920_V2 - Scene 005.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Pulsing Text - Story_v01_Scene 2 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Pulsing Text - Story_v02_Scene 1 - Scene 002.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1920 - Scene 022.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_01_26_TSB21_3HITS_SCREEN_TRANSITION_1080x1350 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Story Ad 1080x1920 - Scene 016.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Story Ad_A (2) - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Story Ad_C_v02 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-GM_210205v_TSBSoyLaBestia-R07_16s_1920x1080 - Scene 013.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Pulsing Text - Story_v01_Scene 4 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 006.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-03_07_21_TSB21_It_Keeper_Time_1080x1080 - Scene 007.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Not A Cat EN_With End Card - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1920 - Scene 001.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Glu_TapBaseball_CinematicOpening_1080x1920_5s (1) - Scene 001.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-HitSlideCatchWin_1080x1350 (1) - Scene 009.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Pulsing Text - Story_v01_Scene 3 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1080x1350 - Scene 022.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Spring in my step 1920x1080 - Scene 016.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB20_20210319_Step It Up_30s_AL_1920x1080 - Scene 021.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1080 - Scene 001.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21_02_01_TSB21_3HITS_ACUNA_1080x1080 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-Spring in my step 1080x1920 - Scene 014.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1920x1080 - Scene 002.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB21-40_Gameplay-Build-Your-Team_17s_1080x1080 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-TSB21-37_Jaws_Soto_20sec_1080x1080 - Scene 010.mp4', '/content/gdrive/MyDrive/Scene- ...
# 109

# %%
videos_mid_train = np.load(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_ARRAY_STORAGE/videos_mid_train.npy')  
print(videos_mid_train.shape)

videos_end_train = np.load(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_ARRAY_STORAGE/videos_end_train.npy')  
print(videos_end_train.shape)
# Out:
# (563, 19200)
# (109, 19200)

# %%
videos_mid_train = videos_mid_train[[list(df_mid_performance.index[df_mid_performance['dimension'] == target_size])]]
videos_end_train = videos_end_train[[list(df_end_performance.index[df_end_performance['dimension'] == target_size])]]

list_m = list(df_mid_performance.index[df_mid_performance['dimension'] == target_size])
#print(list_m)
files_mid = [files_mid[i] for i in list_m]
list_e = list(df_end_performance.index[df_end_performance['dimension'] == target_size])
#print(list_e)
files_end = [files_end[i] for i in list_e]

# %%
print(videos_mid_train.shape)
print(videos_end_train.shape)
print(len(files_mid))
print(len(files_end))
# Out:
# (127, 19200)
# (24, 19200)
# 127
# 24

# %% [markdown]
# ### Feature Extraction for target

# %%
videos_test = feature_extractor(target)
print(videos_test.shape)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/Unseen_Start/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 001.mp4
# The total frames in the video is : 90
# 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# (1, 19200)

# %%
def array_file_merge(video_array,target_array,files_train,target): 
  array = np.concatenate((video_array,target_array),axis=0)
  print(array.shape)
  files_t = files_train + target
  print(len(files_t))
  return array, files_t

# %%
arr_mid, files_t = array_file_merge(videos_mid_train,videos_test,files_mid,target)
# Out:
# (128, 19200)
# 128

# %%
# compute cosine similarities between videos
def cos(arr,files):
  cosSimilarities = cosine_similarity(arr)

  # store the results into a pandas dataframe

  cos_similarities_df = pd.DataFrame(cosSimilarities, columns=files, index=files)
  print(cos_similarities_df.shape)
  return cos_similarities_df

# %%
# function to retrieve the most similar video to the given
M = []
E = []

def retrieve_most_similar_videos(arr,files,given_video,position,nb_closest_videos):

    cos_similarities_df = cos(arr,files)
    print("*********************************")
    print("Original Add Video:")
    print("*********************************")
    print(given_video)
    print("-----------------------------------------------------------------------")
    print("Most Similar Video Recommended:")

    closest_videos = cos_similarities_df[given_video].sort_values(ascending=False)[1:nb_closest_videos+1].index
    closest_videos_scores = cos_similarities_df[given_video].sort_values(ascending=False)[1:nb_closest_videos+1]

    for i in range(0,len(closest_videos)):
        print(closest_videos[i])
        #Get performance data from the performance dataframe
        try:
          if position == 'mid':
            perf = float(df_mid_performance.query("files_path == '{a}'".format(a=closest_videos[i])).performance)
            print('The global performance of video :',perf)
            performance_score.append(perf)
          elif position == 'end':
            perf = float(df_end_performance.query("files_path == '{a}'".format(a=closest_videos[i])).performance)
            print('The global performance of video :',perf)
            performance_score.append(perf)
        except:
            performance_score.append(0)

        if position == 'mid':
          M.append(closest_videos[i])
        elif position == 'end':
          E.append(closest_videos[i])
        print("Cosine Similarity Score: ",closest_videos_scores[i])
        print('---------------------------------------------------------------------')

# %%
MIDDLE_SCENES = []
performance_score = []
start_index = len(files_t)-1
#print(start_index)
for clip in range(No_of_mid_scenes):
  
  retrieve_most_similar_videos(arr_mid,files_t,files_t[start_index],'mid',3)
  print(M)
  print(performance_score)
  MIDDLE = M[performance_score.index(max(performance_score))]
  print(MIDDLE)
  MIDDLE_SCENES.append(MIDDLE)
  M = []
  performance_score = []
 # start_index = files_t.index(M[-1])
 # print("Start index",start_index)
  start_index = files_t.index(MIDDLE_SCENES[-1])
  print("Start index",start_index)
# Out:
# (128, 128)
# *********************************
# Original Add Video:
# *********************************
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/Unseen_Start/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 001.mp4
# -----------------------------------------------------------------------
# Most Similar Video Recommended:
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 004.mp4
# The global performance of video : 0.0
# Cosine Similarity Score:  0.8930363
# ---------------------------------------------------------------------
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 003.mp4
# The global performance of video : 0.0
# Cosine Similarity Score:  0.87242925
# ---------------------------------------------------------------------
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 002.mp4
# The global performance of video : 0.0
# Cosine Similarity Score:  0.86224884
# ---------------------------------------------------------------------
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 002.mp4']
# [0.0, 0.0, 0.0]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 004.mp4
# Start index 68
# (128, 128)
# *********************************
# Original Add Video:
# *********************************
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 004.mp4
# -----------------------------------------------------------------------
# Most Similar Video Recommended:
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 003.mp4
# The global performance of video : 0.0
# Cosine Similarity Score:  0.90598047
# ---------------------------------------------------------------------
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 002.mp4
# The global performance of video : 0.0
# Cosine Similarity Score:  0.9055444
# ---------------------------------------------------------------------
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/Unseen_Start/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 001.mp4
# Cosine Similarity Score:  0.8930363
# ---------------------------------------------------------------------
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 002.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/Unseen_Start/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 001.mp4']
# [0.0, 0.0, 0]
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 003.mp4
# Start index 46

# %%
print('$$$$$$$$$$$$$$$$')
print(performance_score)
print(len(performance_score))
print('$$$$$$$$$$$$$$$$')
print(M)
print(len(M))
print('$$$$$$$$$$$$$$$$')
print(MIDDLE_SCENES)
print(len(MIDDLE_SCENES))
# Out:
# $$$$$$$$$$$$$$$$
# []
# 0
# $$$$$$$$$$$$$$$$
# []
# 0
# $$$$$$$$$$$$$$$$
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 003.mp4']
# 2

# %%
#retrieve_most_similar_videos(arr_mid,files_t,files_t[len(files_t)-1],'mid',1)

# %%
#M

# %%
#files_t.index(M[0])

# %%
#retrieve_most_similar_videos(arr_mid,files_t,files_t[15],'mid',1)

# %%
#M

# %%
#files_t.index(M[1])

# %%
#retrieve_most_similar_videos(arr_mid,files_t,files_t[20],'mid',1)

# %%
target1 = MIDDLE_SCENES[-1:]
#target1 = target[-1:]
target1
# Out:
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 003.mp4']

# %%
videos_test = feature_extractor(target1)
print(videos_test.shape)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# The name of the video is : /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 003.mp4
# The total frames in the video is : 41
# 100%|██████████| 1/1 [00:00<00:00,  1.32it/s]
# features successfully extracted!
# (10, 1920)
# (1, 19200)
# (1, 19200)

# %%
arr_end, files_t1 = array_file_merge(videos_end_train,videos_test,files_end,target1)
# Out:
# (25, 19200)
# 25

# %%
retrieve_most_similar_videos(arr_end,files_t1,files_t1[len(files_t1)-1],'end',1)
# Out:
# (25, 25)
# *********************************
# Original Add Video:
# *********************************
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 003.mp4
# -----------------------------------------------------------------------
# Most Similar Video Recommended:
# /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350 - Scene 001.mp4
# The global performance of video : 0.0
# Cosine Similarity Score:  0.6725702
# ---------------------------------------------------------------------

# %% [markdown]
# # RESTICHING PREDICTED SCENES BACK

# %%
# Name of the directory where we want the splitted scenes to reside
if not os.path.exists(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_RESULT'):
    os.makedirs(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_RESULT')

# %%
print(target)
print(M)
print(MIDDLE_SCENES)
print(E)
# Out:
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/Unseen_Start/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 001.mp4']
# []
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 003.mp4']
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350 - Scene 001.mp4']

# %%
S = target

clip = VideoFileClip(S[0])      
# getting only first 5 seconds
clip = clip.subclip(0, 5) 
# getting clip size
height, width = clip.size
print("Height is :",height,"Width is :",width)

#res = S + M + E
res = S + MIDDLE_SCENES + E 

RESULT = []
[RESULT.append(x) for x in res if x not in RESULT]
print(RESULT)
print("Total scenes in result are :",len(RESULT))
# Out:
# Height is : 720 Width is : 900
# ['/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/Unseen_Start/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 001.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 004.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/MID/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 - Scene 003.mp4', '/content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_Training_Data/END/act_472592610491195-21-03-12-TSB21-SoClose_TopView_1080x1350 - Scene 001.mp4']
# Total scenes in result are : 4

# %%
counter = 0
final = []
for video in RESULT:
  video = VideoFileClip("{a}".format(a=video))
  print(video.size)
  video = video.resize( (height,width) )
  video = video.audio_fadein(2.0)
  video = video.audio_fadeout(2.0)
  final.append(video)
  counter += 1

print(final)
# Out:
# [720, 900]
# [720, 900]
# [720, 900]
# [720, 900]
# [<moviepy.video.io.VideoFileClip.VideoFileClip object at 0x7f8f6b267910>, <moviepy.video.io.VideoFileClip.VideoFileClip object at 0x7f8f6b270090>, <moviepy.video.io.VideoFileClip.VideoFileClip object at 0x7f8f6b270410>, <moviepy.video.io.VideoFileClip.VideoFileClip object at 0x7f8f6a1e8650>]

# %% [markdown]
# # RESULTS

# %%
final_video= concatenate_videoclips(final)
final_video.write_videofile(f'/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_RESULT/video_merge.mp4')
# Out:
# [MoviePy] >>>> Building video /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_RESULT/video_merge.mp4
# [MoviePy] Writing audio in video_mergeTEMP_MPY_wvf_snd.mp3
# 100%|██████████| 445/445 [00:00<00:00, 840.08it/s]
# [MoviePy] Done.
# [MoviePy] Writing video /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_RESULT/video_merge.mp4
# 100%|██████████| 605/605 [00:11<00:00, 50.81it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_RESULT/video_merge.mp4

# %%
# showing final clip
final_video.ipython_display(width = 480)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
videoclip = VideoFileClip(f"/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_RESULT/video_merge.mp4")
#clip_duration = videoclip.duration
#audioclip = AudioFileClip("/content/gdrive/MyDrive/Scene_Detection/music.mp3").set_duration(clip_duration)

#new_audioclip = CompositeAudioClip([audioclip])
#videoclip.audio = new_audioclip

name_start_index = target[0].index("act_")
name_end_index = target[0].index("- S")
videoclip.write_videofile(f"/content/gdrive/MyDrive/Scene-Detection-Version-2/{ADSET}_RESULT/{target[0][name_start_index:name_end_index]}.mp4")
# Out:
# [MoviePy] >>>> Building video /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_RESULT/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 .mp4
# [MoviePy] Writing audio in act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 TEMP_MPY_wvf_snd.mp3
# 100%|██████████| 445/445 [00:00<00:00, 834.78it/s]
# [MoviePy] Done.
# [MoviePy] Writing video /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_RESULT/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 .mp4
# 100%|██████████| 606/606 [00:10<00:00, 55.97it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: /content/gdrive/MyDrive/Scene-Detection-Version-2/TSP_RESULT/act_472592610491195-03-15-21_TSB21_Target_Bash_Meme_1080x1350 .mp4

# %%
# showing final clip
videoclip.ipython_display(width = 480)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
