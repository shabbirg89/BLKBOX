# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ADSET = 'LLC'

# %% [markdown]
# # Code for video Download from Text file

# %%
with open(f"/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}.txt") as file_in:
    lines = []
    for line in file_in:
      line = line.strip()
      lines.append(line)

lines = [name for name in lines if name.endswith('.mp4')]
lines
# Out:
# ['https://gallery-pm.go-game.io/uploads/2020/10/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/10/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/11/LLC_LightningLinkMultipleIP_V28685_15_English_Portrait&IMG=M4T.mp4',
#  'https://gallery-pm.go-game.io/uploads/2018/11/LLC_UA_V723_15_No%20Language_Square&IMG=K3.mp4',
#  'https://gallery-pm.go-game.io/uploads/2019/08/20190620_LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/04/LLC_BuffaloDeluxe_V20593_15_English_Portrait&IMG=FW1.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/01/LLC_BuffaloDeluxe_V30648_15_English_Square&IMG=NNC.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/02/LLC_LightningLinkMultipleIP_V31163_15_English_Portrait&IMG=O1N.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/11/LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/01/LLC_BuffaloDeluxe_V30647_15_English_Portrait&IMG=NNB.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/07/LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/11/LLC_LightningLinkMultipleIP_V28686_15_English_Square&IMG=M4U.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/07/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/11/LLC_LightningLinkMultipleIP_V28694_15_English_Portrait&IMG=M52.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/09/LLC_BuffaloDeluxe_V25786_15_English_Square&IMG=JWA.mp4',
#  'https://gallery-pm.go-game.io/uploads/2020/11/LLC_LightningLinkMultipleIP_V28688_15_English_Portrait&IMG=M4W.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31903_30_English_Portr&IMG=OM7.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31902_30_English_Portr&IMG=OM6.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31887_17_English_Portr&IMG=OLR.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31886_17_English_Squar&IMG=OLQ.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31885_17_English_Lands&IMG=OLP.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31884_17_English_Lands&IMG=OLO.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN.mp4',
#  'https://gallery-pm.go-game.io/uploads/2021/03/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31882_17_English_Portr&IMG=OLM.mp4']

# %%
len(lines)
# Out:
# 36

# %%
import os
if not os.path.exists(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ADS'):
    os.makedirs(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ADS')

# %%
import requests
import time
from tqdm import tqdm

# %%
def download(url,name):
  r = requests.get(url, allow_redirects=True)
  open(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ADS/{name}.mp4', 'wb').write(r.content)
  print("Download_Complete :",name)

# %%
count=0
for url in tqdm(lines):
    name_start_index = url.index(f"{ADSET}")
    name_end_index = url.index(".mp4") 
    download(url=url,name=url[name_start_index:name_end_index:1])
    count += 1
    time.sleep(2)
# Out:
#   0%|          | 0/36 [00:00<?, ?it/s]
# Download_Complete : LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6
#   3%|▎         | 1/36 [00:05<02:55,  5.01s/it]
# Download_Complete : LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5
#   6%|▌         | 2/36 [00:08<02:30,  4.44s/it]
# Download_Complete : LLC_LightningLinkMultipleIP_V28685_15_English_Portrait&IMG=M4T
#   8%|▊         | 3/36 [00:12<02:22,  4.33s/it]
# Download_Complete : LLC_UA_V723_15_No%20Language_Square&IMG=K3
#  11%|█         | 4/36 [00:16<02:22,  4.44s/it]
# Download_Complete : LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4
#  14%|█▍        | 5/36 [00:20<02:07,  4.10s/it]
# Download_Complete : LLC_BuffaloDeluxe_V20593_15_English_Portrait&IMG=FW1
#  17%|█▋        | 6/36 [00:23<01:55,  3.85s/it]
# Download_Complete : LLC_BuffaloDeluxe_V30648_15_English_Square&IMG=NNC
#  19%|█▉        | 7/36 [00:28<02:02,  4.22s/it]
# Download_Complete : LLC_LightningLinkMultipleIP_V31163_15_English_Portrait&IMG=O1N
#  22%|██▏       | 8/36 [00:32<01:57,  4.19s/it]
# Download_Complete : LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY
#  25%|██▌       | 9/36 [00:39<02:10,  4.85s/it]
# Download_Complete : LLC_WildChuco_V28769_15_English_Square&IMG=M75
#  28%|██▊       | 10/36 [00:43<02:03,  4.74s/it]
# Download_Complete : LLC_BuffaloDeluxe_V30647_15_English_Portrait&IMG=NNB
#  31%|███       | 11/36 [00:47<01:53,  4.54s/it]
# Download_Complete : LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ
#  33%|███▎      | 12/36 [00:52<01:52,  4.67s/it]
# Download_Complete : LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2
#  36%|███▌      | 13/36 [00:58<01:52,  4.91s/it]
# Download_Complete : LLC_LightningLinkMultipleIP_V28686_15_English_Square&IMG=M4U
#  39%|███▉      | 14/36 [01:01<01:39,  4.51s/it]
# Download_Complete : LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV
#  42%|████▏     | 15/36 [01:06<01:38,  4.67s/it]
# Download_Complete : LLC_LightningLinkMultipleIP_V28694_15_English_Portrait&IMG=M52
#  44%|████▍     | 16/36 [01:11<01:31,  4.58s/it]
# Download_Complete : LLC_BuffaloDeluxe_V25786_15_English_Square&IMG=JWA
#  47%|████▋     | 17/36 [01:14<01:23,  4.37s/it]
# Download_Complete : LLC_LightningLinkMultipleIP_V28688_15_English_Portrait&IMG=M4W
#  50%|█████     | 18/36 [01:18<01:14,  4.14s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF
#  53%|█████▎    | 19/36 [01:24<01:18,  4.62s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME
#  56%|█████▌    | 20/36 [01:28<01:12,  4.52s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD
#  58%|█████▊    | 21/36 [01:32<01:04,  4.28s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC
#  61%|██████    | 22/36 [01:36<00:57,  4.11s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB
#  64%|██████▍   | 23/36 [01:39<00:51,  3.94s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9
#  67%|██████▋   | 24/36 [01:44<00:49,  4.15s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31903_30_English_Portr&IMG=OM7
#  69%|██████▉   | 25/36 [01:50<00:53,  4.90s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31902_30_English_Portr&IMG=OM6
#  72%|███████▏  | 26/36 [01:55<00:48,  4.81s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5
#  75%|███████▌  | 27/36 [01:59<00:42,  4.68s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU
#  78%|███████▊  | 28/36 [02:05<00:38,  4.85s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT
#  81%|████████  | 29/36 [02:09<00:32,  4.66s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS
#  83%|████████▎ | 30/36 [02:12<00:25,  4.29s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31887_17_English_Portr&IMG=OLR
#  86%|████████▌ | 31/36 [02:17<00:22,  4.56s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31886_17_English_Squar&IMG=OLQ
#  89%|████████▉ | 32/36 [02:22<00:17,  4.49s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31885_17_English_Lands&IMG=OLP
#  92%|█████████▏| 33/36 [02:26<00:13,  4.34s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31884_17_English_Lands&IMG=OLO
#  94%|█████████▍| 34/36 [02:29<00:08,  4.12s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN
#  97%|█████████▋| 35/36 [02:34<00:04,  4.15s/it]
# Download_Complete : LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31882_17_English_Portr&IMG=OLM
# 100%|██████████| 36/36 [02:38<00:00,  4.42s/it]

# %% [markdown]
# # Code for Downloaded ADSET VIDEO SPLITTING INTO SCENES USING PYSCENEDETECT

# %%
from tqdm import tqdm
import time
import os

# %%
# Name of the directory where we want the splitted scenes to reside
if not os.path.exists(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_F_DATA'):
    os.makedirs(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_F_DATA')

# %%
def list_full_paths(directory):
    return [os.path.join(directory, file) for file in os.listdir(directory)]

videos = list_full_paths(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ADS')

# %%
data = os.listdir(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ADS')

# %%
videos = [video for video in videos if video.endswith('.mp4')]
data = [name for name in data if name.endswith('.mp4')]
print(len(videos))

print(len(data))
# Out:
# 36
# 36

# %%
print(data)
print()
print(videos)
# Out:
# ['LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4', 'LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4', 'LLC_LightningLinkMultipleIP_V28685_15_English_Portrait&IMG=M4T.mp4', 'LLC_UA_V723_15_No%20Language_Square&IMG=K3.mp4', 'LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4', 'LLC_BuffaloDeluxe_V20593_15_English_Portrait&IMG=FW1.mp4', 'LLC_BuffaloDeluxe_V30648_15_English_Square&IMG=NNC.mp4', 'LLC_LightningLinkMultipleIP_V31163_15_English_Portrait&IMG=O1N.mp4', 'LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4', 'LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4', 'LLC_BuffaloDeluxe_V30647_15_English_Portrait&IMG=NNB.mp4', 'LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4', 'LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4', 'LLC_LightningLinkMultipleIP_V28686_15_English_Square&IMG=M4U.mp4', 'LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4', 'LLC_LightningLinkMultipleIP_V28694_15_English_Portrait&IMG=M52.mp4', 'LLC_BuffaloDeluxe_V25786_15_English_Square&IMG=JWA.mp4', 'LLC_LightningLinkMultipleIP_V28688_15_English_Portrait&IMG=M4W.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31903_30_English_Portr&IMG=OM7.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31902_30_English_Portr&IMG=OM6.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31887_17_English_Portr&IMG=OLR.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31886_17_English_Squar&IMG=OLQ.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31885_17_English_Lands&IMG=OLP.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31884_17_English_Lands&IMG=OLO.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN.mp4', 'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31882_17_English_Portr&IMG=OLM.mp4']
#
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_LightningLinkMultipleIP_V28685_15_English_Portrait&IMG=M4T.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_UA_V723_15_No%20Language_Square&IMG=K3.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_BuffaloDeluxe_V20593_15_English_Portrait&IMG=FW1.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_BuffaloDeluxe_V30648_15_English_Square&IMG=NNC.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_LightningLinkMultipleIP_V31163_15_English_Portrait&IMG=O1N.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_BuffaloDeluxe_V30647_15_English_Portrait&IMG=NNB.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_LightningLinkMultipleIP_V28686_15_English_Square&IMG=M4U.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_LightningLinkMultipleIP_V28694_15_English_Portrait&IMG=M52.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_BuffaloDeluxe_V25786_15_English_Square&IMG=JWA.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_LightningLinkMultipleIP_V28688_15_English_Portrait&IMG=M4W.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31903_30_English_Portr&IMG=OM7.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31902_30_English_Portr&IMG=OM6.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS.mp4', ...

# %%
# !pip install scenedetect
# Out:
# Collecting scenedetect
#   Downloading https://files.pythonhosted.org/packages/ec/d2/de12be595765235bfbab66d111db7dd390e334dbf4b60986e41003dc9c0b/scenedetect-0.5.5-py2.py3-none-any.whl (107kB)
#      |████████████████████████████████| 112kB 4.0MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from scenedetect) (4.41.1)
# Requirement already satisfied: Click in /usr/local/lib/python3.7/dist-packages (from scenedetect) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from scenedetect) (1.19.5)
# Installing collected packages: scenedetect
# Successfully installed scenedetect-0.5.5

# %%
from scenedetect import VideoManager
from scenedetect.video_splitter import split_video_ffmpeg
from scenedetect import SceneManager

# %%
from scenedetect.detectors import ContentDetector

# %%
def find_scenes(video_path, threshold = 45.0):
    # Create our video & scene managers, then add the detector.
    video_manager = VideoManager([video_path])
    scene_manager = SceneManager()
    scene_manager.add_detector(
        ContentDetector(threshold=threshold))

    # Improve processing speed by downscaling before processing.
    video_manager.set_downscale_factor()

    # Start the video manager and perform the scene detection.
    video_manager.start()
    scene_manager.detect_scenes(frame_source=video_manager)

    # Each returned scene is a tuple of the (start, end) timecode.
    return scene_manager.get_scene_list()

# %%
def split_scenes(video_path, scene_list, name):
  # print(scene_list)
  # print(os.getcwd())
    os.chdir(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_F_DATA')
  # print(os.getcwd())
    
    if not os.path.exists(name):
        os.makedirs(name)
    print(os.getcwd())
    os.chdir(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_F_DATA/{name}')
    print(os.getcwd())
    split_video_ffmpeg([video_path], scene_list = scene_list, 
      output_file_template = '$VIDEO_NAME - Scene $SCENE_NUMBER.mp4', video_name = name)
    # Each returned scene is a tuple of the (start, end) timecode.
    return True

# %%
print(videos[1])
print(data[1])
# Out:
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_ADS/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4
# LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4

# %%
counter = 0
for video in videos:
    video_path = video
    scenes = find_scenes(video_path)
    split_scenes(video_path, scenes, data[counter])
    counter += 1
    time.sleep(3)
# Out:
# 100%|██████████| 510/510 [00:02<00:00, 200.63frames/s]
#   0%|          | 0/510 [00:00<?, ?frame/s]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4
# 100%|██████████| 510/510 [00:14<00:00, 35.20frame/s]
#   0%|          | 0/450 [00:00<?, ?frames/s]
#   3%|▎         | 12/450 [00:00<00:03, 119.03frames/s]
#   6%|▌         | 27/450 [00:00<00:03, 125.08frames/s]
#   9%|▉         | 41/450 [00:00<00:03, 127.57frames/s]
#  13%|█▎        | 58/450 [00:00<00:02, 134.74frames/s]
#  16%|█▌        | 72/450 [00:00<00:02, 134.25frames/s]
#  19%|█▉        | 87/450 [00:00<00:02, 135.04frames/s]
#  23%|██▎       | 102/450 [00:00<00:02, 138.05frames/s]
#  26%|██▌       | 117/450 [00:00<00:02, 140.31frames/s]
#  30%|██▉       | 133/450 [00:00<00:02, 145.10frames/s]
#  34%|███▍      | 152/450 [00:01<00:01, 154.61frames/s]
#  37%|███▋      | 168/450 [00:01<00:01, 149.97frames/s]
#  41%|████▏     | 186/450 [00:01<00:01, 157.40frames/s]
#  45%|████▍     | 202/450 [00:01<00:01, 142.77frames/s]
#  48%|████▊     | 217/450 [00:01<00:01, 133.12frames/s]
#  52%|█████▏    | 232/450 [00:01<00:01, 136.32frames/s]
#  55%|█████▍    | 246/450 [00:01<00:01, 136.79frames/s]
#  58%|█████▊    | 262/450 [00:01<00:01, 141.05frames/s]
#  62%|██████▏   | 278/450 [00:01<00:01, 144.99frames/s]
#  65%|██████▌   | 294/450 [00:02<00:01, 147.11frames/s]
#  69%|██████▊   | 309/450 [00:02<00:00, 146.07frames/s]
#  72%|███████▏  | 326/450 [00:02<00:00, 152.00frames/s]
#  76%|███████▌  | 342/450 [00:02<00:00, 148.54frames/s]
#  80%|███████▉  | 358/450 [00:02<00:00, 151.26frames/s]
#  83%|████████▎ | 374/450 [00:02<00:00, 150.35frames/s]
#  87%|████████▋ | 390/450 [00:02<00:00, 146.19frames/s]
#  90%|█████████ | 406/450 [00:02<00:00, 148.38frames/s]
#  94%|█████████▍| 422/450 [00:02<00:00, 149.92frames/s]
# 100%|██████████| 450/450 [00:03<00:00, 146.67frames/s]
#
#   0%|          | 0/450 [00:00<?, ?frame/s]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4
#  28%|██▊       | 124/450 [00:05<00:14, 23.23frame/s]
#  36%|███▌      | 162/450 [00:07<00:12, 22.95frame/s]
#  60%|█████▉    | 269/450 [00:11<00:07, 23.31frame/s]
#  78%|███████▊  | 353/450 [00:15<00:04, 22.73frame/s]
# 100%|██████████| 450/450 [00:18<00:00, 24.80frame/s]
#   0%|          | 0/450 [00:00<?, ?frames/s]
#
#   3%|▎         | 13/450 [00:00<00:03, 126.49frames/s]
#
#   6%|▌         | 28/450 [00:00<00:03, 132.39frames/s]
#
#   9%|▉         | 42/450 [00:00<00:03, 131.79frames/s]
#
#  13%|█▎        | 58/450 [00:00<00:02, 138.34frames/s]
#
#  16%|█▌        | 70/450 [00:00<00:02, 130.77frames/s]
#
#  19%|█▉        | 86/450 [00:00<00:02, 136.85frames/s]
#
#  22%|██▏       | 100/450 [00:00<00:02, 137.01frames/s]
#
#  26%|██▌       | 115/450 [00:00<00:02, 140.52frames/s]
#
#  29%|██▊       | 129/450 [00:00<00:02, 140.23frames/s]
#
#  32%|███▏      | 146/450 [00:01<00:02, 146.76frames/s]
#
#  36%|███▌      | 161/450 [00:01<00:01, 145.72frames/s]
#
#  39%|███▉      | 176/450 [00:01<00:01, 146.94frames/s]
#
#  42%|████▏     | 191/450 [00:01<00:01, 144.29frames/s]
#
#  46%|████▌     | 207/450 [00:01<00:01, 146.77frames/s]
#
#  49%|████▉     | 222/450 [00:01<00:01, 146.72frames/s]
#
#  53%|█████▎    | 239/450 [00:01<00:01, 150.31frames/s]
#
#  57%|█████▋    | 255/450 [00:01<00:01, 144.86frames/s]
#
#  60%|██████    | 270/450 [00:01<00:01, 144.78frames/s]
#
#  64%|██████▍   | 288/450 [00:01<00:01, 153.05frames/s]
#
#  68%|██████▊   | 304/450 [00:02<00:00, 150.26frames/s]
#
#  71%|███████   | 320/450 [00:02<00:00, 148.72frames/s]
#
#  74%|███████▍  | 335/450 [00:02<00:00, 143.80frames/s]
#
#  78%|███████▊  | 352/450 [00:02<00:00, 149.93frames/s]
#
#  82%|████████▏ | 368/450 [00:02<00:00, 148.50frames/s]
#
#  86%|████████▌ | 385/450 [00:02<00:00, 152.91frames/s]
#
#  89%|████████▉ | 401/450 [00:02<00:00, 149.03frames/s]
#
#  94%|█████████▎| 421/450 [00:02<00:00, 157.72frames/s]
#
# 100%|██████████| 450/450 [00:02<00:00, 150.41frames/s]
#
#
#   0%|          | 0/450 [00:00<?, ?frame/s]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V28685_15_English_Portrait&IMG=M4T.mp4
#  87%|████████▋ | 390/450 [00:10<00:01, 36.04frame/s]
#
# 100%|██████████| 450/450 [00:12<00:00, 35.43frame/s]
#   0%|          | 0/450 [00:00<?, ?frames/s]
#
#
#   4%|▎         | 16/450 [00:00<00:02, 157.09frames/s]
#
#
#   7%|▋         | 33/450 [00:00<00:02, 160.26frames/s]
#
#
#  12%|█▏        | 52/450 [00:00<00:02, 167.19frames/s]
#
#
#  16%|█▌        | 71/450 [00:00<00:02, 171.30frames/s]
#
#
#  20%|█▉        | 89/450 [00:00<00:02, 172.62frames/s]
#
#
#  23%|██▎       | 105/450 [00:00<00:02, 163.81frames/s]
#
#
#  27%|██▋       | 120/450 [00:00<00:02, 157.98frames/s]
#
#
#  30%|███       | 137/450 [00:00<00:01, 161.19frames/s]
#
#
#  34%|███▍      | 153/450 [00:00<00:01, 160.11frames/s]
#
#
#  38%|███▊      | 171/450 [00:01<00:01, 164.00frames/s]
#
#
#  42%|████▏     | 188/450 [00:01<00:01, 154.01frames/s]
#
#
#  46%|████▌     | 206/450 [00:01<00:01, 160.12frames/s]
#
#
#  50%|████▉     | 224/450 [00:01<00:01, 164.57frames/s]
#
#
#  54%|█████▍    | 242/450 [00:01<00:01, 168.08frames/s]
#
#
#  58%|█████▊    | 263/450 [00:01<00:01, 177.02frames/s]
#
#
#  63%|██████▎   | 282/450 [00:01<00:00, 179.29frames/s]
#
#
#  67%|██████▋   | 301/450 [00:01<00:00, 180.19frames/s]
#
#
#  71%|███████▏  | 321/450 [00:01<00:00, 184.93frames/s]
#
#
#  76%|███████▌  | 341/450 [00:01<00:00, 188.45frames/s]
#
#
#  80%|████████  | 362/450 [00:02<00:00, 193.50frames/s]
#
#
#  85%|████████▍ | 382/450 [00:02<00:00, 191.34frames/s]
#
#
#  89%|████████▉ | 402/450 [00:02<00:00, 189.78frames/s]
#
#
#  94%|█████████▍| 422/450 [00:02<00:00, 190.10frames/s]
#
#
# 100%|██████████| 450/450 [00:02<00:00, 177.04frames/s]
#
#
#
#   0%|          | 0/450 [00:00<?, ?frame/s]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_UA_V723_15_No%20Language_Square&IMG=K3.mp4
#  79%|███████▉  | 355/450 [00:09<00:02, 38.26frame/s]
#
#
#  85%|████████▍ | 382/450 [00:10<00:02, 33.49frame/s]
#
#
# 100%|██████████| 450/450 [00:12<00:00, 34.28frame/s]
#   0%|          | 0/450 [00:00<?, ?frames/s]
#
#
#
#   4%|▎         | 16/450 [00:00<00:02, 152.12frames/s]
#
#
#
#   8%|▊         | 37/450 [00:00<00:02, 161.10frames/s]
#
#
#
#  12%|█▏        | 56/450 [00:00<00:02, 168.55frames/s]
#
#
#
#  16%|█▌        | 71/450 [00:00<00:02, 160.10frames/s]
#
#
#
#  19%|█▊        | 84/450 [00:00<00:02, 149.01frames/s]
#
#
#
#  22%|██▏       | 100/450 [00:00<00:02, 151.37frames/s]
#
#
#
#  26%|██▌       | 115/450 [00:00<00:02, 150.71frames/s]
#
#
#
#  30%|███       | 135/450 [00:00<00:01, 161.93frames/s]
#
#
#
#  35%|███▌      | 159/450 [00:00<00:01, 175.53frames/s]
#
#
#
#  39%|███▉      | 177/450 [00:01<00:01, 164.83frames/s]
#
#
#
#  43%|████▎     | 194/450 [00:01<00:01, 163.93frames/s]
#
#
#
#  48%|████▊     | 215/450 [00:01<00:01, 174.05frames/s]
#
#
#
#  52%|█████▏    | 233/450 [00:01<00:01, 171.92frames/s]
#
#
#
#  56%|█████▌    | 251/450 [00:01<00:01, 168.70frames/s]
#
#
#
#  60%|█████▉    | 268/450 [00:01<00:01, 164.92frames/s]
#
#
#
#  64%|██████▍   | 289/450 [00:01<00:00, 173.41frames/s]
#
#
#
#  69%|██████▉   | 310/450 [00:01<00:00, 182.59frames/s]
#
#
#
#  73%|███████▎  | 329/450 [00:01<00:00, 179.82frames/s]
#
#
#
#  77%|███████▋  | 348/450 [00:02<00:00, 172.69frames/s]
#
#
#
#  81%|████████▏ | 366/450 [00:02<00:00, 169.22frames/s]
#
#
#
#  86%|████████▌ | 385/450 [00:02<00:00, 174.81frames/s]
#
#
#
#  90%|█████████ | 405/450 [00:02<00:00, 180.15frames/s]
#
#
#
#  94%|█████████▍| 424/450 [00:02<00:00, 172.68frames/s]
#
#
#
# 100%|██████████| 450/450 [00:02<00:00, 171.44frames/s]
#
#
#
#
#   0%|          | 0/450 [00:00<?, ?frame/s]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4
# 100%|██████████| 450/450 [00:09<00:00, 47.13frame/s]
#   0%|          | 0/450 [00:00<?, ?frames/s]
#
#
#
#
#   2%|▏         | 11/450 [00:00<00:04, 109.34frames/s]
#
#
#
#
#   6%|▌         | 25/450 [00:00<00:03, 115.62frames/s]
#
#
#
#
#   8%|▊         | 37/450 [00:00<00:03, 116.67frames/s]
#
#
#
#
#  11%|█▏        | 51/450 [00:00<00:03, 121.90frames/s]
#
#
#
#
#  14%|█▍        | 65/450 [00:00<00:03, 125.87frames/s]
#
#
#
#
#  18%|█▊        | 81/450 [00:00<00:02, 132.44frames/s]
#
#
#
#
#  21%|██▏       | 96/450 [00:00<00:02, 136.18frames/s]
#
#
#
#
#  25%|██▍       | 111/450 [00:00<00:02, 139.59frames/s]
#
#
#
#
#  28%|██▊       | 125/450 [00:00<00:02, 137.81frames/s]
#
#
#
#
#  32%|███▏      | 143/450 [00:01<00:02, 145.67frames/s]
#
#
#
#
#  35%|███▌      | 158/450 [00:01<00:02, 140.12frames/s]
#
#
#
#
#  38%|███▊      | 173/450 [00:01<00:01, 142.61frames/s]
#
#
#
#
#  42%|████▏     | 188/450 [00:01<00:01, 142.45frames/s]
#
#
#
#
#  45%|████▌     | 203/450 [00:01<00:01, 140.09frames/s]
#
#
#
#
#  48%|████▊     | 218/450 [00:01<00:01, 141.26frames/s]
#
#
#
#
#  52%|█████▏    | 233/450 [00:01<00:01, 143.65frames/s]
#
#
#
#
#  55%|█████▌    | 248/450 [00:01<00:01, 145.28frames/s]
#
#
#
#
#  59%|█████▊    | 264/450 [00:01<00:01, 147.99frames/s]
#
#
#
#
#  62%|██████▏   | 280/450 [00:01<00:01, 148.02frames/s]
#
#
#
#
#  66%|██████▌   | 295/450 [00:02<00:01, 145.98frames/s]
#
#
#
#
#  69%|██████▉   | 310/450 [00:02<00:00, 141.73frames/s]
#
#
#
#
#  72%|███████▏  | 325/450 [00:02<00:00, 141.44frames/s]
#
#
#
#
#  76%|███████▌  | 340/450 [00:02<00:00, 139.72frames/s]
#
#
#
#
#  79%|███████▉  | 357/450 [00:02<00:00, 143.40frames/s]
#
#
#
#
#  83%|████████▎ | 372/450 [00:02<00:00, 138.09frames/s]
#
#
#
#
#  86%|████████▌ | 387/450 [00:02<00:00, 137.81frames/s]
#
#
#
#
#  89%|████████▉ | 401/450 [00:02<00:00, 137.09frames/s]
#
#
#
#
#  92%|█████████▏| 415/450 [00:02<00:00, 135.66frames/s]
#
#
#
#
#  95%|█████████▌| 429/450 [00:03<00:00, 135.52frames/s]
#
#
#
#
# 100%|██████████| 450/450 [00:03<00:00, 140.27frames/s]
#
#
#
#
#
#   0%|          | 0/450 [00:00<?, ?frame/s]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V20593_15_English_Portrait&IMG=FW1.mp4
#  32%|███▏      | 146/450 [00:04<00:09, 30.97frame/s]
#
#
#
#
#  60%|█████▉    | 268/450 [00:10<00:06, 27.14frame/s]
#
#
#
#
# 100%|██████████| 450/450 [00:17<00:00, 26.50frame/s]
#   0%|          | 0/450 [00:00<?, ?frames/s]
#
#
#
#
#
#   4%|▎         | 16/450 [00:00<00:02, 157.06frames/s]
#
#
#
#
#
#   7%|▋         | 32/450 [00:00<00:02, 156.41frames/s]
#
#
#
#
#
#  11%|█         | 49/450 [00:00<00:02, 158.37frames/s]
#
#
#
#
#
#  15%|█▌        | 69/450 [00:00<00:02, 168.01frames/s]
#
#
#
#
#
#  19%|█▉        | 87/450 [00:00<00:02, 170.27frames/s]
#
#
#
#
#
#  23%|██▎       | 105/450 [00:00<00:02, 170.01frames/s]
#
#
#
#
#
#  27%|██▋       | 123/450 [00:00<00:01, 172.05frames/s]
#
#
#
#
#
#  31%|███▏      | 141/450 [00:00<00:01, 170.61frames/s]
#
#
#
#
#
#  35%|███▌      | 158/450 [00:00<00:01, 167.01frames/s]
#
#
#
#
#
#  39%|███▉      | 176/450 [00:01<00:01, 170.08frames/s]
#
#
#
#
#
#  43%|████▎     | 193/450 [00:01<00:01, 168.96frames/s]
#
#
#
#
#
#  47%|████▋     | 210/450 [00:01<00:01, 163.88frames/s]
#
#
#
#
#
#  51%|█████     | 228/450 [00:01<00:01, 166.03frames/s]
#
#
#
#
#
#  55%|█████▍    | 247/450 [00:01<00:01, 170.16frames/s]
#
#
#
#
#
#  59%|█████▉    | 265/450 [00:01<00:01, 172.06frames/s]
#
#
#
#
#
#  63%|██████▎   | 283/450 [00:01<00:00, 170.85frames/s]
#
#
#
#
#
#  67%|██████▋   | 301/450 [00:01<00:00, 170.57frames/s]
#
#
#
#
#
#  71%|███████   | 319/450 [00:01<00:00, 170.81frames/s]
#
#
#
#
#
#  75%|███████▍  | 337/450 [00:02<00:00, 161.79frames/s]
#
#
#
#
#
#  79%|███████▉  | 355/450 [00:02<00:00, 165.51frames/s]
#
#
#
#
#
#  83%|████████▎ | 372/450 [00:02<00:00, 165.83frames/s]
#
#
#
#
#
#  86%|████████▋ | 389/450 [00:02<00:00, 164.85frames/s]
#
#
#
#
#
#  91%|█████████ | 408/450 [00:02<00:00, 169.11frames/s]
#
#
#
#
#
#  95%|█████████▍| 427/450 [00:02<00:00, 174.43frames/s]
#
#
#
#
#
# 100%|██████████| 450/450 [00:02<00:00, 170.19frames/s]
#
#
#
#
#
#
#   0%|          | 0/450 [00:00<?, ?frame/s]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V30648_15_English_Square&IMG=NNC.mp4
#   4%|▎         | 16/450 [00:00<00:18, 23.78frame/s]
#
#
#
#
#
#  31%|███       | 140/450 [00:04<00:12, 25.71frame/s]
#
#
#
#
#
#  36%|███▌      | 163/450 [00:05<00:11, 24.86frame/s]
#
#
#
#
#
# 100%|██████████| 450/450 [00:14<00:00, 26.79frame/s]
#   0%|          | 0/450 [00:00<?, ?frames/s]
#
#
#
#
#
#
#   3%|▎         | 15/450 [00:00<00:03, 141.64frames/s]
#
#
#
#
#
#
#   7%|▋         | 30/450 [00:00<00:03, 139.00frames/s]
#
#
#
#
#
#
#  10%|█         | 46/450 [00:00<00:02, 141.62frames/s]
#
#
#
#
#
#
#  13%|█▎        | 60/450 [00:00<00:02, 132.54frames/s]
#
#
#
#
#
#
#  17%|█▋        | 76/450 [00:00<00:02, 137.50frames/s]
#
#
#
#
#
#
#  20%|██        | 91/450 [00:00<00:02, 140.02frames/s]
#
#
#
#
#
#
#  24%|██▎       | 106/450 [00:00<00:02, 140.59frames/s]
#
#
#
#
#
#
#  27%|██▋       | 120/450 [00:00<00:02, 137.78frames/s]
#
#
#
#
#
#
#  31%|███       | 138/450 [00:00<00:02, 147.81frames/s]
#
#
#
#
#
#
#  34%|███▍      | 154/450 [00:01<00:01, 151.04frames/s]
#
#
#
#
#
#
#  38%|███▊      | 169/450 [00:01<00:01, 147.96frames/s]
#
#
#
#
#
#
#  41%|████      | 184/450 [00:01<00:01, 141.00frames/s]
#
#
#
#
#
#
#  44%|████▍     | 199/450 [00:01<00:01, 143.57frames/s]
#
#
#
#
#
#
#  48%|████▊     | 214/450 [00:01<00:01, 138.96frames/s]
#
#
#
#
#
#
#  51%|█████     | 230/450 [00:01<00:01, 143.43frames/s]
#
#
#
#
#
#
#  54%|█████▍    | 245/450 [00:01<00:01, 137.31frames/s]
#
#
#
#
#
#
#  58%|█████▊    | 259/450 [00:01<00:01, 136.99frames/s]
#
#
#
#
#
#
#  61%|██████    | 273/450 [00:01<00:01, 133.95frames/s]
#
#
#
#
#
#
#  65%|██████▍   | 292/450 [00:02<00:01, 145.59frames/s]
#
#
#
#
#
#
#  68%|██████▊   | 307/450 [00:02<00:00, 145.24frames/s]
#
#
#
#
#
#
#  72%|███████▏  | 324/450 [00:02<00:00, 150.07frames/s]
#
#
#
#
#
#
#  76%|███████▌  | 340/450 [00:02<00:00, 144.31frames/s]
#
#
#
#
#
#
#  79%|███████▉  | 355/450 [00:02<00:00, 143.67frames/s]
#
#
#
#
#
#
#  82%|████████▏ | 370/450 [00:02<00:00, 136.44frames/s]
#
#
#
#
#
#
#  87%|████████▋ | 390/450 [00:02<00:00, 146.49frames/s]
#
#
#
#
#
#
#  91%|█████████ | 409/450 [00:02<00:00, 156.49frames/s]
#
#
#
#
#
#
#  95%|█████████▍| 426/450 [00:02<00:00, 148.33frames/s]
#
#
#
#
#
#
# 100%|██████████| 450/450 [00:03<00:00, 145.02frames/s]
#
#
#
#
#
#
#
#   0%|          | 0/450 [00:00<?, ?frame/s]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V31163_15_English_Portrait&IMG=O1N.mp4
# 100%|██████████| 450/450 [00:11<00:00, 40.90frame/s]
#   0%|          | 0/900 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#   1%|          | 9/900 [00:00<00:10, 86.08frames/s]
#
#
#
#
#
#
#
#   2%|▏         | 20/900 [00:00<00:09, 90.32frames/s]
#
#
#
#
#
#
#
#   4%|▎         | 32/900 [00:00<00:08, 96.85frames/s]
#
#
#
#
#
#
#
#   5%|▍         | 43/900 [00:00<00:08, 100.13frames/s]
#
#
#
#
#
#
#
#   6%|▌         | 55/900 [00:00<00:08, 103.47frames/s]
#
#
#
#
#
#
#
#   8%|▊         | 68/900 [00:00<00:07, 109.32frames/s]
#
#
#
#
#
#
#
#   9%|▉         | 81/900 [00:00<00:07, 114.33frames/s]
#
#
#
#
#
#
#
#  10%|█         | 94/900 [00:00<00:06, 117.50frames/s]
#
#
#
#
#
#
#
#  12%|█▏        | 108/900 [00:00<00:06, 122.27frames/s]
#
#
#
#
#
#
#
#  13%|█▎        | 121/900 [00:01<00:06, 121.89frames/s]
#
#
#
#
#
#
#
#  15%|█▍        | 134/900 [00:01<00:06, 122.77frames/s]
#
#
#
#
#
#
#
#  16%|█▋        | 147/900 [00:01<00:06, 120.84frames/s]
#
#
#
#
#
#
#
#  18%|█▊        | 160/900 [00:01<00:06, 111.13frames/s]
#
#
#
#
#
#
#
#  19%|█▉        | 172/900 [00:01<00:07, 102.81frames/s]
#
#
#
#
#
#
#
#  20%|██        | 183/900 [00:01<00:07, 100.84frames/s]
#
#
#
#
#
#
#
#  22%|██▏       | 196/900 [00:01<00:06, 106.49frames/s]
#
#
#
#
#
#
#
#  23%|██▎       | 207/900 [00:01<00:06, 107.28frames/s]
#
#
#
#
#
#
#
#  24%|██▍       | 218/900 [00:01<00:06, 107.72frames/s]
#
#
#
#
#
#
#
#  26%|██▌       | 231/900 [00:02<00:05, 111.74frames/s]
#
#
#
#
#
#
#
#  27%|██▋       | 243/900 [00:02<00:05, 113.99frames/s]
#
#
#
#
#
#
#
#  28%|██▊       | 256/900 [00:02<00:05, 117.11frames/s]
#
#
#
#
#
#
#
#  30%|██▉       | 269/900 [00:02<00:05, 120.56frames/s]
#
#
#
#
#
#
#
#  31%|███▏      | 282/900 [00:02<00:05, 120.24frames/s]
#
#
#
#
#
#
#
#  33%|███▎      | 295/900 [00:02<00:04, 122.33frames/s]
#
#
#
#
#
#
#
#  34%|███▍      | 308/900 [00:02<00:04, 120.39frames/s]
#
#
#
#
#
#
#
#  36%|███▌      | 321/900 [00:02<00:04, 118.66frames/s]
#
#
#
#
#
#
#
#  37%|███▋      | 333/900 [00:02<00:05, 110.19frames/s]
#
#
#
#
#
#
#
#  38%|███▊      | 345/900 [00:03<00:05, 106.37frames/s]
#
#
#
#
#
#
#
#  40%|███▉      | 356/900 [00:03<00:05, 106.46frames/s]
#
#
#
#
#
#
#
#  41%|████      | 367/900 [00:03<00:04, 107.40frames/s]
#
#
#
#
#
#
#
#  42%|████▏     | 380/900 [00:03<00:04, 111.15frames/s]
#
#
#
#
#
#
#
#  44%|████▎     | 392/900 [00:03<00:04, 112.78frames/s]
#
#
#
#
#
#
#
#  45%|████▌     | 406/900 [00:03<00:04, 119.41frames/s]
#
#
#
#
#
#
#
#  47%|████▋     | 419/900 [00:03<00:03, 120.49frames/s]
#
#
#
#
#
#
#
#  48%|████▊     | 432/900 [00:03<00:03, 119.63frames/s]
#
#
#
#
#
#
#
#  49%|████▉     | 445/900 [00:03<00:03, 120.34frames/s]
#
#
#
#
#
#
#
#  51%|█████     | 458/900 [00:04<00:03, 115.18frames/s]
#
#
#
#
#
#
#
#  52%|█████▏    | 470/900 [00:04<00:03, 114.96frames/s]
#
#
#
#
#
#
#
#  54%|█████▎    | 482/900 [00:04<00:03, 116.08frames/s]
#
#
#
#
#
#
#
#  55%|█████▌    | 496/900 [00:04<00:03, 121.26frames/s]
#
#
#
#
#
#
#
#  57%|█████▋    | 511/900 [00:04<00:03, 125.32frames/s]
#
#
#
#
#
#
#
#  58%|█████▊    | 525/900 [00:04<00:02, 127.55frames/s]
#
#
#
#
#
#
#
#  60%|█████▉    | 538/900 [00:04<00:02, 127.19frames/s]
#
#
#
#
#
#
#
#  61%|██████    | 551/900 [00:04<00:02, 127.88frames/s]
#
#
#
#
#
#
#
#  63%|██████▎   | 566/900 [00:04<00:02, 132.65frames/s]
#
#
#
#
#
#
#
#  64%|██████▍   | 580/900 [00:04<00:02, 128.81frames/s]
#
#
#
#
#
#
#
#  66%|██████▌   | 593/900 [00:05<00:02, 128.38frames/s]
#
#
#
#
#
#
#
#  67%|██████▋   | 606/900 [00:05<00:02, 121.77frames/s]
#
#
#
#
#
#
#
#  69%|██████▉   | 619/900 [00:05<00:02, 117.73frames/s]
#
#
#
#
#
#
#
#  70%|███████   | 631/900 [00:05<00:02, 116.46frames/s]
#
#
#
#
#
#
#
#  72%|███████▏  | 644/900 [00:05<00:02, 118.84frames/s]
#
#
#
#
#
#
#
#  73%|███████▎  | 657/900 [00:05<00:02, 120.48frames/s]
#
#
#
#
#
#
#
#  74%|███████▍  | 670/900 [00:05<00:01, 117.43frames/s]
#
#
#
#
#
#
#
#  76%|███████▌  | 684/900 [00:05<00:01, 122.47frames/s]
#
#
#
#
#
#
#
#  77%|███████▋  | 697/900 [00:05<00:01, 120.79frames/s]
#
#
#
#
#
#
#
#  79%|███████▉  | 711/900 [00:06<00:01, 124.54frames/s]
#
#
#
#
#
#
#
#  80%|████████  | 724/900 [00:06<00:01, 125.26frames/s]
#
#
#
#
#
#
#
#  82%|████████▏ | 737/900 [00:06<00:01, 126.20frames/s]
#
#
#
#
#
#
#
#  83%|████████▎ | 750/900 [00:06<00:01, 126.61frames/s]
#
#
#
#
#
#
#
#  85%|████████▍ | 763/900 [00:06<00:01, 123.17frames/s]
#
#
#
#
#
#
#
#  86%|████████▌ | 776/900 [00:06<00:01, 114.67frames/s]
#
#
#
#
#
#
#
#  88%|████████▊ | 788/900 [00:06<00:01, 107.35frames/s]
#
#
#
#
#
#
#
#  89%|████████▉ | 799/900 [00:06<00:00, 106.62frames/s]
#
#
#
#
#
#
#
#  90%|█████████ | 811/900 [00:06<00:00, 106.57frames/s]
#
#
#
#
#
#
#
#  91%|█████████▏| 823/900 [00:07<00:00, 109.85frames/s]
#
#
#
#
#
#
#
#  93%|█████████▎| 836/900 [00:07<00:00, 113.34frames/s]
#
#
#
#
#
#
#
#  95%|█████████▍| 851/900 [00:07<00:00, 120.29frames/s]
#
#
#
#
#
#
#
#  96%|█████████▌| 865/900 [00:07<00:00, 122.34frames/s]
#
#
#
#
#
#
#
#  98%|█████████▊| 879/900 [00:07<00:00, 125.37frames/s]
#
#
#
#
#
#
#
# 100%|██████████| 900/900 [00:07<00:00, 118.07frames/s]
#
#
#
#
#
#
#
#
#   0%|          | 0/900 [00:00<?, ?frame/s]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4
#   2%|▏         | 16/900 [00:01<01:19, 11.14frame/s]
#
#
#
#
#
#
#
#  16%|█▌        | 140/900 [00:09<01:02, 12.21frame/s]
#
#
#
#
#
#
#
#  50%|████▉     | 447/900 [00:30<00:35, 12.88frame/s]
#
#
#
#
#
#
#
#  51%|█████▏    | 463/900 [00:31<00:37, 11.71frame/s]
#
#
#
#
#
#
#
# 100%|█████████▉| 897/900 [00:58<00:00, 12.76frame/s]
#
#
#
#
#
#
#
# 100%|██████████| 900/900 [00:59<00:00, 10.65frame/s]
#   0%|          | 0/450 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#   4%|▎         | 16/450 [00:00<00:02, 158.47frames/s]
#
#
#
#
#
#
#
#
#   8%|▊         | 35/450 [00:00<00:02, 164.96frames/s]
#
#
#
#
#
#
#
#
#  12%|█▏        | 54/450 [00:00<00:02, 170.19frames/s]
#
#
#
#
#
#
#
#
#  16%|█▌        | 71/450 [00:00<00:02, 163.99frames/s]
#
#
#
#
#
#
#
#
#  19%|█▉        | 87/450 [00:00<00:02, 162.46frames/s]
#
#
#
#
#
#
#
#
#  23%|██▎       | 105/450 [00:00<00:02, 165.93frames/s]
#
#
#
#
#
#
#
#
#  27%|██▋       | 121/450 [00:00<00:02, 164.10frames/s]
#
#
#
#
#
#
#
#
#  31%|███       | 139/450 [00:00<00:01, 164.93frames/s]
#
#
#
#
#
#
#
#
#  34%|███▍      | 155/450 [00:00<00:01, 156.51frames/s]
#
#
#
#
#
#
#
#
#  38%|███▊      | 171/450 [00:01<00:01, 156.38frames/s]
#
#
#
#
#
#
#
#
#  42%|████▏     | 187/450 [00:01<00:01, 157.45frames/s]
#
#
#
#
#
#
#
#
#  46%|████▌     | 205/450 [00:01<00:01, 161.57frames/s]
#
#
#
#
#
#
#
#
#  50%|████▉     | 224/450 [00:01<00:01, 168.69frames/s]
#
#
#
#
#
#
#
#
#  54%|█████▍    | 244/450 [00:01<00:01, 176.32frames/s]
#
#
#
#
#
#
#
#
#  59%|█████▉    | 265/450 [00:01<00:01, 182.78frames/s]
#
#
#
#
#
#
#
#
#  63%|██████▎   | 284/450 [00:01<00:00, 182.29frames/s]
#
#
#
#
#
#
#
#
#  67%|██████▋   | 303/450 [00:01<00:00, 179.62frames/s]
#
#
#
#
#
#
#
#
#  72%|███████▏  | 322/450 [00:01<00:00, 179.29frames/s]
#
#
#
#
#
#
#
#
#  76%|███████▌  | 340/450 [00:02<00:00, 166.51frames/s]
#
#
#
#
#
#
#
#
#  79%|███████▉  | 357/450 [00:02<00:00, 154.53frames/s]
#
#
#
#
#
#
#
#
#  83%|████████▎ | 373/450 [00:02<00:00, 152.30frames/s]
#
#
#
#
#
#
#
#
#  87%|████████▋ | 391/450 [00:02<00:00, 158.11frames/s]
#
#
#
#
#
#
#
#
#  92%|█████████▏| 413/450 [00:02<00:00, 172.07frames/s]
#
#
#
#
#
#
#
#
# 100%|██████████| 450/450 [00:02<00:00, 171.38frames/s]
#
#
#
#
#
#
#
#
#
#   0%|          | 0/450 [00:00<?, ?frame/s]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4
#  32%|███▏      | 144/450 [00:03<00:08, 36.48frame/s]
#
#
#
#
#
#
#
#
#  70%|███████   | 317/450 [00:08<00:03, 36.69frame/s]
#
#
#
#
#
#
#
#
# 100%|██████████| 450/450 [00:12<00:00, 36.45frame/s]
#   0%|          | 0/450 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#   3%|▎         | 12/450 [00:00<00:03, 116.32frames/s]
#
#
#
#
#
#
#
#
#
#   6%|▌         | 27/450 [00:00<00:03, 123.80frames/s]
#
#
#
#
#
#
#
#
#
#   9%|▉         | 42/450 [00:00<00:03, 129.52frames/s]
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 57/450 [00:00<00:02, 133.47frames/s]
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 71/450 [00:00<00:02, 134.24frames/s]
#
#
#
#
#
#
#
#
#
#  19%|█▊        | 84/450 [00:00<00:02, 132.08frames/s]
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 98/450 [00:00<00:02, 132.60frames/s]
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 112/450 [00:00<00:02, 134.19frames/s]
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 126/450 [00:00<00:02, 134.51frames/s]
#
#
#
#
#
#
#
#
#
#  31%|███       | 140/450 [00:01<00:02, 135.52frames/s]
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 154/450 [00:01<00:02, 131.24frames/s]
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 169/450 [00:01<00:02, 133.91frames/s]
#
#
#
#
#
#
#
#
#
#  41%|████      | 183/450 [00:01<00:02, 132.22frames/s]
#
#
#
#
#
#
#
#
#
#  44%|████▍     | 199/450 [00:01<00:01, 139.27frames/s]
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 213/450 [00:01<00:01, 138.61frames/s]
#
#
#
#
#
#
#
#
#
#  51%|█████     | 228/450 [00:01<00:01, 139.51frames/s]
#
#
#
#
#
#
#
#
#
#  54%|█████▍    | 242/450 [00:01<00:01, 137.81frames/s]
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 258/450 [00:01<00:01, 142.33frames/s]
#
#
#
#
#
#
#
#
#
#  61%|██████    | 273/450 [00:01<00:01, 139.75frames/s]
#
#
#
#
#
#
#
#
#
#  64%|██████▍   | 288/450 [00:02<00:01, 139.22frames/s]
#
#
#
#
#
#
#
#
#
#  67%|██████▋   | 302/450 [00:02<00:01, 135.93frames/s]
#
#
#
#
#
#
#
#
#
#  70%|███████   | 316/450 [00:02<00:00, 136.03frames/s]
#
#
#
#
#
#
#
#
#
#  73%|███████▎  | 330/450 [00:02<00:00, 132.71frames/s]
#
#
#
#
#
#
#
#
#
#  77%|███████▋  | 345/450 [00:02<00:00, 136.24frames/s]
#
#
#
#
#
#
#
#
#
#  80%|████████  | 360/450 [00:02<00:00, 137.82frames/s]
#
#
#
#
#
#
#
#
#
#  83%|████████▎ | 375/450 [00:02<00:00, 140.73frames/s]
#
#
#
#
#
#
#
#
#
#  87%|████████▋ | 390/450 [00:02<00:00, 142.65frames/s]
#
#
#
#
#
#
#
#
#
#  90%|█████████ | 406/450 [00:02<00:00, 146.42frames/s]
#
#
#
#
#
#
#
#
#
#  94%|█████████▎| 421/450 [00:03<00:00, 138.72frames/s]
#
#
#
#
#
#
#
#
#
# 100%|██████████| 450/450 [00:03<00:00, 138.84frames/s]
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/450 [00:00<?, ?frame/s]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V30647_15_English_Portrait&IMG=NNB.mp4
#  31%|███       | 140/450 [00:05<00:12, 25.29frame/s]
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 165/450 [00:06<00:12, 23.15frame/s]
#
#
#
#
#
#
#
#
#
# 100%|██████████| 450/450 [00:17<00:00, 23.85frame/s]
#   0%|          | 0/450 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 14/450 [00:00<00:03, 131.93frames/s]
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 28/450 [00:00<00:03, 131.78frames/s]
#
#
#
#
#
#
#
#
#
#
#  11%|█▏        | 51/450 [00:00<00:02, 150.14frames/s]
#
#
#
#
#
#
#
#
#
#
#  15%|█▌        | 69/450 [00:00<00:02, 155.52frames/s]
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 85/450 [00:00<00:02, 154.83frames/s]
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 100/450 [00:00<00:02, 153.10frames/s]
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 120/450 [00:00<00:02, 164.68frames/s]
#
#
#
#
#
#
#
#
#
#
#  30%|███       | 137/450 [00:00<00:01, 165.65frames/s]
#
#
#
#
#
#
#
#
#
#
#  35%|███▍      | 157/450 [00:00<00:01, 173.70frames/s]
#
#
#
#
#
#
#
#
#
#
#  39%|███▉      | 175/450 [00:01<00:01, 170.41frames/s]
#
#
#
#
#
#
#
#
#
#
#  43%|████▎     | 192/450 [00:01<00:01, 169.65frames/s]
#
#
#
#
#
#
#
#
#
#
#  48%|████▊     | 215/450 [00:01<00:01, 182.66frames/s]
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 240/450 [00:01<00:01, 196.08frames/s]
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 261/450 [00:01<00:00, 198.05frames/s]
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 282/450 [00:01<00:00, 193.01frames/s]
#
#
#
#
#
#
#
#
#
#
#  67%|██████▋   | 302/450 [00:01<00:00, 171.43frames/s]
#
#
#
#
#
#
#
#
#
#
#  71%|███████   | 320/450 [00:01<00:00, 165.52frames/s]
#
#
#
#
#
#
#
#
#
#
#  75%|███████▌  | 338/450 [00:01<00:00, 165.93frames/s]
#
#
#
#
#
#
#
#
#
#
#  80%|███████▉  | 359/450 [00:02<00:00, 176.95frames/s]
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 379/450 [00:02<00:00, 181.39frames/s]
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 400/450 [00:02<00:00, 187.62frames/s]
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 420/450 [00:02<00:00, 190.60frames/s]
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 450/450 [00:02<00:00, 179.41frames/s]
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/450 [00:00<?, ?frame/s]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4
#  22%|██▏       | 100/450 [00:02<00:09, 35.47frame/s]
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 115/450 [00:03<00:10, 30.84frame/s]
#
#
#
#
#
#
#
#
#
#
#  41%|████▏     | 186/450 [00:05<00:08, 32.93frame/s]
#
#
#
#
#
#
#
#
#
#
#  78%|███████▊  | 350/450 [00:09<00:02, 34.68frame/s]
#
#
#
#
#
#
#
#
#
#
#  81%|████████  | 365/450 [00:10<00:02, 30.31frame/s]
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 450/450 [00:12<00:00, 33.18frame/s]
#   0%|          | 0/900 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#   1%|          | 10/900 [00:00<00:09, 93.39frames/s]
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 25/900 [00:00<00:08, 104.93frames/s]
#
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 35/900 [00:00<00:08, 103.24frames/s]
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 47/900 [00:00<00:08, 105.56frames/s]
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 59/900 [00:00<00:07, 108.20frames/s]
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 72/900 [00:00<00:07, 112.52frames/s]
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 84/900 [00:00<00:07, 113.88frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 95/900 [00:00<00:07, 112.31frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 108/900 [00:00<00:06, 115.88frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 120/900 [00:01<00:06, 117.01frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▍        | 132/900 [00:01<00:06, 117.29frames/s]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        |
ames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  75%|███████▌  | 385/510 [00:04<00:01, 91.18frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  77%|███████▋  | 395/510 [00:04<00:01, 89.40frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 405/510 [00:04<00:01, 91.33frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  81%|████████▏ | 415/510 [00:04<00:01, 93.08frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  83%|████████▎ | 425/510 [00:04<00:00, 90.17frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  85%|████████▌ | 435/510 [00:04<00:00, 91.48frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  87%|████████▋ | 445/510 [00:05<00:00, 89.94frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 455/510 [00:05<00:00, 86.05frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 464/510 [00:05<00:00, 85.23frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 473/510 [00:05<00:00, 83.00frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 482/510 [00:05<00:00, 82.34frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▋| 491/510 [00:05<00:00, 82.84frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 500/510 [00:05<00:00, 80.25frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 510/510 [00:05<00:00, 86.00frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/510 [00:00<?, ?frame/s]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN.mp4
#  16%|█▌        | 82/510 [00:03<00:19, 21.52frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 216/510 [00:11<00:14, 20.41frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  59%|█████▉    | 302/510 [00:15<00:09, 20.81frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▊ | 452/510 [00:21<00:02, 21.83frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 510/510 [00:24<00:00, 21.07frame/s]
#   0%|          | 0/510 [00:00<?, ?frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 15/510 [00:00<00:03, 145.31frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 28/510 [00:00<00:03, 138.96frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 39/510 [00:00<00:03, 127.55frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|█         | 51/510 [00:00<00:03, 124.37frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 63/510 [00:00<00:03, 121.39frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▌        | 78/510 [00:00<00:03, 125.05frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 91/510 [00:00<00:03, 123.70frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|██        | 103/510 [00:00<00:03, 121.42frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 115/510 [00:00<00:03, 117.06frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 127/510 [00:01<00:03, 114.85frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 139/510 [00:01<00:03, 115.79frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|██▉       | 151/510 [00:01<00:03, 116.37frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 165/510 [00:01<00:02, 121.08frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▌      | 179/510 [00:01<00:02, 123.49frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 192/510 [00:01<00:02, 122.84frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  40%|████      | 205/510 [00:01<00:02, 117.48frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  43%|████▎     | 217/510 [00:01<00:02, 116.92frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  45%|████▌     | 232/510 [00:01<00:02, 124.22frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  48%|████▊     | 245/510 [00:02<00:02, 123.49frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  51%|█████▏    | 262/510 [00:02<00:01, 133.44frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  54%|█████▍    | 276/510 [00:02<00:01, 131.85frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 290/510 [00:02<00:01, 130.64frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  60%|█████▉    | 304/510 [00:02<00:01, 128.24frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 319/510 [00:02<00:01, 132.82frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  65%|██████▌   | 333/510 [00:02<00:01, 131.27frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 347/510 [00:02<00:01, 133.07frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  71%|███████   | 362/510 [00:02<00:01, 136.84frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▍  | 378/510 [00:02<00:00, 141.82frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  77%|███████▋  | 393/510 [00:03<00:00, 135.24frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  80%|████████  | 408/510 [00:03<00:00, 138.40frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  83%|████████▎ | 422/510 [00:03<00:00, 133.89frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  85%|████████▌ | 436/510 [00:03<00:00, 134.84frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  88%|████████▊ | 450/510 [00:03<00:00, 128.77frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 463/510 [00:03<00:00, 124.74frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  93%|█████████▎| 476/510 [00:03<00:00, 122.27frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 489/510 [00:03<00:00, 120.71frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 510/510 [00:04<00:00, 125.81frames/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/510 [00:00<?, ?frame/s]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31882_17_English_Portr&IMG=OLM.mp4
#  16%|█▌        | 82/510 [00:02<00:13, 32.41frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 216/510 [00:07<00:09, 30.25frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  59%|█████▉    | 302/510 [00:10<00:06, 30.79frame/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 510/510 [00:16<00:00, 31.89frame/s]

# %% [markdown]
# # Code to make training Data seperated in START,MID,END folder

# %%
import os
from pathlib import Path
import pandas as pd
import shutil

# %%
image_dir = Path(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_F_DATA')

# %%
total=os.listdir(image_dir)
print(len(total))
total
# Out:
# 36
# ['LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4',
#  'LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4',
#  'LLC_LightningLinkMultipleIP_V28685_15_English_Portrait&IMG=M4T.mp4',
#  'LLC_UA_V723_15_No%20Language_Square&IMG=K3.mp4',
#  'LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4',
#  'LLC_BuffaloDeluxe_V20593_15_English_Portrait&IMG=FW1.mp4',
#  'LLC_BuffaloDeluxe_V30648_15_English_Square&IMG=NNC.mp4',
#  'LLC_LightningLinkMultipleIP_V31163_15_English_Portrait&IMG=O1N.mp4',
#  'LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4',
#  'LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4',
#  'LLC_BuffaloDeluxe_V30647_15_English_Portrait&IMG=NNB.mp4',
#  'LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4',
#  'LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4',
#  'LLC_LightningLinkMultipleIP_V28686_15_English_Square&IMG=M4U.mp4',
#  'LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4',
#  'LLC_LightningLinkMultipleIP_V28694_15_English_Portrait&IMG=M52.mp4',
#  'LLC_BuffaloDeluxe_V25786_15_English_Square&IMG=JWA.mp4',
#  'LLC_LightningLinkMultipleIP_V28688_15_English_Portrait&IMG=M4W.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31903_30_English_Portr&IMG=OM7.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31902_30_English_Portr&IMG=OM6.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31887_17_English_Portr&IMG=OLR.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31886_17_English_Squar&IMG=OLQ.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31885_17_English_Lands&IMG=OLP.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31884_17_English_Lands&IMG=OLO.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN.mp4',
#  'LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31882_17_English_Portr&IMG=OLM.mp4']

# %%
# Name of the directory where we want the splitted scenes to reside
if not os.path.exists(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data'):
    os.makedirs(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data')

# %%
root_path = f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/'
folders = ['START','MID','END','Unseen_Start']
for folder in folders:
    os.mkdir(os.path.join(root_path,folder))

# %%
# Test Paths
total[1]
filepaths = list(pd.Series(list(image_dir.glob(r'{}/*.mp4'.format(total[1]))), name='Filepath').astype(str))
print("All Paths")
print(filepaths)
print("Start Scene")
print(filepaths[0])
print("End Scene")
print(filepaths[-1])
print("Mid Scenes")
print(filepaths[1:-1])
# Out:
# All Paths
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4 - Scene 001.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4 - Scene 002.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4 - Scene 003.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4 - Scene 004.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4 - Scene 005.mp4']
# Start Scene
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4 - Scene 001.mp4
# End Scene
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4 - Scene 005.mp4
# Mid Scenes
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4 - Scene 002.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4 - Scene 003.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4 - Scene 004.mp4']

# %%
#start
for i in total:
    filepaths = list(pd.Series(list(image_dir.glob(r'{}/*.mp4'.format(i))), name='Filepath').astype(str))
    print(filepaths[0])
    shutil.copy2(filepaths[0],f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/START')
# Out:
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V28685_15_English_Portrait&IMG=M4T.mp4/LLC_LightningLinkMultipleIP_V28685_15_English_Portrait&IMG=M4T.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_UA_V723_15_No%20Language_Square&IMG=K3.mp4/LLC_UA_V723_15_No%20Language_Square&IMG=K3.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4/LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V20593_15_English_Portrait&IMG=FW1.mp4/LLC_BuffaloDeluxe_V20593_15_English_Portrait&IMG=FW1.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V30648_15_English_Square&IMG=NNC.mp4/LLC_BuffaloDeluxe_V30648_15_English_Square&IMG=NNC.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V31163_15_English_Portrait&IMG=O1N.mp4/LLC_LightningLinkMultipleIP_V31163_15_English_Portrait&IMG=O1N.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4/LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4/LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V30647_15_English_Portrait&IMG=NNB.mp4/LLC_BuffaloDeluxe_V30647_15_English_Portrait&IMG=NNB.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4/LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V28686_15_English_Square&IMG=M4U.mp4/LLC_LightningLinkMultipleIP_V28686_15_English_Square&IMG=M4U.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V28694_15_English_Portrait&IMG=M52.mp4/LLC_LightningLinkMultipleIP_V28694_15_English_Portrait&IMG=M52.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V25786_15_English_Square&IMG=JWA.mp4/LLC_BuffaloDeluxe_V25786_15_English_Square&IMG=JWA.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V28688_15_English_Portrait&IMG=M4W.mp4/LLC_LightningLinkMultipleIP_V28688_15_English_Portrait&IMG=M4W.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31903_30_English_Portr&IMG=OM7.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31903_30_English_Portr&IMG=OM7.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31902_30_English_Portr&IMG=OM6.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31902_30_English_Portr&IMG=OM6.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31887_17_English_Portr&IMG=OLR.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31887_17_English_Portr&IMG=OLR.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31886_17_English_Squar&IMG=OLQ.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31886_17_English_Squar&IMG=OLQ.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31885_17_English_Lands&IMG=OLP.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31885_17_English_Lands&IMG=OLP.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31884_17_English_Lands&IMG=OLO.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31884_17_English_Lands&IMG=OLO.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31882_17_English_Portr&IMG=OLM.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31882_17_English_Portr&IMG=OLM.mp4 - Scene 001.mp4

# %%
#end
for i in total:
    filepaths = list(pd.Series(list(image_dir.glob(r'{}/*.mp4'.format(i))), name='Filepath').astype(str))
    print(filepaths[-1])
    shutil.copy2(filepaths[-1],f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/END')
# Out:
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4 - Scene 005.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4 - Scene 005.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V28685_15_English_Portrait&IMG=M4T.mp4/LLC_LightningLinkMultipleIP_V28685_15_English_Portrait&IMG=M4T.mp4 - Scene 002.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_UA_V723_15_No%20Language_Square&IMG=K3.mp4/LLC_UA_V723_15_No%20Language_Square&IMG=K3.mp4 - Scene 003.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4/LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V20593_15_English_Portrait&IMG=FW1.mp4/LLC_BuffaloDeluxe_V20593_15_English_Portrait&IMG=FW1.mp4 - Scene 003.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V30648_15_English_Square&IMG=NNC.mp4/LLC_BuffaloDeluxe_V30648_15_English_Square&IMG=NNC.mp4 - Scene 004.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V31163_15_English_Portrait&IMG=O1N.mp4/LLC_LightningLinkMultipleIP_V31163_15_English_Portrait&IMG=O1N.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4/LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4 - Scene 006.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4/LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4 - Scene 003.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V30647_15_English_Portrait&IMG=NNB.mp4/LLC_BuffaloDeluxe_V30647_15_English_Portrait&IMG=NNB.mp4 - Scene 003.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4/LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4 - Scene 006.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4 - Scene 011.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V28686_15_English_Square&IMG=M4U.mp4/LLC_LightningLinkMultipleIP_V28686_15_English_Square&IMG=M4U.mp4 - Scene 002.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4 - Scene 006.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V28694_15_English_Portrait&IMG=M52.mp4/LLC_LightningLinkMultipleIP_V28694_15_English_Portrait&IMG=M52.mp4 - Scene 002.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V25786_15_English_Square&IMG=JWA.mp4/LLC_BuffaloDeluxe_V25786_15_English_Square&IMG=JWA.mp4 - Scene 003.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V28688_15_English_Portrait&IMG=M4W.mp4/LLC_LightningLinkMultipleIP_V28688_15_English_Portrait&IMG=M4W.mp4 - Scene 002.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4 - Scene 010.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4 - Scene 010.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4 - Scene 010.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4 - Scene 008.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4 - Scene 010.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4 - Scene 010.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31903_30_English_Portr&IMG=OM7.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31903_30_English_Portr&IMG=OM7.mp4 - Scene 004.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31902_30_English_Portr&IMG=OM6.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31902_30_English_Portr&IMG=OM6.mp4 - Scene 004.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4 - Scene 006.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU.mp4 - Scene 005.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT.mp4 - Scene 005.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS.mp4 - Scene 005.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31887_17_English_Portr&IMG=OLR.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31887_17_English_Portr&IMG=OLR.mp4 - Scene 004.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31886_17_English_Squar&IMG=OLQ.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31886_17_English_Squar&IMG=OLQ.mp4 - Scene 005.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31885_17_English_Lands&IMG=OLP.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31885_17_English_Lands&IMG=OLP.mp4 - Scene 005.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31884_17_English_Lands&IMG=OLO.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31884_17_English_Lands&IMG=OLO.mp4 - Scene 005.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN.mp4 - Scene 005.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31882_17_English_Portr&IMG=OLM.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31882_17_English_Portr&IMG=OLM.mp4 - Scene 004.mp4

# %%
#mid
for i in total:
    filepaths = list(pd.Series(list(image_dir.glob(r'{}/*.mp4'.format(i))), name='Filepath').astype(str))
    filepaths = filepaths[1:-1]
    print(filepaths[1:-1])
    for c in filepaths:
        shutil.copy2(c,f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/MID')
# Out:
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4 - Scene 003.mp4']
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4 - Scene 003.mp4']
# []
# []
# []
# []
# []
# []
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4/LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4 - Scene 003.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4/LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4 - Scene 004.mp4']
# []
# []
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4/LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4 - Scene 003.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4/LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4 - Scene 004.mp4']
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4 - Scene 003.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4 - Scene 004.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4 - Scene 005.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4 - Scene 006.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4 - Scene 007.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4 - Scene 008.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4 - Scene 009.mp4']
# []
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4 - Scene 003.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4 - Scene 004.mp4']
# []
# []
# []
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4 - Scene 003.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4 - Scene 004.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4 - Scene 005.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4 - Scene 006.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4 - Scene 007.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4 - Scene 008.mp4']
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4 - Scene 003.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4 - Scene 004.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4 - Scene 005.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4 - Scene 006.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4 - Scene 007.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4 - Scene 008.mp4']
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4 - Scene 003.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4 - Scene 004.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4 - Scene 005.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4 - Scene 006.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4 - Scene 007.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4 - Scene 008.mp4']
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4 - Scene 003.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4 - Scene 004.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4 - Scene 005.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4 - Scene 006.mp4']
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4 - Scene 003.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4 - Scene 004.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4 - Scene 005.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4 - Scene 006.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4 - Scene 007.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4 - Scene 008.mp4']
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4 - Scene 003.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4 - Scene 004.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4 - Scene 005.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4 - Scene 006.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4 - Scene 007.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4 - Scene 008.mp4']
# []
# []
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4 - Scene 003.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4 - Scene 004.mp4']
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU.mp4 - Scene 003.mp4']
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT.mp4 - Scene 003.mp4']
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS.mp4 - Scene 003.mp4']
# []
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31886_17_English_Squar&IMG=OLQ.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31886_17_English_Squar&IMG=OLQ.mp4 - Scene 003.mp4']
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31885_17_English_Lands&IMG=OLP.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31885_17_English_Lands&IMG=OLP.mp4 - Scene 003.mp4']
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31884_17_English_Lands&IMG=OLO.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31884_17_English_Lands&IMG=OLO.mp4 - Scene 003.mp4']
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN.mp4 - Scene 003.mp4']
# []

# %%
#Unseen_Start
for i in total:
    filepaths = list(pd.Series(list(image_dir.glob(r'{}/*.mp4'.format(i))), name='Filepath').astype(str))
    print(filepaths[0])
    shutil.copy2(filepaths[0],f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/Unseen_Start')
# Out:
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4/LLC_BuffaloDeluxe_V26393_15_English_Portrait&IMG=KD5.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V28685_15_English_Portrait&IMG=M4T.mp4/LLC_LightningLinkMultipleIP_V28685_15_English_Portrait&IMG=M4T.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_UA_V723_15_No%20Language_Square&IMG=K3.mp4/LLC_UA_V723_15_No%20Language_Square&IMG=K3.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4/LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V20593_15_English_Portrait&IMG=FW1.mp4/LLC_BuffaloDeluxe_V20593_15_English_Portrait&IMG=FW1.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V30648_15_English_Square&IMG=NNC.mp4/LLC_BuffaloDeluxe_V30648_15_English_Square&IMG=NNC.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V31163_15_English_Portrait&IMG=O1N.mp4/LLC_LightningLinkMultipleIP_V31163_15_English_Portrait&IMG=O1N.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4/LLC_BuffaloDeluxe_V31966_30_English_Landscape&IMG=ONY.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4/LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V30647_15_English_Portrait&IMG=NNB.mp4/LLC_BuffaloDeluxe_V30647_15_English_Portrait&IMG=NNB.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4/LLC_BuffaloDeluxe_V22526_15_English_Square&IMG=HDQ.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4/LLC_LightningLinkInfluencerCrypt_V31934_30_English_Landscape&IMG=ON2.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V28686_15_English_Square&IMG=M4U.mp4/LLC_LightningLinkMultipleIP_V28686_15_English_Square&IMG=M4U.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V28694_15_English_Portrait&IMG=M52.mp4/LLC_LightningLinkMultipleIP_V28694_15_English_Portrait&IMG=M52.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_BuffaloDeluxe_V25786_15_English_Square&IMG=JWA.mp4/LLC_BuffaloDeluxe_V25786_15_English_Square&IMG=JWA.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_LightningLinkMultipleIP_V28688_15_English_Portrait&IMG=M4W.mp4/LLC_LightningLinkMultipleIP_V28688_15_English_Portrait&IMG=M4W.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31911_30_English_Lands&IMG=OMF.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31910_30_English_Lands&IMG=OME.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31909_30_English_Portr&IMG=OMD.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31908_30_English_Portr&IMG=OMC.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31905_30_English_Lands&IMG=OM9.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31903_30_English_Portr&IMG=OM7.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31903_30_English_Portr&IMG=OM7.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31902_30_English_Portr&IMG=OM6.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31902_30_English_Portr&IMG=OM6.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31890_17_English_Lands&IMG=OLU.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31889_17_English_Portr&IMG=OLT.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31888_17_English_Lands&IMG=OLS.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31887_17_English_Portr&IMG=OLR.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31887_17_English_Portr&IMG=OLR.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31886_17_English_Squar&IMG=OLQ.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31886_17_English_Squar&IMG=OLQ.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31885_17_English_Lands&IMG=OLP.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31885_17_English_Lands&IMG=OLP.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31884_17_English_Lands&IMG=OLO.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31884_17_English_Lands&IMG=OLO.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31883_17_English_Portr&IMG=OLN.mp4 - Scene 001.mp4
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_F_DATA/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31882_17_English_Portr&IMG=OLM.mp4/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31882_17_English_Portr&IMG=OLM.mp4 - Scene 001.mp4

# %%
import numpy as np
import cv2 # extract frames from the videos
from PIL import Image  # to manipulate images
import os
import psycopg2

from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.preprocessing.image import load_img,img_to_array
from tensorflow.keras.models import Model
from tensorflow.keras.applications.imagenet_utils import preprocess_input

from PIL import Image
import os
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
from google.colab.patches import cv2_imshow
import pickle
from tqdm import tqdm
import moviepy.editor
# Import everything needed to edit video clips
from moviepy.editor import VideoFileClip, AudioFileClip, concatenate_videoclips, TextClip, CompositeVideoClip, concatenate_audioclips, AudioClip, CompositeAudioClip

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %%
# load the model
dense_model = DenseNet201(weights='imagenet')

# remove the last layers in order to get features instead of predictions
feat_extractor = Model(inputs=dense_model.input, outputs=dense_model.get_layer("avg_pool").output)

# print the layers of the CNN
feat_extractor.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels.h5
# 82526208/82524592 [==============================] - 3s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 112, 112, 64) 0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 114, 114, 64) 0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 56, 56, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 56, 56, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 56, 56, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 56, 56, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 56, 56, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 56, 56, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 56, 56, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 56, 56, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 56, 56, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 56, 56, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 56, 56, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 56, 56, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 56, 56, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 56, 56, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 56, 56, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 56, 56, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 56, 56, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 56, 56, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 56, 56, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 56, 56, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 56, 56, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 56, 56, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 56, 56, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 56, 56, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 56, 56, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 28, 28, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 28, 28, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 28, 28, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 28, 28, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 28, 28, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 28, 28, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 28, 28, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 28, 28, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 28, 28, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 28, 28, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 28, 28, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 28, 28, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 28, 28, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 28, 28, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 28, 28, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 28, 28, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 28, 28, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 28, 28, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 28, 28, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 28, 28, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 28, 28, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 28, 28, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 28, 28, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 28, 28, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 28, 28, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 28, 28, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 28, 28, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 28, 28, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 28, 28, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 28, 28, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 28, 28, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 28, 28, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 28, 28, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 28, 28, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 28, 28, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 28, 28, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 28, 28, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 28, 28, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 28, 28, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 28, 28, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 28, 28, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 28, 28, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 28, 28, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 28, 28, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 28, 28, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 28, 28, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 28, 28, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 28, 28, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 28, 28, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 28, 28, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 28, 28, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 28, 28, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 14, 14, 256)  0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 256)  1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 14, 14, 256)  0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 128)  32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 128)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 14, 14, 288)  0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 14, 14, 288)  1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 14, 14, 288)  0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 128)  36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 128)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 14, 14, 320)  0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 14, 14, 320)  1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 14, 14, 320)  0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 128)  40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 128)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 14, 14, 352)  0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 14, 14, 352)  1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 14, 14, 352)  0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 128)  45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 128)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 14, 14, 384)  0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 14, 14, 384)  1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 14, 14, 384)  0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 128)  49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 128)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 14, 14, 416)  0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 14, 14, 416)  1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 14, 14, 416)  0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 128)  53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 128)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 14, 14, 448)  0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 14, 14, 448)  1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 14, 14, 448)  0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 14, 14, 128)  57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 14, 14, 128)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 14, 14, 480)  0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 14, 14, 480)  1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 14, 14, 480)  0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 14, 14, 128)  61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 14, 14, 128)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 14, 14, 512)  0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 14, 14, 512)  2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 14, 14, 512)  0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 14, 14, 128)  65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 14, 14, 128)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 14, 14, 544)  0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 14, 14, 544)  2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 14, 14, 544)  0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 14, 14, 128)  69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 14, 14, 576)  0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 14, 14, 576)  2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 14, 14, 576)  0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 14, 14, 128)  73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 14, 14, 608)  0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 14, 14, 608)  2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 14, 14, 608)  0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 14, 14, 128)  77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 14, 14, 640)  0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# ...
# conv5_block22_concat (Concatena (None, 7, 7, 1600)   0           conv5_block21_concat[0][0]
#                                                                  conv5_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_bn (BatchNormal (None, 7, 7, 1600)   6400        conv5_block22_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_relu (Activatio (None, 7, 7, 1600)   0           conv5_block23_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_conv (Conv2D)   (None, 7, 7, 128)    204800      conv5_block23_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_concat (Concatena (None, 7, 7, 1632)   0           conv5_block22_concat[0][0]
#                                                                  conv5_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_bn (BatchNormal (None, 7, 7, 1632)   6528        conv5_block23_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_relu (Activatio (None, 7, 7, 1632)   0           conv5_block24_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_conv (Conv2D)   (None, 7, 7, 128)    208896      conv5_block24_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block24_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block24_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block24_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_concat (Concatena (None, 7, 7, 1664)   0           conv5_block23_concat[0][0]
#                                                                  conv5_block24_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_bn (BatchNormal (None, 7, 7, 1664)   6656        conv5_block24_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_relu (Activatio (None, 7, 7, 1664)   0           conv5_block25_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_conv (Conv2D)   (None, 7, 7, 128)    212992      conv5_block25_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block25_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block25_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block25_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_concat (Concatena (None, 7, 7, 1696)   0           conv5_block24_concat[0][0]
#                                                                  conv5_block25_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_bn (BatchNormal (None, 7, 7, 1696)   6784        conv5_block25_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_relu (Activatio (None, 7, 7, 1696)   0           conv5_block26_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_conv (Conv2D)   (None, 7, 7, 128)    217088      conv5_block26_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block26_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block26_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block26_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_concat (Concatena (None, 7, 7, 1728)   0           conv5_block25_concat[0][0]
#                                                                  conv5_block26_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_bn (BatchNormal (None, 7, 7, 1728)   6912        conv5_block26_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_relu (Activatio (None, 7, 7, 1728)   0           conv5_block27_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_conv (Conv2D)   (None, 7, 7, 128)    221184      conv5_block27_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block27_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block27_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block27_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_concat (Concatena (None, 7, 7, 1760)   0           conv5_block26_concat[0][0]
#                                                                  conv5_block27_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_bn (BatchNormal (None, 7, 7, 1760)   7040        conv5_block27_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_relu (Activatio (None, 7, 7, 1760)   0           conv5_block28_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_conv (Conv2D)   (None, 7, 7, 128)    225280      conv5_block28_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block28_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block28_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block28_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_concat (Concatena (None, 7, 7, 1792)   0           conv5_block27_concat[0][0]
#                                                                  conv5_block28_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_bn (BatchNormal (None, 7, 7, 1792)   7168        conv5_block28_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_relu (Activatio (None, 7, 7, 1792)   0           conv5_block29_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_conv (Conv2D)   (None, 7, 7, 128)    229376      conv5_block29_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block29_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block29_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block29_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_concat (Concatena (None, 7, 7, 1824)   0           conv5_block28_concat[0][0]
#                                                                  conv5_block29_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_bn (BatchNormal (None, 7, 7, 1824)   7296        conv5_block29_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_relu (Activatio (None, 7, 7, 1824)   0           conv5_block30_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_conv (Conv2D)   (None, 7, 7, 128)    233472      conv5_block30_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block30_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block30_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block30_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_concat (Concatena (None, 7, 7, 1856)   0           conv5_block29_concat[0][0]
#                                                                  conv5_block30_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_bn (BatchNormal (None, 7, 7, 1856)   7424        conv5_block30_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_relu (Activatio (None, 7, 7, 1856)   0           conv5_block31_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_conv (Conv2D)   (None, 7, 7, 128)    237568      conv5_block31_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block31_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block31_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block31_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_concat (Concatena (None, 7, 7, 1888)   0           conv5_block30_concat[0][0]
#                                                                  conv5_block31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_bn (BatchNormal (None, 7, 7, 1888)   7552        conv5_block31_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_relu (Activatio (None, 7, 7, 1888)   0           conv5_block32_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_conv (Conv2D)   (None, 7, 7, 128)    241664      conv5_block32_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_concat (Concatena (None, 7, 7, 1920)   0           conv5_block31_concat[0][0]
#                                                                  conv5_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 7, 7, 1920)   7680        conv5_block32_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 7, 7, 1920)   0           bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1920)         0           relu[0][0]
# ==================================================================================================
# Total params: 18,321,984
# Trainable params: 18,092,928
# Non-trainable params: 229,056
# __________________________________________________________________________________________________

# %%
# parameters setup

video_path_mid = f"/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/MID/"
video_path_end = f"/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/END/"
target_path = f"/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_Training_Data/Unseen_Start/"
video_model_width, video_model_height = 224, 224
No_of_frames = 10
No_of_mid_scenes = 2
No_of_end_scenes = 1

nb_closest_videos = 1

# %%
files_mid = [video_path_mid + x for x in os.listdir(video_path_mid) if ".mp4" in x]
#files_mid = np.random.choice(files_mid, 20)
files_mid = list(set(files_mid))
print("number of videos in Mid :",len(files_mid))

files_end = [video_path_end + x for x in os.listdir(video_path_end) if ".mp4" in x]
#files_end = np.random.choice(files_end, 5)
files_end = list(set(files_end))
print("number of videos in end:",len(files_end))
# Out:
# number of videos in Mid : 113
# number of videos in end: 36

# %%
target = [target_path + x for x in os.listdir(target_path) if ".mp4" in x]
#files1 = np.random.choice(files1, 3)
print("number of Videos:",len(target))
target = list(target)
print(len(target))
a = []
for vid in target:
      video = moviepy.editor.VideoFileClip(vid)
      video_duration = int(video.duration)
    #  print(video_duration)
      if video_duration > 0:
        a.append(vid)
        
target = a
print(len(target))
t = target[4]
target = []
target.append(t)
target
# Out:
# number of Videos: 36
# 36
# 34
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/Unseen_Start/LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4 - Scene 001.mp4']

# %%
target_clip = VideoFileClip(target[0])      
# getting only first 5 seconds
target_clip = target_clip.subclip(0, 5) 
# getting clip size
height, width = target_clip.size
print("Height is :",height,"Width is :",width)
# Out:
# Height is : 600 Width is : 600

# %% [markdown]
# ### Filtering files_mid & files_end according to the target scene aspect ratio

# %%
def clip_duration_check(files):    
    counter = 0
    a = []
    mid_files = []
    for vid in files:
      video = moviepy.editor.VideoFileClip(vid)
      video_height, video_width = video.size
    # Contains the duration of the video in terms of seconds
      video_duration = int(video.duration)
    #  print(video_duration)
      if video_duration > 0 and video_height==height and video_width==width:
        a.append(vid)
        counter += 1
    print(counter)
    return a

# %%
files_mid = clip_duration_check(files_mid)
files_end = clip_duration_check(files_end)
# Out:
# 25
# 12

# %% [markdown]
# # Capture Global Performance Data to scenes into dataframes

# %%
# Fetching Data directly from Database
def global_performance(clip_name):
  conn = psycopg2.connect(user = "ds_readonly", password = "blkbox2020!",host = "db.blkbox.ai",port = "5432",database = "blkbox")
  sql = ("select distinct(global_performance) "   
        "from fb_app_assets "
        "where asset_name like '%{a}%' and asset_type = 'VIDEO'; ".format(a=clip_name))
  data = pd.read_sql_query(sql, conn)
  conn = None
  return max(data.global_performance,default=0)

# %%
def performance_df(files,section):
  counter = 0
  performance = []
  video_name_list = []
  for video in files:
    s1 = video
    s2 = "{a}/".format(a=section)
    s3 = "- Scene"

    name = s1[s1.index(s2) + len(s2):s1.index(s3)]
    video_name_list.append(name)
    performance.append(global_performance(name))
  print(len(video_name_list))
  print(len(performance))
  print(len(files))
  df = pd.DataFrame(list(zip(video_name_list, files, performance)),columns =['video_name','files_path','performance'])
  return df

# %%
df_mid_performance = performance_df(files_mid,'MID')
df_end_performance = performance_df(files_end,'END')
# Out:
# 25
# 25
# 25
# 12
# 12
# 12

# %%
print(df_mid_performance.head())
print(df_end_performance.head())
# Out:
#                                           video_name  ... performance
# 0  LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGol...  ...           0
# 1  LLC_BuffaloDeluxe_V26394_17_English_Square&IMG...  ...           0
# 2  LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGol...  ...           0
# 3  LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGol...  ...           0
# 4  LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGol...  ...           0
#
# [5 rows x 3 columns]
#                                           video_name  ... performance
# 0  LLC_GEN_Happy%20and%20Prosperous%20Drago%20Lin...  ...           0
# 1    LLC_UA_V723_15_No%20Language_Square&IMG=K3.mp4   ...           0
# 2  LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGol...  ...           0
# 3  LLC_BuffaloDeluxe_V26394_17_English_Square&IMG...  ...           0
# 4  LLC_LightningLinkMultipleIP_V28686_15_English_...  ...           0
#
# [5 rows x 3 columns]

# %% [markdown]
# #### Function to extract features from videos

# %%
def feature_extractor(files):  
  importedvideos = []
  # load all the images and prepare them for feeding into the CNN
  counter = 0

  for video in tqdm(files):
      
        frames = []
        count = 1

        path = video
        cap = cv2.VideoCapture(path)

        length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
   #    print("The total frames in the video is :",length)
        temp = length / No_of_frames
   #    print(temp)

        ret = True
        while ret:
          ret, img = cap.read() # read one frame from the 'capture' object; img is (H, W, C)
          if ret:
              img = cv2.resize(img, (224, 224))
              frames.append(img)
      #       cv2_imshow(img)
      #       print("****************************")
      #       print("****************************")
              count += temp
              cap.set(1,count)
          else:
            cap.release()
            break
        video_frames = np.stack(frames, axis=0)  
        # extract the images features

        imgs_features = feat_extractor.predict(video_frames)

        print("features successfully extracted!")
   #    print(imgs_features.shape)

        flatten_img_features = imgs_features.flatten()
        flatten_img_features = np.expand_dims(flatten_img_features,axis = 0)
        print(flatten_img_features.shape)
        importedvideos.append(flatten_img_features)
  videos_array = np.vstack(importedvideos)
  return videos_array

# %%
# Name of the directory where we want the splitted scenes to reside
if not os.path.exists(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ARRAY_STORAGE'):
    os.makedirs(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ARRAY_STORAGE')

# %%
videos_mid_train = feature_extractor(files_mid)
np.save(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ARRAY_STORAGE/videos_mid_train-{height}*{width}', videos_mid_train)
print()
videos_end_train = feature_extractor(files_end)
np.save(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ARRAY_STORAGE/videos_end_train-{height}*{width}', videos_end_train)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   6%|▋         | 1/16 [00:03<00:45,  3.02s/it]
# features successfully extracted!
# (1, 19200)
#  12%|█▎        | 2/16 [00:04<00:36,  2.61s/it]
# features successfully extracted!
# (1, 19200)
#  19%|█▉        | 3/16 [00:06<00:28,  2.23s/it]
# features successfully extracted!
# (1, 19200)
#  25%|██▌       | 4/16 [00:08<00:26,  2.17s/it]
# features successfully extracted!
# (1, 19200)
#  31%|███▏      | 5/16 [00:09<00:21,  1.97s/it]
# features successfully extracted!
# (1, 19200)
#  38%|███▊      | 6/16 [00:10<00:15,  1.59s/it]
# features successfully extracted!
# (1, 19200)
#  44%|████▍     | 7/16 [00:11<00:12,  1.36s/it]
# features successfully extracted!
# (1, 19200)
#  50%|█████     | 8/16 [00:13<00:12,  1.59s/it]
# features successfully extracted!
# (1, 19200)
#  56%|█████▋    | 9/16 [00:13<00:09,  1.32s/it]
# features successfully extracted!
# (1, 19200)
#  62%|██████▎   | 10/16 [00:16<00:10,  1.70s/it]
# features successfully extracted!
# (1, 19200)
#  69%|██████▉   | 11/16 [00:18<00:09,  1.83s/it]
# features successfully extracted!
# (1, 19200)
#  75%|███████▌  | 12/16 [00:20<00:07,  1.91s/it]
# features successfully extracted!
# (1, 19200)
#  81%|████████▏ | 13/16 [00:21<00:04,  1.64s/it]
# features successfully extracted!
# (1, 19200)
#  88%|████████▊ | 14/16 [00:22<00:03,  1.53s/it]
# features successfully extracted!
# (1, 19200)
#  94%|█████████▍| 15/16 [00:24<00:01,  1.46s/it]
# features successfully extracted!
# (1, 19200)
# 100%|██████████| 16/16 [00:26<00:00,  1.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/11 [00:00<?, ?it/s]
# features successfully extracted!
# (1, 19200)
#   9%|▉         | 1/11 [00:02<00:24,  2.49s/it]
# features successfully extracted!
# (1, 19200)
#  18%|█▊        | 2/11 [00:04<00:19,  2.20s/it]
# features successfully extracted!
# (1, 19200)
#  27%|██▋       | 3/11 [00:05<00:14,  1.86s/it]
# features successfully extracted!
# (1, 19200)
#  36%|███▋      | 4/11 [00:08<00:16,  2.33s/it]
# features successfully extracted!
# (1, 19200)
#  45%|████▌     | 5/11 [00:11<00:14,  2.43s/it]
# features successfully extracted!
# (1, 19200)
#  55%|█████▍    | 6/11 [00:13<00:12,  2.53s/it]
# features successfully extracted!
# (1, 19200)
#  64%|██████▎   | 7/11 [00:14<00:08,  2.06s/it]
# features successfully extracted!
# (1, 19200)
#  73%|███████▎  | 8/11 [00:17<00:06,  2.13s/it]
# features successfully extracted!
# (1, 19200)
#  82%|████████▏ | 9/11 [00:19<00:04,  2.28s/it]
# features successfully extracted!
# (1, 19200)
#  91%|█████████ | 10/11 [00:22<00:02,  2.41s/it]
# features successfully extracted!
# (1, 19200)
# 100%|██████████| 11/11 [00:23<00:00,  2.14s/it]
# features successfully extracted!
# (1, 19200)

# %%
videos_mid_train = np.load(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ARRAY_STORAGE/videos_mid_train-{height}*{width}.npy')  
print(videos_mid_train.shape)

videos_end_train = np.load(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_ARRAY_STORAGE/videos_end_train-{height}*{width}.npy')  
print(videos_end_train.shape)
# Out:
# (25, 19200)
# (12, 19200)

# %% [markdown]
# ### Feature Extraction for target

# %%
videos_test = feature_extractor(target)
print(videos_test.shape)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 1/1 [00:01<00:00,  1.76s/it]
# features successfully extracted!
# (1, 19200)
# (1, 19200)

# %%
def array_file_merge(video_array,target_array,files_train,target): 
  array = np.concatenate((video_array,target_array),axis=0)
  print(array.shape)
  files_t = files_train + target
  print(len(files_t))
  return array, files_t

# %%
arr_mid, files_t = array_file_merge(videos_mid_train,videos_test,files_mid,target)
# Out:
# (26, 19200)
# 26

# %%
# compute cosine similarities between videos
def cos(arr,files):
  cosSimilarities = cosine_similarity(arr)

  # store the results into a pandas dataframe

  cos_similarities_df = pd.DataFrame(cosSimilarities, columns=files, index=files)
  print(cos_similarities_df.shape)
  return cos_similarities_df

# %%
# function to retrieve the most similar video to the given
M = []
E = []

def retrieve_most_similar_videos(arr,files,given_video,position,nb_closest_videos):

    cos_similarities_df = cos(arr,files)
    print("*********************************")
    print("Original Add Video:")
    print("*********************************")
    print(given_video)
    print("-----------------------------------------------------------------------")
    print("Most Similar Video Recommended:")

    closest_videos = cos_similarities_df[given_video].sort_values(ascending=False)[1:nb_closest_videos+1].index
    closest_videos_scores = cos_similarities_df[given_video].sort_values(ascending=False)[1:nb_closest_videos+1]

    for i in range(0,len(closest_videos)):
        print(closest_videos[i])
        #Get performance data from the performance dataframe
        try:
          if position == 'mid':
            perf = float(df_mid_performance.query("files_path == '{a}'".format(a=closest_videos[i])).performance)
            print('The global performance of video :',perf)
            performance_score.append(perf)
          elif position == 'end':
            perf = float(df_end_performance.query("files_path == '{a}'".format(a=closest_videos[i])).performance)
            print('The global performance of video :',perf)
            performance_score.append(perf)
        except:
            performance_score.append(0)

        if position == 'mid':
          M.append(closest_videos[i])
        elif position == 'end':
          E.append(closest_videos[i])
        print("Cosine Similarity Score: ",closest_videos_scores[i])
        print('---------------------------------------------------------------------')

# %%
MIDDLE_SCENES = []
performance_score = []
start_index = len(files_t)-1
#print(start_index)
for clip in range(No_of_mid_scenes):
  
  retrieve_most_similar_videos(arr_mid,files_t,files_t[start_index],'mid',3)
  print(M)
  print(performance_score)
  MIDDLE = M[performance_score.index(max(performance_score))]
  print(MIDDLE)
  MIDDLE_SCENES.append(MIDDLE)
  M = []
  performance_score = []
 # start_index = files_t.index(M[-1])
 # print("Start index",start_index)
  start_index = files_t.index(MIDDLE_SCENES[-1])
  print("Start index",start_index)
# Out:
# (26, 26)
# *********************************
# Original Add Video:
# *********************************
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/Unseen_Start/LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4 - Scene 001.mp4
# -----------------------------------------------------------------------
# Most Similar Video Recommended:
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4 - Scene 002.mp4
# The global performance of video : 0.0
# Cosine Similarity Score:  0.7467317
# ---------------------------------------------------------------------
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4 - Scene 003.mp4
# The global performance of video : 0.0
# Cosine Similarity Score:  0.7436519
# ---------------------------------------------------------------------
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4 - Scene 002.mp4
# The global performance of video : 0.0
# Cosine Similarity Score:  0.74100876
# ---------------------------------------------------------------------
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4 - Scene 002.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4 - Scene 003.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_BuffaloDeluxe_V22531_15_English_Square&IMG=HDV.mp4 - Scene 002.mp4']
# [0.0, 0.0, 0.0]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4 - Scene 002.mp4
# Start index 1
# (26, 26)
# *********************************
# Original Add Video:
# *********************************
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4 - Scene 002.mp4
# -----------------------------------------------------------------------
# Most Similar Video Recommended:
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4 - Scene 004.mp4
# The global performance of video : 0.0
# Cosine Similarity Score:  0.86652166
# ---------------------------------------------------------------------
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4 - Scene 004.mp4
# The global performance of video : 0.0
# Cosine Similarity Score:  0.81145394
# ---------------------------------------------------------------------
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4 - Scene 008.mp4
# The global performance of video : 0.0
# Cosine Similarity Score:  0.81022793
# ---------------------------------------------------------------------
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4 - Scene 004.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4 - Scene 004.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31907_30_English_Squar&IMG=OMB.mp4 - Scene 008.mp4']
# [0.0, 0.0, 0.0]
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4 - Scene 004.mp4
# Start index 0

# %%
print('$$$$$$$$$$$$$$$$')
print(performance_score)
print(len(performance_score))
print('$$$$$$$$$$$$$$$$')
print(M)
print(len(M))
print('$$$$$$$$$$$$$$$$')
print(MIDDLE_SCENES)
print(len(MIDDLE_SCENES))
# Out:
# $$$$$$$$$$$$$$$$
# []
# 0
# $$$$$$$$$$$$$$$$
# []
# 0
# $$$$$$$$$$$$$$$$
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4 - Scene 002.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4 - Scene 004.mp4']
# 2

# %%
#retrieve_most_similar_videos(arr_mid,files_t,files_t[len(files_t)-1],'mid',1)

# %%
#M

# %%
#files_t.index(M[0])

# %%
#retrieve_most_similar_videos(arr_mid,files_t,files_t[15],'mid',1)

# %%
#M

# %%
#files_t.index(M[1])

# %%
#retrieve_most_similar_videos(arr_mid,files_t,files_t[20],'mid',1)

# %%
target1 = MIDDLE_SCENES[-1:]
#target1 = target[-1:]
target1
# Out:
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4 - Scene 004.mp4']

# %%
videos_test = feature_extractor(target1)
print(videos_test.shape)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 1/1 [00:00<00:00,  2.06it/s]
# features successfully extracted!
# (1, 19200)
# (1, 19200)

# %%
arr_end, files_t1 = array_file_merge(videos_end_train,videos_test,files_end,target1)
# Out:
# (13, 19200)
# 13

# %%
retrieve_most_similar_videos(arr_end,files_t1,files_t1[len(files_t1)-1],'end',1)
# Out:
# (13, 13)
# *********************************
# Original Add Video:
# *********************************
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4 - Scene 004.mp4
# -----------------------------------------------------------------------
# Most Similar Video Recommended:
# /content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/END/LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4 - Scene 003.mp4
# The global performance of video : 0.0
# Cosine Similarity Score:  0.7700554
# ---------------------------------------------------------------------

# %% [markdown]
# # RESTICHING PREDICTED SCENES BACK

# %%
# Name of the directory where we want the splitted scenes to reside
if not os.path.exists(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_RESULT'):
    os.makedirs(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_RESULT')

# %%
print(target)
print(M)
print(MIDDLE_SCENES)
print(E)
# Out:
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/Unseen_Start/LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4 - Scene 001.mp4']
# []
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4 - Scene 002.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4 - Scene 004.mp4']
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/END/LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4 - Scene 003.mp4']

# %%
S = target

clip = VideoFileClip(S[0])      
# getting only first 5 seconds
clip = clip.subclip(0, 5) 
# getting clip size
height, width = clip.size
print("Height is :",height,"Width is :",width)

#res = S + M + E
res = S + MIDDLE_SCENES + E 

RESULT = []
[RESULT.append(x) for x in res if x not in RESULT]
print(RESULT)
print("Total scenes in result are :",len(RESULT))
# Out:
# Height is : 600 Width is : 600
# ['/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/Unseen_Start/LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4 - Scene 001.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_BuffaloDeluxe_V26394_17_English_Square&IMG=KD6.mp4 - Scene 002.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/MID/LLC_CreativeWorkshopConcept1BuffaloDeluxeVSGoldenCentury_V31901_30_English_Squar&IMG=OM5.mp4 - Scene 004.mp4', '/content/drive/MyDrive/Scene-Detection-Version-2/LLC_Training_Data/END/LLC_WildChuco_V28769_15_English_Square&IMG=M75.mp4 - Scene 003.mp4']
# Total scenes in result are : 4

# %%
counter = 0
final = []
for video in RESULT:
  video = VideoFileClip("{a}".format(a=video))
  print(video.size)
  video = video.resize( (height,width) )
  final.append(video)
  counter += 1

print(final)
# Out:
# [600, 600]
# [600, 600]
# [600, 600]
# [600, 600]
# [<moviepy.video.io.VideoFileClip.VideoFileClip object at 0x7f6076c53e90>, <moviepy.video.io.VideoFileClip.VideoFileClip object at 0x7f6076c53ad0>, <moviepy.video.io.VideoFileClip.VideoFileClip object at 0x7f6076c54890>, <moviepy.video.io.VideoFileClip.VideoFileClip object at 0x7f6076cc3250>]

# %% [markdown]
# # RESULTS

# %%
final_video= concatenate_videoclips(final)
final_video.write_videofile(f'/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_RESULT/video_merge.mp4')
# Out:
# [MoviePy] >>>> Building video /content/drive/MyDrive/Scene-Detection-Version-2/LLC_RESULT/video_merge.mp4
# [MoviePy] Writing audio in video_mergeTEMP_MPY_wvf_snd.mp3
#   0%|          | 0/485 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 62/485 [00:00<00:00, 619.98it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 125/485 [00:00<00:00, 621.43it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  40%|███▉      | 192/485 [00:00<00:00, 634.74it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  52%|█████▏    | 254/485 [00:00<00:00, 622.49it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  67%|██████▋   | 325/485 [00:00<00:00, 645.32it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 384/485 [00:00<00:00, 626.63it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 485/485 [00:00<00:00, 626.98it/s]
# [MoviePy] Done.
# [MoviePy] Writing video /content/drive/MyDrive/Scene-Detection-Version-2/LLC_RESULT/video_merge.mp4
#   0%|          | 0/659 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 16/659 [00:00<00:04, 152.23it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 35/659 [00:00<00:03, 161.73it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 51/659 [00:00<00:03, 160.62it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 62/659 [00:00<00:07, 84.45it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 71/659 [00:00<00:11, 52.64it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 79/659 [00:01<00:12, 45.51it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 85/659 [00:01<00:12, 44.69it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▍        | 91/659 [00:01<00:12, 46.71it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▍        | 97/659 [00:01<00:12, 45.53it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 103/659 [00:01<00:11, 49.03it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 109/659 [00:01<00:12, 44.10it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 116/659 [00:01<00:11, 48.52it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▊        | 122/659 [00:02<00:11, 46.31it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 127/659 [00:02<00:12, 42.52it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|██        | 132/659 [00:02<00:11, 44.45it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 137/659 [00:02<00:12, 42.23it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 142/659 [00:02<00:12, 41.87it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 147/659 [00:02<00:12, 42.49it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 152/659 [00:02<00:12, 39.34it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 157/659 [00:02<00:12, 39.54it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 162/659 [00:03<00:12, 38.68it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▌       | 166/659 [00:03<00:12, 38.74it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 170/659 [00:03<00:12, 38.74it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 174/659 [00:03<00:12, 39.01it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 178/659 [00:03<00:12, 39.29it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 183/659 [00:03<00:11, 40.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 190/659 [00:03<00:10, 43.72it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|██▉       | 195/659 [00:03<00:10, 43.34it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 201/659 [00:03<00:09, 46.33it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███▏      | 206/659 [00:04<00:09, 46.96it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 211/659 [00:04<00:09, 47.63it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 216/659 [00:04<00:09, 44.41it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▎      | 221/659 [00:04<00:10, 41.43it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 226/659 [00:04<00:11, 39.30it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▌      | 231/659 [00:04<00:12, 33.84it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 235/659 [00:04<00:12, 33.95it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▋      | 239/659 [00:05<00:13, 30.56it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 243/659 [00:05<00:13, 31.90it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 248/659 [00:05<00:12, 33.76it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 252/659 [00:05<00:11, 34.19it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  39%|███▉      | 257/659 [00:05<00:11, 35.93it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  40%|███▉      | 262/659 [00:05<00:10, 38.34it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  40%|████      | 266/659 [00:05<00:10, 38.09it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  41%|████      | 270/659 [00:05<00:10, 37.90it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 274/659 [00:05<00:10, 35.48it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 278/659 [00:06<00:10, 35.93it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  43%|████▎     | 283/659 [00:06<00:10, 36.58it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  44%|████▎     | 287/659 [00:06<00:09, 37.22it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  44%|████▍     | 291/659 [00:06<00:09, 37.93it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  45%|████▌     | 297/659 [00:06<00:09, 39.51it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  46%|████▌     | 301/659 [00:06<00:09, 38.92it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  46%|████▋     | 305/659 [00:06<00:09, 37.56it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 310/659 [00:06<00:08, 39.76it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  48%|████▊     | 315/659 [00:07<00:08, 38.86it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  48%|████▊     | 319/659 [00:07<00:09, 36.98it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  49%|████▉     | 323/659 [00:07<00:08, 37.80it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  50%|████▉     | 327/659 [00:07<00:08, 38.01it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  50%|█████     | 332/659 [00:07<00:08, 40.87it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  51%|█████▏    | 338/659 [00:07<00:07, 42.73it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  52%|█████▏    | 344/659 [00:07<00:07, 44.91it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 349/659 [00:07<00:07, 41.64it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  54%|█████▍    | 355/659 [00:07<00:06, 45.05it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  55%|█████▍    | 360/659 [00:08<00:07, 42.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  55%|█████▌    | 365/659 [00:08<00:06, 42.98it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  56%|█████▌    | 370/659 [00:08<00:07, 37.45it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 374/659 [00:08<00:08, 31.90it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 378/659 [00:08<00:08, 32.05it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 382/659 [00:08<00:09, 30.66it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  59%|█████▊    | 386/659 [00:08<00:08, 31.26it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  59%|█████▉    |
/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: /content/drive/MyDrive/Scene-Detection-Version-2/LLC_RESULT/video_merge.mp4

# %%
videoclip = VideoFileClip(f"/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_RESULT/video_merge.mp4")
clip_duration = videoclip.duration
audioclip = AudioFileClip("/content/drive/MyDrive/Scene_Detection/music.mp3").set_duration(clip_duration)

new_audioclip = CompositeAudioClip([audioclip])
videoclip.audio = new_audioclip

name_start_index = target[0].index("LLC_G")
name_end_index = target[0].index(".mp4")
videoclip.write_videofile(f"/content/drive/MyDrive/Scene-Detection-Version-2/{ADSET}_RESULT/{target[0][name_start_index:name_end_index]}.mp4")
# Out:
# [MoviePy] >>>> Building video /content/drive/MyDrive/Scene-Detection-Version-2/LLC_RESULT/LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4
# [MoviePy] Writing audio in LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4TEMP_MPY_wvf_snd.mp3
#   0%|          | 0/486 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 65/486 [00:00<00:00, 648.90it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▌       | 123/486 [00:00<00:00, 622.00it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 181/486 [00:00<00:00, 605.43it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  49%|████▉     | 240/486 [00:00<00:00, 598.97it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  60%|██████    | 294/486 [00:00<00:00, 579.52it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  73%|███████▎  | 356/486 [00:00<00:00, 578.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  86%|████████▌ | 418/486 [00:00<00:00, 587.86it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 486/486 [00:00<00:00, 576.23it/s]
# [MoviePy] Done.
# [MoviePy] Writing video /content/drive/MyDrive/Scene-Detection-Version-2/LLC_RESULT/LLC_GEN_Happy%20and%20Prosperous%20Drago%20Link_15T_600x600_JA-&IMG=BJ4.mp4
#   0%|          | 0/661 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 23/661 [00:00<00:02, 226.40it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 44/661 [00:00<00:02, 220.41it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 56/661 [00:00<00:04, 142.80it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  10%|█         | 67/661 [00:00<00:08, 73.08it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  11%|█▏        | 76/661 [00:00<00:10, 57.38it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 83/661 [00:01<00:11, 51.52it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 89/661 [00:01<00:11, 49.89it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  14%|█▍        | 95/661 [00:01<00:11, 50.90it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  15%|█▌        | 101/661 [00:01<00:10, 51.03it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 107/661 [00:01<00:11, 48.58it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 114/661 [00:01<00:10, 51.63it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 120/661 [00:01<00:10, 52.49it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 126/661 [00:01<00:10, 48.69it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  20%|█▉        | 132/661 [00:02<00:11, 47.31it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 137/661 [00:02<00:11, 44.67it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  21%|██▏       | 142/661 [00:02<00:11, 43.59it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 147/661 [00:02<00:11, 43.11it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 152/661 [00:02<00:11, 44.78it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 157/661 [00:02<00:12, 41.82it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▍       | 162/661 [00:02<00:11, 41.92it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  25%|██▌       | 167/661 [00:02<00:11, 41.38it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 172/661 [00:03<00:12, 40.11it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 177/661 [00:03<00:11, 41.21it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 182/661 [00:03<00:11, 42.06it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 188/661 [00:03<00:10, 46.20it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 193/661 [00:03<00:10, 45.32it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  30%|███       | 200/661 [00:03<00:09, 48.89it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31%|███▏      | 207/661 [00:03<00:08, 51.26it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 213/661 [00:03<00:08, 50.76it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 219/661 [00:04<00:10, 44.01it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      | 224/661 [00:04<00:11, 39.20it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▍      | 229/661 [00:04<00:11, 38.06it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  35%|███▌      | 233/661 [00:04<00:12, 35.05it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  36%|███▌      | 237/661 [00:04<00:12, 34.96it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 242/661 [00:04<00:11, 35.88it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 246/661 [00:04<00:11, 36.47it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 250/661 [00:04<00:11, 37.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  39%|███▊      | 255/661 [00:05<00:11, 36.77it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  39%|███▉      | 259/661 [00:05<00:10, 37.03it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  40%|███▉      | 264/661 [00:05<00:10, 38.38it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  41%|████      | 270/661 [00:05<00:09, 42.15it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 275/661 [00:05<00:09, 39.50it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 280/661 [00:05<00:09, 41.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  43%|████▎     | 285/661 [00:05<00:09, 39.38it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  44%|████▍     | 291/661 [00:05<00:08, 41.41it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  45%|████▍     | 296/661 [00:06<00:08, 40.91it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  46%|████▌     | 301/661 [00:06<00:08, 40.64it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  46%|████▋     | 306/661 [00:06<00:08, 40.85it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 311/661 [00:06<00:08, 42.06it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  48%|████▊     | 316/661 [00:06<00:07, 43.26it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  49%|████▊     | 321/661 [00:06<00:07, 43.59it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  49%|████▉     |